# %% [markdown]
# ## Analysis process - Dianela

# %%
import pandas as pd
from pathlib import Path
import statsmodels.formula.api as smf

import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV

# %%
raw_data   = Path("G:/Mi unidad/Master_LSE/Git-hub/Economic_Observatory/Data/raw_data")
clean_data = Path("G:/Mi unidad/Master_LSE/Git-hub/Economic_Observatory/Data/cleaning_data")

# %%
analysis_data = pd.read_csv(clean_data / "local_indicators_with_LAD_all_sample.csv")
analysis_data.head()
# Out:
# C:\Users\diane\AppData\Local\Temp\ipykernel_17508\2069571743.py:1: DtypeWarning: Columns (9,13,14,78,106,110,111,134) have mixed types. Specify dtype option on import or set low_memory=False.
#   analysis_data = pd.read_csv(clean_data / "local_indicators_with_LAD_all_sample.csv")
#    YEAR GEOGRAPHY_CODE GEOGRAPHY_NAME              IS8_SECTOR  \
# 0  2022      E06000001     Hartlepool  Advanced manufacturing
# 1  2022      E06000001     Hartlepool  Advanced manufacturing
# 2  2022      E06000001     Hartlepool  Advanced manufacturing
# 3  2022      E06000001     Hartlepool  Advanced manufacturing
# 4  2022      E06000001     Hartlepool     Creative Industries
#
#              FRONTIER_SECTOR  OBS_Value_Business  OBS_Value_Employment  \
# 0    Aerospace manufacturing                 0.0                   0.0
# 1                   Agritech                 0.0                   0.0
# 2   Automotive manufacturing                 0.0                 400.0
# 3                  Batteries                 0.0                   0.0
# 4  Advertising and marketing                10.0                  15.0
#
#    Area Code  ITL Level 1 [GVA per hour] County_or_Unitary_Authority  ...  \
# 0  E06000001                         NaN                  Hartlepool  ...
# 1  E06000001                         NaN                  Hartlepool  ...
# 2  E06000001                         NaN                  Hartlepool  ...
# 3  E06000001                         NaN                  Hartlepool  ...
# 4  E06000001                         NaN                  Hartlepool  ...
#
#                              Data accuracy [Anxiety]  Notes [Anxiety]  \
# 0  coefficient of variation is greater than 5% bu...              NaN
# 1  coefficient of variation is greater than 5% bu...              NaN
# 2  coefficient of variation is greater than 5% bu...              NaN
# 3  coefficient of variation is greater than 5% bu...              NaN
# 4  coefficient of variation is greater than 5% bu...              NaN
#
#    Local Authority District [Net additions]  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Net additions per 1,000 stock [Net additions] Notes [Net additions]  \
# 0                                          11.0                   NaN
# 1                                          11.0                   NaN
# 2                                          11.0                   NaN
# 3                                          11.0                   NaN
# 4                                          11.0                   NaN
#
#    Police Force Area [Homicide]  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   Homicide Offences (per million population) [Homicide]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Observation Status [Homicide]  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    % living in an area that has a devolution deal with a directly elected mayor  [Devolution]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both
#
# [5 rows x 185 columns]

# %%
threshold = 0.1  # drop columns with more than 10% missing
missing_pct = analysis_data.isnull().mean()  # gives proportion (0 to 1)
cols_to_keep = missing_pct[missing_pct < threshold].index.tolist()
cols_to_drop = missing_pct[missing_pct >= threshold].index.tolist()

print(f"Columns kept:    {len(cols_to_keep)}")
print(f"Columns dropped: {len(cols_to_drop)}")
print(f"\nDropped columns:\n{cols_to_drop}")

# Apply
X_clean = analysis_data[cols_to_keep]

X_clean.head()
# Out:
# Columns kept:    30
# Columns dropped: 155
#
# Dropped columns:
# ['ITL Level 1 [GVA per hour]', 'County_or_Unitary_Authority', 'Local Authority District [GVA per hour]', 'Notes [GVA per hour]', 'Country', 'Nation', 'Region', 'Local Authority District [Weekly pay]', 'Notes [Weekly pay]', 'Local Authority District [Employment rate]', 'Combined Authority or City Region [Employment rate]', 'Notes [Employment rate]', 'Local Authority District [Employment rate (NI)]', 'Employment rate, aged 16 to 64 years (%) [Employment rate (NI)]', 'Local Authority District [Unemployment rate]', 'Combined Authority or City Region [Unemployment rate]', 'Notes [Unemployment rate]', 'Local Authority District [GDHI per head]', 'Notes [GDHI per head]', 'Local Authority District [New enterprises]', 'Notes [New enterprises]', 'Local Authority District [Deaths of enterprises]', 'Notes [Deaths of enterprises]', 'Local Authority District [Active enterprises]', 'Notes [Active enterprises]', 'Local Authority District [High growth enterprises]', 'Notes [High growth enterprises]', 'ITL Level 1 [UK exports]', 'ITL Level 2 [UK exports]', 'Combined Authority or City Region [UK exports]', 'ITL Level 3 [UK exports]', 'Total value of UK exports (£ million) [UK exports]', 'ITL Level 1 [Inward FDI]', 'ITL Level 2 [Inward FDI]', 'Combined Authority or City Region [Inward FDI]', 'Total FDI international investment position in the UK at end period (£ million) [Inward FDI]', 'Notes [Inward FDI]', 'ITL Level 1 [Outward FDI]', 'ITL Level 2 [Outward FDI]', 'Combined Authority or City Region [Outward FDI]', 'Total FDI international investment position abroad at end period (£ million) [Outward FDI]', 'Notes [Outward FDI]', 'Total UK public-funded gross regional capital and non-capital expenditure on research and development (£ million) [Goverment R&D]', 'Local Authority District [Public transport to employer]', 'Average travel time in minutes to reach nearest large employment centre (500 to 4999 jobs available), by public transport or walking (minutes) [Public transport to employer]', 'Notes [Public transport to employer]', 'Local Authority District [Drive to employer]', 'Average travel time in minutes to reach nearest large employment centre (500 to 4999 jobs available), by car (minutes) [Drive to employer]', 'Notes [Drive to employer]', 'Local Authority District [Cycle to employer]', 'Average travel time in minutes to reach nearest large employment centre (500 to 4999 jobs available), by cycle (minutes) [Cycle to employer]', 'Notes [Cycle to employer]', 'Local Authority District [Broadband availability]', 'Notes [Broadband availability]', 'Local Authority District [4G area coverage]', 'Notes [4G area coverage]', 'Local Authority District [KS2 attainment]', 'Percentage of pupils in state-funded schools meeting the expected standard in reading, writing and maths at the end of key stage 2 (%) [KS2 attainment]', 'Local Authority District [GCSE by age 19]', 'Percentage of young people achieving GCSEs (and equivalent qualifications) in English and maths by age 19 (%) [GCSE by age 19]', 'Notes [GCSE by age 19]', 'Local Authority District [Ofsted]', 'Percentage of schools rated good or outstanding by Ofsted (%) [Ofsted]', 'Local Authority District [Persistent absences]', 'Percentage of persistent absences (10% or more missed) for all pupils (%) [Persistent absences]', 'Notes [Persistent absences]', 'Local Authority District [Persistent absences FSM]', 'Percentage of persistent absences (10% or more missed) eligible for free school meals in the past 6 years (%) [Persistent absences FSM]', 'Notes [Persistent absences FSM]', 'Local Authority District [Persistent absences CLA]', 'Percentage of persistent absences (10% or more missed) for pupils who are looked after continuously for at least 12 months by local authorities (%) [Persistent absences CLA]', 'Notes [Persistent absences CLA]', 'Local Authority District [Early years comms]', "Percentage of 5-year olds at 'expected level' in communication and language early learning goals (%) [Early years comm ...
#    YEAR GEOGRAPHY_CODE GEOGRAPHY_NAME              IS8_SECTOR  \
# 0  2022      E06000001     Hartlepool  Advanced manufacturing
# 1  2022      E06000001     Hartlepool  Advanced manufacturing
# 2  2022      E06000001     Hartlepool  Advanced manufacturing
# 3  2022      E06000001     Hartlepool  Advanced manufacturing
# 4  2022      E06000001     Hartlepool     Creative Industries
#
#              FRONTIER_SECTOR  OBS_Value_Business  OBS_Value_Employment  \
# 0    Aerospace manufacturing                 0.0                   0.0
# 1                   Agritech                 0.0                   0.0
# 2   Automotive manufacturing                 0.0                 400.0
# 3                  Batteries                 0.0                   0.0
# 4  Advertising and marketing                10.0                  15.0
#
#    Area Code  Gross Value Added (GVA) per hour worked (£) [GVA per hour]  \
# 0  E06000001                                              29.84
# 1  E06000001                                              29.84
# 2  E06000001                                              29.84
# 3  E06000001                                              29.84
# 4  E06000001                                              29.84
#
#   Gross median weekly pay (£) [Weekly pay]  ...  \
# 0                                    521.2  ...
# 1                                    521.2  ...
# 2                                    521.2  ...
# 3                                    521.2  ...
# 4                                    521.2  ...
#
#   Percentage of adults that currently smoke cigarettes (%) [Smokers]  \
# 0                                               14.3
# 1                                               14.3
# 2                                               14.3
# 3                                               14.3
# 4                                               14.3
#
#   Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]  \
# 0                                               7.29
# 1                                               7.29
# 2                                               7.29
# 3                                               7.29
# 4                                               7.29
#
#                    Data accuracy [Life satisfaction]  \
# 0  coefficient of variation is less than or equal...
# 1  coefficient of variation is less than or equal...
# 2  coefficient of variation is less than or equal...
# 3  coefficient of variation is less than or equal...
# 4  coefficient of variation is less than or equal...
#
#    Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]  \
# 0                                               7.75
# 1                                               7.75
# 2                                               7.75
# 3                                               7.75
# 4                                               7.75
#
#                           Data accuracy [Worthwhile]  \
# 0  coefficient of variation is less than or equal...
# 1  coefficient of variation is less than or equal...
# 2  coefficient of variation is less than or equal...
# 3  coefficient of variation is less than or equal...
# 4  coefficient of variation is less than or equal...
#
#    Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]  \
# 0                                               7.57
# 1                                               7.57
# 2                                               7.57
# 3                                               7.57
# 4                                               7.57
#
#                            Data accuracy [Happiness]  \
# 0  coefficient of variation is less than or equal...
# 1  coefficient of variation is less than or equal...
# 2  coefficient of variation is less than or equal...
# 3  coefficient of variation is less than or equal...
# 4  coefficient of variation is less than or equal...
#
#    Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]  \
# 0                                               3.48
# 1                                               3.48
# 2                                               3.48
# 3                                               3.48
# 4                                               3.48
#
#                              Data accuracy [Anxiety] _merge
# 0  coefficient of variation is greater than 5% bu...   both
# 1  coefficient of variation is greater than 5% bu...   both
# 2  coefficient of variation is greater than 5% bu...   both
# 3  coefficient of variation is greater than 5% bu...   both
# 4  coefficient of variation is greater than 5% bu...   both
#
# [5 rows x 30 columns]

# %%
cols_to_drop = [col for col in X_clean.columns if 
                col.startswith('Local Authority District') or
                col.startswith('Notes') or
                col.startswith('Data accuracy')]

# Drop merged variable and pattern-matched columns
X_clean = X_clean.drop(columns=['_merge', 'Area Code'] + cols_to_drop)

print(f"Columns dropped: {len(cols_to_drop) + 2}")
print(f"Remaining columns: {X_clean.shape[1]}")
# Out:
# Columns dropped: 6
# Remaining columns: 24

# %%
#Variables with growth rates:
X_clean= X_clean.rename(columns={
    'OBS_Value_Business': 'Business_growth_rate',
    'OBS_Value_Employment': 'Employment_growth_rate'
})

# %%
X_clean.head()
# Out:
#    YEAR GEOGRAPHY_CODE GEOGRAPHY_NAME              IS8_SECTOR  \
# 0  2022      E06000001     Hartlepool  Advanced manufacturing
# 1  2022      E06000001     Hartlepool  Advanced manufacturing
# 2  2022      E06000001     Hartlepool  Advanced manufacturing
# 3  2022      E06000001     Hartlepool  Advanced manufacturing
# 4  2022      E06000001     Hartlepool     Creative Industries
#
#              FRONTIER_SECTOR  Business_growth_rate  Employment_growth_rate  \
# 0    Aerospace manufacturing                   0.0                     0.0
# 1                   Agritech                   0.0                     0.0
# 2   Automotive manufacturing                   0.0                   400.0
# 3                  Batteries                   0.0                     0.0
# 4  Advertising and marketing                  10.0                    15.0
#
#    Gross Value Added (GVA) per hour worked (£) [GVA per hour]  \
# 0                                              29.84
# 1                                              29.84
# 2                                              29.84
# 3                                              29.84
# 4                                              29.84
#
#   Gross median weekly pay (£) [Weekly pay]  \
# 0                                    521.2
# 1                                    521.2
# 2                                    521.2
# 3                                    521.2
# 4                                    521.2
#
#   Employment rate, aged 16 to 64 years (%) [Employment rate]  ...  \
# 0                                               69.7          ...
# 1                                               69.7          ...
# 2                                               69.7          ...
# 3                                               69.7          ...
# 4                                               69.7          ...
#
#   Count of active enterprises (control rounded to base 5) [Active enterprises]  \
# 0                                             2430.0
# 1                                             2430.0
# 2                                             2430.0
# 3                                             2430.0
# 4                                             2430.0
#
#    Count of high growth enterprises (control rounded to base 5) [High growth enterprises]  \
# 0                                               10.0
# 1                                               10.0
# 2                                               10.0
# 3                                               10.0
# 4                                               10.0
#
#    Percentage of premises with gigabit-capable broadband (%) [Broadband availability]  \
# 0                                               91.4
# 1                                               91.4
# 2                                               91.4
# 3                                               91.4
# 4                                               91.4
#
#    Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]  \
# 0                                              99.98
# 1                                              99.98
# 2                                              99.98
# 3                                              99.98
# 4                                              99.98
#
#    Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]  \
# 0                                               56.4
# 1                                               56.4
# 2                                               56.4
# 3                                               56.4
# 4                                               56.4
#
#    Percentage of adults that currently smoke cigarettes (%) [Smokers]  \
# 0                                               14.3
# 1                                               14.3
# 2                                               14.3
# 3                                               14.3
# 4                                               14.3
#
#    Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]  \
# 0                                               7.29
# 1                                               7.29
# 2                                               7.29
# 3                                               7.29
# 4                                               7.29
#
#    Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]  \
# 0                                               7.75
# 1                                               7.75
# 2                                               7.75
# 3                                               7.75
# 4                                               7.75
#
#   Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]  \
# 0                                               7.57
# 1                                               7.57
# 2                                               7.57
# 3                                               7.57
# 4                                               7.57
#
#   Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]
# 0                                               3.48
# 1                                               3.48
# 2                                               3.48
# 3                                               3.48
# 4                                               3.48
#
# [5 rows x 24 columns]

# %%
#With the previous code, I realised that some of the indicators were not numeric, so I will convert them to numeric:
cols_to_convert = [
    'Gross median weekly pay (£) [Weekly pay]',
    'Employment rate, aged 16 to 64 years (%) [Employment rate]',
    'Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]',
    'Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]',
    'Percentage of adults that currently smoke cigarettes (%) [Smokers]',
    'Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]',
    'Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]',
    'Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]',
    'Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]'
]
for col in cols_to_convert:
    X_clean[col] = pd.to_numeric(X_clean[col], errors='coerce')

print(X_clean.dtypes)
# Out:
# YEAR                                                                                                       int64
# GEOGRAPHY_CODE                                                                                            object
# GEOGRAPHY_NAME                                                                                            object
# IS8_SECTOR                                                                                                object
# FRONTIER_SECTOR                                                                                           object
# Business_growth_rate                                                                                     float64
# Employment_growth_rate                                                                                   float64
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                               float64
# Gross median weekly pay (£) [Weekly pay]                                                                 float64
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                               float64
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               float64
# Gross disposable household income, per head (£) [GDHI per head]                                          float64
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                         float64
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                       float64
# Count of active enterprises (control rounded to base 5) [Active enterprises]                             float64
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                   float64
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       float64
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                 float64
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        float64
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       float64
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    float64
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     float64
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                             float64
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                 float64
# dtype: object

# %%
##Number of missing values after conversion
print(X_clean.isnull().sum())
# Out:
# YEAR                                                                                                       0
# GEOGRAPHY_CODE                                                                                             0
# GEOGRAPHY_NAME                                                                                             0
# IS8_SECTOR                                                                                                 0
# FRONTIER_SECTOR                                                                                            0
# Business_growth_rate                                                                                       0
# Employment_growth_rate                                                                                     0
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                               153
# Gross median weekly pay (£) [Weekly pay]                                                                  34
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                               102
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               357
# Gross disposable household income, per head (£) [GDHI per head]                                           68
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                          68
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                        68
# Count of active enterprises (control rounded to base 5) [Active enterprises]                              68
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                    68
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       153
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                 153
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        102
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       119
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    272
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     272
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                             272
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                 272
# dtype: int64

# %%
total = len(X_clean)
missing_pct = (X_clean.isnull().sum() / total * 100).round(1)
print(missing_pct[missing_pct > 0])
# Out:
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                               2.5
# Gross median weekly pay (£) [Weekly pay]                                                                 0.6
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                               1.7
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               5.9
# Gross disposable household income, per head (£) [GDHI per head]                                          1.1
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                         1.1
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                       1.1
# Count of active enterprises (control rounded to base 5) [Active enterprises]                             1.1
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                   1.1
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       2.5
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                 2.5
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        1.7
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       2.0
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    4.5
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     4.5
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                             4.5
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                 4.5
# dtype: float64

# %%
# How many LADs needed the national median fallback?
lads_with_all_missing = X_clean.groupby('GEOGRAPHY_CODE')[col].apply(
    lambda x: x.isnull().all()
).sum()

print(f"LADs with no data at all for {col}: {lads_with_all_missing}")
# Out:
# LADs with no data at all for Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]: 16

# %% [markdown]
# One important thing — the wellbeing variables (Life satisfaction, Happiness, Worthwhile, Anxiety) and Unemployment rate tend to be missing in the same 16-21 LADs. This is likely because smaller or more rural LADs don't report these statistics. Worth one line in your limitations:

# %% [markdown]
# For approximately 16-21 LADs (~5%) where no local data was available, missing values were imputed using the national median. These LADs are predominantly smaller or rural authorities with limited data reporting.

# %%
# Columns to exclude from indicators
cols_to_exclude = ['YEAR', 'GEOGRAPHY_CODE', 'GEOGRAPHY_NAME', 
                   'IS8_SECTOR', 'FRONTIER_SECTOR', 
                   'Business_growth_rate', 'Employment_growth_rate']

# X — only local indicators
indicators = X_clean.drop(columns=cols_to_exclude)

# %%
fallback_summary = {}
for col in indicators.columns:
    lads_all_missing = X_clean.groupby('GEOGRAPHY_CODE')[col].apply(
        lambda x: x.isnull().all()
    ).sum()
    fallback_summary[col] = lads_all_missing
fallback_df = pd.DataFrame.from_dict(
    fallback_summary, orient='index', columns=['LADs using national median']
)
fallback_df = fallback_df[fallback_df['LADs using national median'] > 0].sort_values(
    'LADs using national median', ascending=False
)
print(fallback_df)
print(f"\nTotal LADs in dataset: {X_clean['GEOGRAPHY_CODE'].nunique()}")
# Out:
#                                                     LADs using national median
# Modelled unemployment rate, aged 16 years and o...                          21
# Mean satisfaction with your life nowadays score...                          16
# Mean feeling things done in life are worthwhile...                          16
# Mean happiness yesterday scored 0 (not at all) ...                          16
# Mean anxiety yesterday scored 0 (not at all) - ...                          16
# Gross Value Added (GVA) per hour worked (£) [GV...                           9
# Percentage of 4G coverage by at least one mobil...                           9
# Percentage of premises with gigabit-capable bro...                           9
# Percentage of adults that currently smoke cigar...                           7
# Employment rate, aged 16 to 64 years (%) [Emplo...                           6
# Proportion of the population aged 16 to 64 with...                           6
# Count of births of new enterprises (control rou...                           4
# Count of high growth enterprises (control round...                           4
# Count of deaths of enterprises (control rounded...                           4
# Gross disposable household income, per head (£)...                           4
# Count of active enterprises (control rounded to...                           4
# Gross median weekly pay (£) [Weekly pay]                                     2
#
# Total LADs in dataset: 355

# %%
for col in indicators.columns:
    X_clean[col] = X_clean.groupby('GEOGRAPHY_CODE')[col].transform(
        lambda x: x.fillna(x.median())
    )
    X_clean[col] = X_clean[col].fillna(X_clean[col].median())  # fallback for any remaining missing with the national median

# %%
X = X_clean[indicators.columns].copy()
y_bus = X_clean['Business_growth_rate'].reset_index(drop=True)
y_emp = X_clean['Employment_growth_rate'].reset_index(drop=True)

# %%
# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=indicators.columns, 
                            index=X_clean.index)

# Sector dummies
is8_dummies     = pd.get_dummies(X_clean['IS8_SECTOR'], 
                                  prefix='IS8', drop_first=True)
frontier_dummies = pd.get_dummies(X_clean['FRONTIER_SECTOR'], 
                                   prefix='FS', drop_first=True)

# %%
##### LASSO — variable selection 
lasso_bus = LassoCV(cv=10, random_state=42, max_iter=10000).fit(X_scaled, y_bus)
lasso_emp = LassoCV(cv=10, random_state=42, max_iter=10000).fit(X_scaled, y_emp)

selected_bus = [col for col, coef in zip(indicators.columns, lasso_bus.coef_) if coef != 0]
selected_emp = [col for col, coef in zip(indicators.columns, lasso_emp.coef_) if coef != 0]

# LASSO coefficients summary
lasso_bus_df = pd.DataFrame({
    'Variable'   : indicators.columns,
    'Coefficient': lasso_bus.coef_
}).query('Coefficient != 0').sort_values('Coefficient', key=abs, ascending=False)

lasso_emp_df = pd.DataFrame({
    'Variable'   : indicators.columns,
    'Coefficient': lasso_emp.coef_
}).query('Coefficient != 0').sort_values('Coefficient', key=abs, ascending=False)

print(f"LASSO — Business growth selected {len(selected_bus)} variables:")
print(lasso_bus_df.to_string(index=False))

print(f"LASSO — Employment growth selected {len(selected_emp)} variables:")
print(lasso_emp_df.to_string(index=False))
# Out:
# LASSO — Business growth selected 10 variables:
#                                                                                          Variable  Coefficient
#                  Count of births of new enterprises (control rounded to base 5) [New enterprises]  1961.283188
#            Count of high growth enterprises (control rounded to base 5) [High growth enterprises]  1279.819401
#                Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]   222.026464
#                      Count of active enterprises (control rounded to base 5) [Active enterprises]   154.920547
#                                   Gross disposable household income, per head (£) [GDHI per head]    20.598192
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]    11.575714
#                                                          Gross median weekly pay (£) [Weekly pay]    10.921015
#                                        Gross Value Added (GVA) per hour worked (£) [GVA per hour]     3.284948
#                        Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]    -1.488358
#                Percentage of premises with gigabit-capable broadband (%) [Broadband availability]    -1.133158
# LASSO — Employment growth selected 9 variables:
#                                                                                          Variable  Coefficient
#            Count of high growth enterprises (control rounded to base 5) [High growth enterprises] 28180.417486
#                                   Gross disposable household income, per head (£) [GDHI per head]   820.410389
#                                                          Gross median weekly pay (£) [Weekly pay]  -235.450667
#                                        Gross Value Added (GVA) per hour worked (£) [GVA per hour]   191.847071
#                                Percentage of adults that currently smoke cigarettes (%) [Smokers]    41.478899
#                Percentage of premises with gigabit-capable broadband (%) [Broadband availability]    39.887763
#                        Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]    33.746220
#                      Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]   -31.411605
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]    -4.802974

# %%
# ── Sector dummies ────────────────────────────────────────────────
is8_dummies      = pd.get_dummies(X_clean['IS8_SECTOR'],      drop_first=True).astype(float)
frontier_dummies = pd.get_dummies(X_clean['FRONTIER_SECTOR'], drop_first=True).astype(float)

# %%
# ── Modelos CON estandarización ───────────────────────────────────
def run_ols_scaled(y, dummies, label):
    X_ols = pd.concat([
        X_scaled_df[indicators.columns].reset_index(drop=True),
        dummies.reset_index(drop=True)
    ], axis=1).astype(float)
    X_ols = sm.add_constant(X_ols)
    model = sm.OLS(y, X_ols).fit(cov_type='HC3')
    print(f"\n{'='*60}")
    print(f"MODEL (SCALED): {label}")
    print(model.summary())
    return model

# ── Modelos SIN estandarización ───────────────────────────────────
def run_ols_raw(y, dummies, label):
    X_ols = pd.concat([
        X_clean[indicators.columns].reset_index(drop=True),
        dummies.reset_index(drop=True)
    ], axis=1).astype(float)
    X_ols = sm.add_constant(X_ols)
    model = sm.OLS(y, X_ols).fit(cov_type='HC3')
    print(f"\n{'='*60}")
    print(f"MODEL (RAW): {label}")
    print(model.summary())
    return model

# %% [markdown]
# ### IS8 FIXED EFFECTS

# %% [markdown]
# Business outcome

# %%
print("IS8 with standarized local indicators")
m1_scaled = run_ols_scaled(y_bus, is8_dummies, "M1: Business Growth   + IS8 FE")
# Out:
# IS8 with standarized local indicators
#
# ============================================================
# MODEL (SCALED): M1: Business Growth   + IS8 FE
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Business_growth_rate   R-squared:                       0.253
# Model:                              OLS   Adj. R-squared:                  0.250
# Method:                   Least Squares   F-statistic:                     6.821
# Date:                  Sun, 15 Mar 2026   Prob (F-statistic):           1.38e-21
# Time:                          15:45:56   Log-Likelihood:                -61410.
# No. Observations:                  6035   AIC:                         1.229e+05
# Df Residuals:                      6011   BIC:                         1.230e+05
# Df Model:                            23
# Covariance Type:                    HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                    16.8380     94.754      0.178      0.859    -168.876     202.552
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                                3.9636     18.593      0.213      0.831     -32.479      40.406
# Gross median weekly pay (£) [Weekly pay]                                                                 14.5785     15.598      0.935      0.350     -15.994      45.151
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                                0.4539     50.572      0.009      0.993     -98.666      99.574
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               -0.3302    174.461     -0.002      0.998    -342.268     341.607
# Gross disposable household income, per head (£) [GDHI per head]                                          14.3415     61.300      0.234      0.815    -105.804     134.487
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                        362.7540   2.57e+04      0.014      0.989      -5e+04    5.07e+04
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                     1538.5020   4.43e+04      0.035      0.972   -8.52e+04    8.83e+04
# Count of active enterprises (control rounded to base 5) [Active enterprises]                              0.7924   6.19e+04   1.28e-05      1.000   -1.21e+05    1.21e+05
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                 1719.6717   6152.712      0.279      0.780   -1.03e+04    1.38e+04
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       -6.9944     95.100     -0.074      0.941    -193.388     179.399
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                  1.7020     10.833      0.157      0.875     -19.530      22.934
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        12.9360     17.414      0.743      0.458     -21.195      47.067
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       -0.6279     27.973     -0.022      0.982     -55.454      54.198
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    -0.1328     25.434     -0.005      0.996     -49.982      49.716
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     -2.1807     14.939     -0.146      0.884     -31.462      27.100
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                              0.0524     14.517      0.004      0.997     -28.400      28.505
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                  2.1633     26.500      0.082      0.935     -49.776      54.103
# Creative Industries                                                                                     243.1549    108.304      2.245      0.025      30.882     455.428
# Defence sector                                                                                          -15.4296    218.148     -0.071      0.944    -442.993     412.134
# Digital and Technology                                                                                 3259.9366   1209.364      2.696      0.007     889.626    5630.247
# Financial Services                                                                                      248.6127    112.435      2.211      0.027      28.243     468.982
# Life Sciences                                                                                            30.5563    199.916      0.153      0.879    -361.272     422.385
# Professional and Business Services                                                                      842.7817    202.939      4.153      0.000     445.028    1240.536
# ==============================================================================
# Omnibus:                    15348.248   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        278907765.728
# Skew:                          28.266   Prob(JB):                         0.00
# Kurtosis:                    1054.649   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
print("IS8 without standarized local indicators")
m1_raw    = run_ols_raw   (y_bus, is8_dummies, "M1: Business Growth   + IS8 FE")
# Out:
# IS8 without standarized local indicators
# ============================================================
# MODEL (RAW): M1: Business Growth   + IS8 FE
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Business_growth_rate   R-squared:                       0.253
# Model:                              OLS   Adj. R-squared:                  0.250
# Method:                   Least Squares   F-statistic:                     6.821
# Date:                  Sun, 15 Mar 2026   Prob (F-statistic):           1.38e-21
# Time:                          15:45:56   Log-Likelihood:                -61410.
# No. Observations:                  6035   AIC:                         1.229e+05
# Df Residuals:                      6011   BIC:                         1.230e+05
# Df Model:                            23
# Covariance Type:                    HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                  -674.8220    919.283     -0.734      0.463   -2476.583    1126.939
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                                0.4787      2.245      0.213      0.831      -3.922       4.880
# Gross median weekly pay (£) [Weekly pay]                                                                  0.2162      0.231      0.935      0.350      -0.237       0.670
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                                0.0790      8.801      0.009      0.993     -17.171      17.329
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               -0.3285    173.557     -0.002      0.998    -340.493     339.836
# Gross disposable household income, per head (£) [GDHI per head]                                           0.0013      0.005      0.234      0.815      -0.009       0.012
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                          0.0126      0.892      0.014      0.989      -1.735       1.760
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                        0.0521      1.499      0.035      0.972      -2.885       2.989
# Count of active enterprises (control rounded to base 5) [Active enterprises]                           3.199e-06      0.250   1.28e-05      1.000      -0.490       0.490
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                    1.7603      6.298      0.279      0.780     -10.584      14.104
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       -0.3819      5.192     -0.074      0.941     -10.559       9.795
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                  0.4855      3.090      0.157      0.875      -5.571       6.543
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]         1.4784      1.990      0.743      0.458      -2.422       5.379
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       -0.1634      7.279     -0.022      0.982     -14.430      14.103
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    -0.5398    103.349     -0.005      0.996    -203.101     202.021
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     -8.9761     61.493     -0.146      0.884    -129.500     111.548
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                              0.2033     56.299      0.004      0.997    -110.140     110.546
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                  5.4539     66.811      0.082      0.935    -125.494     136.402
# Creative Industries                                                                                     243.1549    108.304      2.245      0.025      30.882     455.428
# Defence sector                                                                                          -15.4296    218.148     -0.071      0.944    -442.993     412.134
# Digital and Technology                                                                                 3259.9366   1209.364      2.696      0.007     889.626    5630.247
# Financial Services                                                                                      248.6127    112.435      2.211      0.027      28.243     468.982
# Life Sciences                                                                                            30.5563    199.916      0.153      0.879    -361.272     422.385
# Professional and Business Services                                                                      842.7817    202.939      4.153      0.000     445.028    1240.536
# ==============================================================================
# Omnibus:                    15348.248   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        278907765.728
# Skew:                          28.266   Prob(JB):                         0.00
# Kurtosis:                    1054.649   Cond. No.                     1.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Employment outcome

# %%
#With standarizaed local indicators
m2_scaled = run_ols_scaled(y_emp, is8_dummies, "M2: Employment Growth + IS8 FE")
# Out:
# ============================================================
# MODEL (SCALED): M2: Employment Growth + IS8 FE
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Employment_growth_rate   R-squared:                       0.295
# Model:                                OLS   Adj. R-squared:                  0.292
# Method:                     Least Squares   F-statistic:                     11.13
# Date:                    Sun, 15 Mar 2026   Prob (F-statistic):           2.88e-40
# Time:                            15:45:56   Log-Likelihood:                -73160.
# No. Observations:                    6035   AIC:                         1.464e+05
# Df Residuals:                        6011   BIC:                         1.465e+05
# Df Model:                              23
# Covariance Type:                      HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                   663.9930    642.498      1.033      0.301    -595.280    1923.266
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                              211.2011    139.801      1.511      0.131     -62.803     485.205
# Gross median weekly pay (£) [Weekly pay]                                                               -240.3826    213.697     -1.125      0.261    -659.220     178.455
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                              113.6692    360.166      0.316      0.752    -592.243     819.582
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                              151.0727   1226.098      0.123      0.902   -2252.035    2554.181
# Gross disposable household income, per head (£) [GDHI per head]                                         627.6812    623.162      1.007      0.314    -593.693    1849.056
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                      -4202.1830    1.8e+05     -0.023      0.981   -3.57e+05    3.48e+05
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                     9713.2997    3.1e+05      0.031      0.975   -5.98e+05    6.17e+05
# Count of active enterprises (control rounded to base 5) [Active enterprises]                          -1.994e+04   4.35e+05     -0.046      0.963   -8.73e+05    8.33e+05
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                 4.264e+04   4.35e+04      0.981      0.326   -4.25e+04    1.28e+05
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       82.2177    669.863      0.123      0.902   -1230.689    1395.124
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                -83.1145     87.887     -0.946      0.344    -255.370      89.141
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]       -53.9912    145.044     -0.372      0.710    -338.272     230.290
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       14.7230    200.480      0.073      0.941    -378.210     407.656
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    72.6774    185.913      0.391      0.696    -291.705     437.059
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     14.6675    112.681      0.130      0.896    -206.184     235.519
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                            -85.4667    114.104     -0.749      0.454    -309.106     138.173
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                -20.2549    189.790     -0.107      0.915    -392.237     351.727
# Creative Industries                                                                                     636.1655    819.302      0.776      0.437    -969.637    2241.968
# Defence sector                                                                                         -478.6972   1595.754     -0.300      0.764   -3606.317    2648.923
# Digital and Technology                                                                                  2.44e+04   9135.734      2.670      0.008    6489.411    4.23e+04
# Financial Services                                                                                     3602.2277    767.892      4.691      0.000    2097.186    5107.269
# Life Sciences                                                                                           528.3310   1226.323      0.431      0.667   -1875.218    2931.880
# Professional and Business Services                                                                     4085.3075    747.462      5.466      0.000    2620.309    5550.306
# ==============================================================================
# Omnibus:                    16259.101   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        470148647.257
# Skew:                          32.689   Prob(JB):                         0.00
# Kurtosis:                    1368.802   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
#Without standarised local indicators
m2_raw    = run_ols_raw   (y_emp, is8_dummies, "M2: Employment Growth + IS8 FE")
# Out:
# ============================================================
# MODEL (RAW): M2: Employment Growth + IS8 FE
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Employment_growth_rate   R-squared:                       0.295
# Model:                                OLS   Adj. R-squared:                  0.292
# Method:                     Least Squares   F-statistic:                     11.13
# Date:                    Sun, 15 Mar 2026   Prob (F-statistic):           2.88e-40
# Time:                            15:45:56   Log-Likelihood:                -73160.
# No. Observations:                    6035   AIC:                         1.464e+05
# Df Residuals:                        6011   BIC:                         1.465e+05
# Df Model:                              23
# Covariance Type:                      HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                 -2802.3255   6715.504     -0.417      0.676    -1.6e+04    1.04e+04
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                               25.5059     16.883      1.511      0.131      -7.584      58.596
# Gross median weekly pay (£) [Weekly pay]                                                                 -3.5654      3.170     -1.125      0.261      -9.778       2.647
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                               19.7825     62.682      0.316      0.752    -103.072     142.637
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                              150.2896   1219.742      0.123      0.902   -2240.361    2540.940
# Gross disposable household income, per head (£) [GDHI per head]                                           0.0559      0.056      1.007      0.314      -0.053       0.165
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                         -0.1459      6.249     -0.023      0.981     -12.395      12.103
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                        0.3287     10.488      0.031      0.975     -20.227      20.885
# Count of active enterprises (control rounded to base 5) [Active enterprises]                             -0.0805      1.756     -0.046      0.963      -3.523       3.362
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                   43.6481     44.480      0.981      0.326     -43.532     130.828
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                        4.4889     36.573      0.123      0.902     -67.193      76.171
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                -23.7107     25.072     -0.946      0.344     -72.851      25.430
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        -6.1703     16.576     -0.372      0.710     -38.659      26.318
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                        3.8311     52.167      0.073      0.941     -98.415     106.077
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]   295.3228    755.451      0.391      0.696   -1185.334    1775.980
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     60.3736    463.812      0.130      0.896    -848.680     969.427
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                           -331.4546    442.514     -0.749      0.454   -1198.767     535.858
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                -51.0659    478.492     -0.107      0.915    -988.894     886.762
# Creative Industries                                                                                     636.1655    819.302      0.776      0.437    -969.637    2241.968
# Defence sector                                                                                         -478.6972   1595.754     -0.300      0.764   -3606.317    2648.923
# Digital and Technology                                                                                  2.44e+04   9135.734      2.670      0.008    6489.411    4.23e+04
# Financial Services                                                                                     3602.2277    767.892      4.691      0.000    2097.186    5107.269
# Life Sciences                                                                                           528.3310   1226.323      0.431      0.667   -1875.218    2931.880
# Professional and Business Services                                                                     4085.3075    747.462      5.466      0.000    2620.309    5550.306
# ==============================================================================
# Omnibus:                    16259.101   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        470148647.257
# Skew:                          32.689   Prob(JB):                         0.00
# Kurtosis:                    1368.802   Cond. No.                     1.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## FRONTIER SECTOR FIXED EFFECTS

# %% [markdown]
# Business outcome

# %%
# With standarised local indicators
m3_scaled = run_ols_scaled(y_bus, frontier_dummies, "M3: Business Growth   + Frontier FE")
# Out:
# ============================================================
# MODEL (SCALED): M3: Business Growth   + Frontier FE
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Business_growth_rate   R-squared:                       0.255
# Model:                              OLS   Adj. R-squared:                  0.251
# Method:                   Least Squares   F-statistic:                     31.21
# Date:                  Sun, 15 Mar 2026   Prob (F-statistic):          7.68e-179
# Time:                          15:45:56   Log-Likelihood:                -61405.
# No. Observations:                  6035   AIC:                         1.229e+05
# Df Residuals:                      6001   BIC:                         1.231e+05
# Df Model:                            33
# Covariance Type:                    HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                   478.4366      9.047     52.885      0.000     460.705     496.168
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                                3.9636     18.753      0.211      0.833     -32.791      40.718
# Gross median weekly pay (£) [Weekly pay]                                                                 14.5785     15.738      0.926      0.354     -16.267      45.424
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                                0.4539     50.676      0.009      0.993     -98.868      99.776
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               -0.3302    174.363     -0.002      0.998    -342.076     341.415
# Gross disposable household income, per head (£) [GDHI per head]                                          14.3415     61.231      0.234      0.815    -105.669     134.352
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                        362.7540   2.57e+04      0.014      0.989   -4.99e+04    5.06e+04
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                     1538.5020   4.42e+04      0.035      0.972   -8.52e+04    8.83e+04
# Count of active enterprises (control rounded to base 5) [Active enterprises]                              0.7924   6.19e+04   1.28e-05      1.000   -1.21e+05    1.21e+05
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                 1719.6717   6143.136      0.280      0.780   -1.03e+04    1.38e+04
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       -6.9944     95.096     -0.074      0.941    -193.379     179.390
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                  1.7020     11.395      0.149      0.881     -20.632      24.036
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        12.9360     17.713      0.730      0.465     -21.780      47.652
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       -0.6279     28.125     -0.022      0.982     -55.751      54.496
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    -0.1328     25.831     -0.005      0.996     -50.761      50.495
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     -2.1807     15.524     -0.140      0.888     -32.607      28.246
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                              0.0524     15.104      0.003      0.997     -29.551      29.656
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                  2.1633     26.699      0.081      0.935     -50.167      54.493
# Advertising and marketing                                                                              -183.1831     69.898     -2.621      0.009    -320.180     -46.186
# Aerospace manufacturing                                                                                -458.6197    188.519     -2.433      0.015    -828.109     -89.130
# Agritech                                                                                               -473.0986    194.969     -2.427      0.015    -855.231     -90.966
# Asset management and wholesale services                                                                 -41.9155     15.819     -2.650      0.008     -72.921     -10.910
# Automotive manufacturing                                                                               -436.9718    179.478     -2.435      0.015    -788.742     -85.201
# Batteries                                                                                              -477.7042    197.069     -2.424      0.015    -863.953     -91.456
# Capital markets and retail investment                                                                  -192.0704     74.741     -2.570      0.010    -338.560     -45.581
# Defence Sector                                                                                         -477.0282    196.704     -2.425      0.015    -862.560     -91.496
# Digital and Technology                                                                                 2798.3380   1205.681      2.321      0.020     435.247    5161.429
# Film and TV                                                                                            -163.3662     61.897     -2.639      0.008    -284.683     -42.049
# Insurance and reinsurance markets                                                                      -404.9718    165.243     -2.451      0.014    -728.843     -81.101
# Legal services                                                                                          -83.5211     32.781     -2.548      0.011    -147.770     -19.272
# Life Sciences                                                                                          -431.0423    176.267     -2.445      0.014    -776.519     -85.566
# Management consultancy                                                                                 1227.0704    535.467      2.292      0.022     177.575    2276.566
# Music, peforming, and visual arts                                                                       -72.3239     24.668     -2.932      0.003    -120.672     -23.975
# Video games                                                                                            -454.9014    187.004     -2.433      0.015    -821.422     -88.381
# ==============================================================================
# Omnibus:                    15353.427   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        280228580.060
# Skew:                          28.289   Prob(JB):                         0.00
# Kurtosis:                    1057.141   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
# Without standarised local indicators
m3_raw    = run_ols_raw   (y_bus, frontier_dummies, "M3: Business Growth   + Frontier FE")
# Out:
# ============================================================
# MODEL (RAW): M3: Business Growth   + Frontier FE
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Business_growth_rate   R-squared:                       0.255
# Model:                              OLS   Adj. R-squared:                  0.251
# Method:                   Least Squares   F-statistic:                     31.21
# Date:                  Sun, 15 Mar 2026   Prob (F-statistic):          7.70e-179
# Time:                          15:45:56   Log-Likelihood:                -61405.
# No. Observations:                  6035   AIC:                         1.229e+05
# Df Residuals:                      6001   BIC:                         1.231e+05
# Df Model:                            33
# Covariance Type:                    HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                  -213.2234    930.688     -0.229      0.819   -2037.338    1610.891
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                                0.4787      2.265      0.211      0.833      -3.960       4.917
# Gross median weekly pay (£) [Weekly pay]                                                                  0.2162      0.233      0.926      0.354      -0.241       0.674
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                                0.0790      8.819      0.009      0.993     -17.207      17.365
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                               -0.3285    173.459     -0.002      0.998    -340.302     339.645
# Gross disposable household income, per head (£) [GDHI per head]                                           0.0013      0.005      0.234      0.815      -0.009       0.012
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                          0.0126      0.891      0.014      0.989      -1.733       1.759
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                        0.0521      1.497      0.035      0.972      -2.883       2.987
# Count of active enterprises (control rounded to base 5) [Active enterprises]                           3.199e-06      0.250   1.28e-05      1.000      -0.490       0.490
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                    1.7603      6.288      0.280      0.780     -10.564      14.085
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       -0.3819      5.192     -0.074      0.941     -10.558       9.794
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                  0.4855      3.251      0.149      0.881      -5.886       6.857
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]         1.4784      2.024      0.730      0.465      -2.489       5.446
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       -0.1634      7.318     -0.022      0.982     -14.507      14.180
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    -0.5398    104.965     -0.005      0.996    -206.267     205.187
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     -8.9761     63.899     -0.140      0.888    -134.215     116.263
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                              0.2033     58.577      0.003      0.997    -114.606     115.012
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                  5.4539     67.314      0.081      0.935    -126.478     137.386
# Advertising and marketing                                                                              -183.1831     69.898     -2.621      0.009    -320.180     -46.186
# Aerospace manufacturing                                                                                -458.6197    188.519     -2.433      0.015    -828.109     -89.130
# Agritech                                                                                               -473.0986    194.969     -2.427      0.015    -855.231     -90.966
# Asset management and wholesale services                                                                 -41.9155     15.819     -2.650      0.008     -72.921     -10.910
# Automotive manufacturing                                                                               -436.9718    179.478     -2.435      0.015    -788.742     -85.201
# Batteries                                                                                              -477.7042    197.069     -2.424      0.015    -863.953     -91.456
# Capital markets and retail investment                                                                  -192.0704     74.741     -2.570      0.010    -338.560     -45.581
# Defence Sector                                                                                         -477.0282    196.704     -2.425      0.015    -862.560     -91.496
# Digital and Technology                                                                                 2798.3380   1205.681      2.321      0.020     435.247    5161.429
# Film and TV                                                                                            -163.3662     61.897     -2.639      0.008    -284.683     -42.049
# Insurance and reinsurance markets                                                                      -404.9718    165.243     -2.451      0.014    -728.843     -81.101
# Legal services                                                                                          -83.5211     32.781     -2.548      0.011    -147.770     -19.272
# Life Sciences                                                                                          -431.0423    176.267     -2.445      0.014    -776.519     -85.566
# Management consultancy                                                                                 1227.0704    535.467      2.292      0.022     177.575    2276.566
# Music, peforming, and visual arts                                                                       -72.3239     24.668     -2.932      0.003    -120.672     -23.975
# Video games                                                                                            -454.9014    187.004     -2.433      0.015    -821.422     -88.381
# ==============================================================================
# Omnibus:                    15353.427   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        280228580.060
# Skew:                          28.289   Prob(JB):                         0.00
# Kurtosis:                    1057.141   Cond. No.                     1.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Employment outcome

# %%
m4_scaled = run_ols_scaled(y_emp, frontier_dummies, "M4: Employment Growth + Frontier FE")
# Out:
# ============================================================
# MODEL (SCALED): M4: Employment Growth + Frontier FE
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Employment_growth_rate   R-squared:                       0.295
# Model:                                OLS   Adj. R-squared:                  0.291
# Method:                     Least Squares   F-statistic:                     21.08
# Date:                    Sun, 15 Mar 2026   Prob (F-statistic):          1.10e-117
# Time:                            15:45:57   Log-Likelihood:                -73159.
# No. Observations:                    6035   AIC:                         1.464e+05
# Df Residuals:                        6001   BIC:                         1.466e+05
# Df Model:                              33
# Covariance Type:                      HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                  4982.1408    611.919      8.142      0.000    3782.801    6181.481
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                              211.2011    140.119      1.507      0.132     -63.427     485.829
# Gross median weekly pay (£) [Weekly pay]                                                               -240.3826    213.050     -1.128      0.259    -657.954     177.189
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                              113.6692    360.391      0.315      0.752    -592.684     820.022
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                              151.0727   1226.174      0.123      0.902   -2252.184    2554.329
# Gross disposable household income, per head (£) [GDHI per head]                                         627.6812    621.639      1.010      0.313    -590.709    1846.071
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                      -4202.1830    1.8e+05     -0.023      0.981   -3.57e+05    3.48e+05
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                     9713.2997    3.1e+05      0.031      0.975   -5.98e+05    6.17e+05
# Count of active enterprises (control rounded to base 5) [Active enterprises]                          -1.994e+04   4.35e+05     -0.046      0.963   -8.73e+05    8.33e+05
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                 4.264e+04   4.34e+04      0.982      0.326   -4.25e+04    1.28e+05
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                       82.2177    669.967      0.123      0.902   -1230.894    1395.329
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                -83.1145     88.685     -0.937      0.349    -256.934      90.705
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]       -53.9912    145.339     -0.371      0.710    -338.851     230.869
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                       14.7230    200.763      0.073      0.942    -378.765     408.211
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]    72.6774    186.605      0.389      0.697    -293.062     438.417
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     14.6675    113.685      0.129      0.897    -208.151     237.486
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                            -85.4667    114.927     -0.744      0.457    -310.719     139.785
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                -20.2549    190.145     -0.107      0.915    -392.931     352.422
# Advertising and marketing                                                                             -3140.0986    959.449     -3.273      0.001   -5020.584   -1259.613
# Aerospace manufacturing                                                                               -3966.0423   1275.290     -3.110      0.002   -6465.564   -1466.520
# Agritech                                                                                              -4897.3380   1621.701     -3.020      0.003   -8075.814   -1718.862
# Asset management and wholesale services                                                                 897.0563   1181.755      0.759      0.448   -1419.142    3213.254
# Automotive manufacturing                                                                              -3452.3239   1077.082     -3.205      0.001   -5563.366   -1341.282
# Batteries                                                                                             -4956.8873   1646.223     -3.011      0.003   -8183.424   -1730.350
# Capital markets and retail investment                                                                  -355.4930    780.702     -0.455      0.649   -1885.640    1174.654
# Defence Sector                                                                                        -4796.8451   1583.689     -3.029      0.002   -7900.819   -1692.871
# Digital and Technology                                                                                 2.008e+04   9133.634      2.198      0.028    2175.378     3.8e+04
# Film and TV                                                                                           -3200.9859    989.740     -3.234      0.001   -5140.841   -1261.131
# Insurance and reinsurance markets                                                                     -2689.3239    833.583     -3.226      0.001   -4323.116   -1055.532
# Legal services                                                                                        -1476.3662    620.056     -2.381      0.017   -2691.654    -261.078
# Life Sciences                                                                                         -3789.8169   1210.582     -3.131      0.002   -6162.515   -1417.119
# Management consultancy                                                                                  777.8451   1140.249      0.682      0.495   -1457.002    3012.692
# Music, peforming, and visual arts                                                                     -3678.6338   1163.779     -3.161      0.002   -5959.599   -1397.669
# Video games                                                                                           -4708.2113   1546.500     -3.044      0.002   -7739.296   -1677.127
# ==============================================================================
# Omnibus:                    16262.678   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        470821625.887
# Skew:                          32.708   Prob(JB):                         0.00
# Kurtosis:                    1369.779   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
m4_raw    = run_ols_raw   (y_emp, frontier_dummies, "M4: Employment Growth + Frontier FE")
# Out:
# ============================================================
# MODEL (RAW): M4: Employment Growth + Frontier FE
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Employment_growth_rate   R-squared:                       0.295
# Model:                                OLS   Adj. R-squared:                  0.291
# Method:                     Least Squares   F-statistic:                     21.08
# Date:                    Sun, 15 Mar 2026   Prob (F-statistic):          1.11e-117
# Time:                            15:45:57   Log-Likelihood:                -73159.
# No. Observations:                    6035   AIC:                         1.464e+05
# Df Residuals:                        6001   BIC:                         1.466e+05
# Df Model:                              33
# Covariance Type:                      HC3
# =========================================================================================================================================================================
#                                                                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                                  1515.8223   6748.280      0.225      0.822   -1.17e+04    1.47e+04
# Gross Value Added (GVA) per hour worked (£) [GVA per hour]                                               25.5059     16.922      1.507      0.132      -7.660      58.672
# Gross median weekly pay (£) [Weekly pay]                                                                 -3.5654      3.160     -1.128      0.259      -9.759       2.628
# Employment rate, aged 16 to 64 years (%) [Employment rate]                                               19.7825     62.721      0.315      0.752    -103.148     142.713
# Modelled unemployment rate, aged 16 years and over (%) [Unemployment rate]                              150.2896   1219.818      0.123      0.902   -2240.509    2541.088
# Gross disposable household income, per head (£) [GDHI per head]                                           0.0559      0.055      1.010      0.313      -0.053       0.164
# Count of births of new enterprises (control rounded to base 5) [New enterprises]                         -0.1459      6.249     -0.023      0.981     -12.394      12.103
# Count of deaths of enterprises (control rounded to base 5) [Deaths of enterprises]                        0.3287     10.488      0.031      0.975     -20.227      20.885
# Count of active enterprises (control rounded to base 5) [Active enterprises]                             -0.0805      1.756     -0.046      0.963      -3.523       3.362
# Count of high growth enterprises (control rounded to base 5) [High growth enterprises]                   43.6481     44.463      0.982      0.326     -43.497     130.793
# Percentage of premises with gigabit-capable broadband (%) [Broadband availability]                        4.4889     36.579      0.123      0.902     -67.204      76.182
# Percentage of 4G coverage by at least one mobile network operator (%) [4G area coverage]                -23.7107     25.300     -0.937      0.349     -73.298      25.876
# Proportion of the population aged 16 to 64 with NVQ3+ qualification (%) [Level 3+ qualifications]        -6.1703     16.610     -0.371      0.710     -38.725      26.385
# Percentage of adults that currently smoke cigarettes (%) [Smokers]                                        3.8311     52.241      0.073      0.942     -98.559     106.221
# Mean satisfaction with your life nowadays scored 0 (not at all) - 10 (completely) [Life satisfaction]   295.3228    758.265      0.389      0.697   -1190.850    1781.495
# Mean feeling things done in life are worthwhile scored 0 (not at all) - 10 (completely) [Worthwhile]     60.3736    467.943      0.129      0.897    -856.778     977.525
# Mean happiness yesterday scored 0 (not at all) - 10 (completely) [Happiness]                           -331.4546    445.705     -0.744      0.457   -1205.021     542.112
# Mean anxiety yesterday scored 0 (not at all) - 10 (completely) [Anxiety]                                -51.0659    479.386     -0.107      0.915    -990.645     888.513
# Advertising and marketing                                                                             -3140.0986    959.449     -3.273      0.001   -5020.584   -1259.613
# Aerospace manufacturing                                                                               -3966.0423   1275.290     -3.110      0.002   -6465.564   -1466.520
# Agritech                                                                                              -4897.3380   1621.701     -3.020      0.003   -8075.814   -1718.862
# Asset management and wholesale services                                                                 897.0563   1181.755      0.759      0.448   -1419.142    3213.254
# Automotive manufacturing                                                                              -3452.3239   1077.082     -3.205      0.001   -5563.366   -1341.282
# Batteries                                                                                             -4956.8873   1646.223     -3.011      0.003   -8183.424   -1730.350
# Capital markets and retail investment                                                                  -355.4930    780.702     -0.455      0.649   -1885.640    1174.654
# Defence Sector                                                                                        -4796.8451   1583.689     -3.029      0.002   -7900.819   -1692.871
# Digital and Technology                                                                                 2.008e+04   9133.634      2.198      0.028    2175.378     3.8e+04
# Film and TV                                                                                           -3200.9859    989.740     -3.234      0.001   -5140.841   -1261.131
# Insurance and reinsurance markets                                                                     -2689.3239    833.583     -3.226      0.001   -4323.116   -1055.532
# Legal services                                                                                        -1476.3662    620.056     -2.381      0.017   -2691.654    -261.078
# Life Sciences                                                                                         -3789.8169   1210.582     -3.131      0.002   -6162.515   -1417.119
# Management consultancy                                                                                  777.8451   1140.249      0.682      0.495   -1457.002    3012.692
# Music, peforming, and visual arts                                                                     -3678.6338   1163.779     -3.161      0.002   -5959.599   -1397.669
# Video games                                                                                           -4708.2113   1546.500     -3.044      0.002   -7739.296   -1677.127
# ==============================================================================
# Omnibus:                    16262.678   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        470821625.887
# Skew:                          32.708   Prob(JB):                         0.00
# Kurtosis:                    1369.779   Cond. No.                     1.55e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.55e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
