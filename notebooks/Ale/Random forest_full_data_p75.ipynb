# %% [markdown]
# ## Random Forest

# %%
pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (2025.12.0)
# Requirement already satisfied: pandas>=1.5.0 in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from fastparquet) (3.0.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from fastparquet) (2.4.2)
# Requirement already satisfied: cramjam>=2.3 in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from fastparquet) (2026.2.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from fastparquet) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pp422/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score, mean_squared_error, classification_report
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from pathlib import Path

root = next(p for p in Path.cwd().parents if (p / "config.yml").exists())

panel = pd.read_parquet(
    root / "data/processed_data/analysis_panel.parquet", engine='fastparquet'
)
print(panel.shape)
print(panel.dtypes)
panel.head(20)
# Out:
# (16576, 35)
# YEAR                              int16
# GEOGRAPHY_CODE                 category
# GEOGRAPHY_NAME                 category
# IS8_SECTOR                     category
# EMPLOYEES                       float32
# BUSINESSES                      float32
# unemployment_rate               float64
# transport_to_employer           float64
# drive_to_employer               float64
# cycle_to_employer               float64
# broadband                       float64
# coverage_4g                     float64
# gcse_age19                      float64
# apprenticeship_starts           float64
# apprenticeship_achievements     float64
# nvq_level3                      float64
# fe_participation                float64
# housing_net_additions           float64
# enterprise_birth_rate           float64
# enterprise_death_rate           float64
# enterprise_high_growth_rate     float64
# REGION                           object
# COUNTY_UA                        object
# n_universities_feecap_lad         int64
# lq_bus                          float64
# emp_share                       float64
# lq_emp                          float64
# gd_emp                          float64
# gd_bus                          float64
# n_years_emp                       int64
# n_years_bus                       int64
# related_variety                 float64
# within_sector_diversity         float64
# size_large_share                float64
# size_micro_share                float64
# dtype: object
#     YEAR GEOGRAPHY_CODE        GEOGRAPHY_NAME  \
# 0   2016      E06000001            Hartlepool
# 1   2016      E06000001            Hartlepool
# 2   2016      E06000001            Hartlepool
# 3   2016      E06000001            Hartlepool
# 4   2016      E06000001            Hartlepool
# 5   2016      E06000001            Hartlepool
# 6   2016      E06000001            Hartlepool
# 7   2016      E06000002         Middlesbrough
# 8   2016      E06000002         Middlesbrough
# 9   2016      E06000002         Middlesbrough
# 10  2016      E06000002         Middlesbrough
# 11  2016      E06000002         Middlesbrough
# 12  2016      E06000002         Middlesbrough
# 13  2016      E06000002         Middlesbrough
# 14  2016      E06000003  Redcar and Cleveland
# 15  2016      E06000003  Redcar and Cleveland
# 16  2016      E06000003  Redcar and Cleveland
# 17  2016      E06000003  Redcar and Cleveland
# 18  2016      E06000003  Redcar and Cleveland
# 19  2016      E06000003  Redcar and Cleveland
#
#                             IS8_SECTOR  EMPLOYEES  BUSINESSES  \
# 0               Advanced Manufacturing     1470.0        25.0
# 1                  Creative Industries      450.0       110.0
# 2                              Defence        0.0         0.0
# 3             Digital and Technologies     1510.0       440.0
# 4                   Financial Services      285.0        40.0
# 5                        Life Sciences       40.0         0.0
# 6   Professional and Business Services     2630.0       870.0
# 7               Advanced Manufacturing      620.0        25.0
# 8                  Creative Industries     1320.0       180.0
# 9                              Defence        0.0         0.0
# 10            Digital and Technologies     2600.0       565.0
# 11                  Financial Services     1645.0       115.0
# 12                       Life Sciences       10.0         0.0
# 13  Professional and Business Services     6925.0      1280.0
# 14              Advanced Manufacturing     1910.0        35.0
# 15                 Creative Industries      415.0       130.0
# 16                             Defence        0.0         0.0
# 17            Digital and Technologies     1865.0       560.0
# 18                  Financial Services      370.0        65.0
# 19                       Life Sciences       50.0         0.0
#
#     unemployment_rate  transport_to_employer  drive_to_employer  \
# 0                 4.6              12.900208           7.790802
# 1                 4.6              12.900208           7.790802
# 2                 4.6              12.900208           7.790802
# 3                 4.6              12.900208           7.790802
# 4                 4.6              12.900208           7.790802
# 5                 4.6              12.900208           7.790802
# 6                 4.6              12.900208           7.790802
# 7                 5.1              15.372879           8.457817
# 8                 5.1              15.372879           8.457817
# 9                 5.1              15.372879           8.457817
# 10                5.1              15.372879           8.457817
# 11                5.1              15.372879           8.457817
# 12                5.1              15.372879           8.457817
# 13                5.1              15.372879           8.457817
# 14                3.6              13.259369           8.066075
# 15                3.6              13.259369           8.066075
# 16                3.6              13.259369           8.066075
# 17                3.6              13.259369           8.066075
# 18                3.6              13.259369           8.066075
# 19                3.6              13.259369           8.066075
#
#     cycle_to_employer  ...  emp_share    lq_emp    gd_emp    gd_bus  \
# 0           10.070582  ...   0.048197  1.648198  0.001431 -0.112731
# 1           10.070582  ...   0.014754  0.281144  0.044382 -0.014263
# 2           10.070582  ...   0.000000  0.000000       NaN       NaN
# 3           10.070582  ...   0.049508  0.682440 -0.026657 -0.059004
# 4           10.070582  ...   0.009344  0.154102 -0.037470  0.047092
# 5           10.070582  ...   0.001311  0.473936 -0.073609       NaN
# 6           10.070582  ...   0.086230  0.461236 -0.005547 -0.041919
# 7           11.335077  ...   0.010622  0.363240  0.005820  0.054637
# 8           11.335077  ...   0.022614  0.430924  0.055147  0.014442
# 9           11.335077  ...   0.000000  0.000000       NaN       NaN
# 10          11.335077  ...   0.044543  0.614004 -0.014856 -0.026772
# 11          11.335077  ...   0.028182  0.464770 -0.055247 -0.034986
# 12          11.335077  ...   0.000171  0.061911 -0.083099       NaN
# 13          11.335077  ...   0.118640  0.634597 -0.004990 -0.012076
# 14          11.103287  ...   0.048172  1.647336 -0.088478  0.014272
# 15          11.103287  ...   0.010467  0.199444 -0.040143  0.009441
# 16          11.103287  ...   0.000000  0.000000       NaN       NaN
# 17          11.103287  ...   0.047037  0.648370 -0.060170 -0.072627
# 18          11.103287  ...   0.009332  0.153894 -0.068907 -0.020792
# 19          11.103287  ...   0.001261  0.455707  0.112675       NaN
#
#     n_years_emp  n_years_bus  related_variety  within_sector_diversity  \
# 0             8            8         1.032564                 1.332179
# 1             8            8         1.032564                 2.200516
# 2             0            0         1.032564                 0.000000
# 3             8            8         1.032564                 1.072313
# 4             8            8         1.032564                 1.213008
# 5             8            0         1.032564                 0.000000
# 6             8            8         1.032564                 1.830641
# 7             8            8         1.075517                 1.332179
# 8             8            8         1.075517                 2.328951
# 9             0            0         1.075517                 0.000000
# 10            8            8         1.075517                 1.376962
# 11            8            8         1.075517                 1.481863
# 12            8            0         1.075517                 0.000000
# 13            8            8         1.075517                 2.055287
# 14            8            8         1.046638                 1.277034
# 15            8            8         1.046638                 2.140633
# 16            0            0         1.046638                 0.000000
# 17            8            8         1.046638                 1.093751
# 18            8            8         1.046638                 1.230932
# 19            8            0         1.046638                 0.000000
#
#     size_large_share  size_micro_share
# 0           0.000000          1.000000
# 1           0.000000          1.000000
# 2                NaN               NaN
# 3           0.000000          1.000000
# 4           0.000000          0.750000
# 5                NaN               NaN
# 6           0.000000          0.965517
# 7           0.000000          0.800000
# 8           0.000000          1.000000
# 9                NaN               NaN
# 10          0.000000          0.973451
# 11          0.000000          0.782609
# 12               NaN               NaN
# 13          0.007812          0.929688
# 14          0.000000          0.714286
# 15          0.000000          1.000000
# 16               NaN               NaN
# 17          0.000000          0.955357
# 18          0.000000          0.692308
# 19               NaN               NaN
#
# [20 rows x 35 columns]

# %%
panel.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16576 entries, 0 to 16575
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   YEAR                         16576 non-null  int16
#  1   GEOGRAPHY_CODE               16576 non-null  category
#  2   GEOGRAPHY_NAME               16576 non-null  category
#  3   IS8_SECTOR                   16576 non-null  category
#  4   EMPLOYEES                    16576 non-null  float32
#  5   BUSINESSES                   16576 non-null  float32
#  6   unemployment_rate            15624 non-null  float64
#  7   transport_to_employer        16520 non-null  float64
#  8   drive_to_employer            16520 non-null  float64
#  9   cycle_to_employer            16520 non-null  float64
#  10  broadband                    16576 non-null  float64
#  11  coverage_4g                  16576 non-null  float64
#  12  gcse_age19                   16520 non-null  float64
#  13  apprenticeship_starts        16576 non-null  float64
#  14  apprenticeship_achievements  16520 non-null  float64
#  15  nvq_level3                   16464 non-null  float64
#  16  fe_participation             16576 non-null  float64
#  17  housing_net_additions        16576 non-null  float64
#  18  enterprise_birth_rate        16576 non-null  float64
#  19  enterprise_death_rate        16576 non-null  float64
#  20  enterprise_high_growth_rate  16576 non-null  float64
#  21  REGION                       16576 non-null  object
#  22  COUNTY_UA                    16576 non-null  object
#  23  lq_bus                       16576 non-null  float64
#  24  emp_share                    16576 non-null  float64
#  25  lq_emp                       16576 non-null  float64
#  26  gd_emp                       14424 non-null  float64
#  27  gd_bus                       13704 non-null  float64
#  28  n_years_emp                  16576 non-null  int64
#  29  n_years_bus                  16576 non-null  int64
#  30  related_variety              16576 non-null  float64
#  31  within_sector_diversity      16576 non-null  float64
#  32  size_large_share             13601 non-null  float64
#  33  size_micro_share             13601 non-null  float64
# dtypes: category(3), float32(2), float64(24), int16(1), int64(2), object(2)
# memory usage: 3.8+ MB

# %%
# ─────────────────────────────────────────────
# 1. CARGAR DATOS
# ─────────────────────────────────────────────
root = next(p for p in Path.cwd().parents if (p / "config.yml").exists())

df = pd.read_parquet(
    root / "data/processed_data/analysis_panel.parquet", engine='fastparquet'
)
print(df.shape)
print(df.dtypes)
df.head(20)

# Filtrar solo 2023
df = df[df["YEAR"] == 2023].copy()
print(f"Shape filtrado (2023): {df.shape}")
print("Sectores IS8:", df["IS8_SECTOR"].unique())

# Dropear missings en cagr_bus
#print(f"Missings en cagr_bus: {df['cagr_bus'].isna().sum()}")
#df = df.dropna(subset=["cagr_bus"])
#print(f"Shape final: {df.shape}")
# Out:
# (16576, 35)
# YEAR                              int16
# GEOGRAPHY_CODE                 category
# GEOGRAPHY_NAME                 category
# IS8_SECTOR                     category
# EMPLOYEES                       float32
# BUSINESSES                      float32
# unemployment_rate               float64
# transport_to_employer           float64
# drive_to_employer               float64
# cycle_to_employer               float64
# broadband                       float64
# coverage_4g                     float64
# gcse_age19                      float64
# apprenticeship_starts           float64
# apprenticeship_achievements     float64
# nvq_level3                      float64
# fe_participation                float64
# housing_net_additions           float64
# enterprise_birth_rate           float64
# enterprise_death_rate           float64
# enterprise_high_growth_rate     float64
# REGION                           object
# COUNTY_UA                        object
# n_universities_feecap_lad         int64
# lq_bus                          float64
# emp_share                       float64
# lq_emp                          float64
# gd_emp                          float64
# gd_bus                          float64
# n_years_emp                       int64
# n_years_bus                       int64
# related_variety                 float64
# within_sector_diversity         float64
# size_large_share                float64
# size_micro_share                float64
# dtype: object
# Shape filtrado (2023): (2072, 35)
# Sectores IS8: ['Advanced Manufacturing', 'Creative Industries', 'Defence', 'Digital and Technologies', 'Financial Services', 'Life Sciences', 'Professional and Business Services']
# Categories (7, str): ['Advanced Manufacturing', 'Creative Industries', 'Defence', 'Digital and Technologies', 'Financial Services', 'Life Sciences', 'Professional and Business Services']

# %%
# ─────────────────────────────────────────────
# DEFINIR LOS DOS GRUPOS DE FEATURES
# ─────────────────────────────────────────────
features_full = [
   # Entrepreneurial discovery
    "enterprise_birth_rate",
    "enterprise_death_rate",
    "enterprise_high_growth_rate",
    # Connectivity
    "broadband",
    "coverage_4g",
    "transport_to_employer",
    "drive_to_employer",
    "cycle_to_employer",
    # Human capital
    "nvq_level3",
    "gcse_age19",
    "apprenticeship_starts",
    "apprenticeship_achievements",
    "fe_participation",
    # Labour market
    "unemployment_rate",
    # Place conditions
    "housing_net_additions",
    "size_large_share",
    "size_micro_share",
    # Relatedness
    "related_variety",
    "within_sector_diversity",
]

features_theory = [
    # Human capital
    "nvq_level3",
    "gcse_age19",
    "apprenticeship_starts",
    "apprenticeship_achievements",
    "fe_participation",
    # Entrepreneurial discovery
    "enterprise_birth_rate",
    "enterprise_death_rate",
    "enterprise_high_growth_rate",
    # Connectivity
    "broadband",
    "coverage_4g",
    # Place conditions
    "housing_net_additions",
    # Relatedness
    "related_variety",
]

feature_groups = {
    "full":   features_full,
    "theory": features_theory,
}

# ─────────────────────────────────────────────
# CONFIGURACIÓN
# ─────────────────────────────────────────────
RF_PARAMS_REG = dict(n_estimators=100, max_depth=4, min_samples_leaf=5,
                     n_jobs=-1, random_state=42)
RF_PARAMS_CLF = dict(n_estimators=100, max_depth=4, min_samples_leaf=5,
                     n_jobs=-1, random_state=42)

CV_REG = KFold(n_splits=5, shuffle=True, random_state=42)
CV_CLF = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

dep_vars_regression     = ["lq_emp", "lq_bus", "gd_emp", "gd_bus"]
dep_vars_classification = ["lq_emp", "lq_bus", "gd_emp", "gd_bus"]

# ── Dos esquemas de umbral para clasificación ──
THRESHOLD_SCHEMES = {
    "median": {"lq": 1,    "gd": 0.50},   # p50 — criterio original
    "p75":    {"lq": 1,    "gd": 0.75},   # p75 — criterio nuevo
}

sectors = sorted(df["IS8_SECTOR"].dropna().unique())

# ─────────────────────────────────────────────
# LOOP PRINCIPAL — dos grupos x dos esquemas
# ─────────────────────────────────────────────
all_results = []
all_fi      = []

for group_name, features in feature_groups.items():

    missing  = [f for f in features if f not in df.columns]
    if missing:
        print(f"⚠️  [{group_name}] Columnas no encontradas: {missing}")
    features = [f for f in features if f in df.columns]

    print(f"\n{'#'*60}")
    print(f"  GRUPO: {group_name.upper()}  |  {len(features)} features")
    print(f"{'#'*60}")

    for sector in sectors:
        sub = df[df["IS8_SECTOR"] == sector].copy()
        X   = sub[features].copy()
        X   = X.fillna(X.median(numeric_only=True))

        print(f"\n{'='*60}")
        print(f"  SECTOR: {sector}  |  n = {len(sub)}")
        print(f"{'='*60}")

        # ── REGRESIÓN — sin cambios ───────────────────────────────
        for dep in dep_vars_regression:
            if dep not in sub.columns:
                continue
            y    = sub[dep].copy()
            mask = y.notna()
            X_r, y_r = X[mask], y[mask]

            if len(y_r) < 20:
                print(f"  [SKIP reg {dep}] n={len(y_r)} < 20")
                continue

            model = RandomForestRegressor(**RF_PARAMS_REG)
            r2_cv   = cross_val_score(model, X_r, y_r, cv=CV_REG, scoring="r2")
            rmse_cv = np.sqrt(-cross_val_score(model, X_r, y_r, cv=CV_REG,
                              scoring="neg_mean_squared_error"))

            print(f"  [Reg {group_name}] {dep} | R²={r2_cv.mean():.3f} ± {r2_cv.std():.3f}")

            model.fit(X_r, y_r)
            all_fi.append(pd.DataFrame({
                "group":        group_name,
                "threshold_scheme": "all",   # regresión no depende del umbral
                "sector":       sector,
                "dep_var":      dep,
                "model_type":   "regression",
                "feature":      features,
                "importance":   model.feature_importances_
            }))

            all_results.append({
                "group":            group_name,
                "threshold_scheme": "all",
                "sector":           sector,
                "dep_var":          dep,
                "model_type":       "regression",
                "n":                int(mask.sum()),
                "R2_mean":          round(r2_cv.mean(), 4),
                "R2_std":           round(r2_cv.std(),  4),
                "RMSE_mean":        round(rmse_cv.mean(), 4),
                "RMSE_std":         round(rmse_cv.std(),  4),
            })

        # ── CLASIFICACIÓN — dos esquemas de umbral ───────────────
        for scheme_name, scheme in THRESHOLD_SCHEMES.items():
            for dep in dep_vars_classification:
                if dep not in sub.columns:
                    continue

                y_cont = sub[dep].copy()
                mask   = y_cont.notna()
                X_c    = X[mask]
                y_vals = y_cont[mask]

                # Definir umbral según tipo de variable y esquema
                is_lq = dep in ("lq_emp", "lq_bus")
                if is_lq:
                    threshold = scheme["lq"]          # siempre 1
                else:
                    threshold = y_vals.quantile(scheme["gd"])  # p50 o p75

                y_c     = (y_vals >= threshold).astype(int)
                dep_clf = f"{dep}_binary_{scheme_name}"

                if len(y_c) < 20 or y_c.nunique() < 2:
                    print(f"  [SKIP clf {dep_clf}] n<20 o clase única")
                    continue

                # Aviso si clase positiva es muy pequeña
                n_pos = y_c.sum()
                if n_pos < 15:
                    print(f"  ⚠️  [{dep_clf}] solo {n_pos} positivos — resultado inestable")

                model_c = RandomForestClassifier(**RF_PARAMS_CLF)
                f1_cv  = cross_val_score(model_c, X_c, y_c, cv=CV_CLF, scoring="f1")
                acc_cv = cross_val_score(model_c, X_c, y_c, cv=CV_CLF, scoring="accuracy")

                print(f"  [Clf {group_name}|{scheme_name}] {dep_clf} "
                      f"| F1={f1_cv.mean():.3f} ± {f1_cv.std():.3f} "
                      f"| n_pos={n_pos}")

                model_c.fit(X_c, y_c)
                all_fi.append(pd.DataFrame({
                    "group":            group_name,
                    "threshold_scheme": scheme_name,
                    "sector":           sector,
                    "dep_var":          dep_clf,
                    "model_type":       "classification",
                    "feature":          features,
                    "importance":       model_c.feature_importances_
                }))

                all_results.append({
                    "group":            group_name,
                    "threshold_scheme": scheme_name,
                    "sector":           sector,
                    "dep_var":          dep_clf,
                    "model_type":       "classification",
                    "n":                int(mask.sum()),
                    "n_positive":       int(n_pos),
                    "threshold_value":  round(float(threshold), 4),
                    "F1_mean":          round(f1_cv.mean(), 4),
                    "F1_std":           round(f1_cv.std(),  4),
                    "Acc_mean":         round(acc_cv.mean(), 4),
                    "Acc_std":          round(acc_cv.std(),  4),
                })

# ─────────────────────────────────────────────
# EXPORTAR
# ─────────────────────────────────────────────
results_df = pd.DataFrame(all_results)
fi_df      = pd.concat(all_fi, ignore_index=True) if all_fi else pd.DataFrame()

results_df.to_csv("rf_two_groups_metrics.csv",       index=False)
fi_df.to_csv("rf_two_groups_feature_importance.csv", index=False)

# ── Comparación regresión (sin cambios) ──
reg_df   = results_df[results_df["model_type"] == "regression"]
comp_reg = reg_df.pivot_table(
    index=["sector", "dep_var"],
    columns="group",
    values=["R2_mean", "RMSE_mean"]
).round(4)
comp_reg.columns     = ["_".join(c) for c in comp_reg.columns]
comp_reg["R2_winner"] = np.where(
    comp_reg["R2_mean_full"] >= comp_reg["R2_mean_theory"], "full", "theory"
)
comp_reg.to_csv("rf_comparison_regression.csv")
print("\n── COMPARACIÓN REGRESIÓN (R²) ──")
print(comp_reg[["R2_mean_full", "R2_mean_theory", "R2_winner"]].to_string())

# ── Comparación clasificación — separada por esquema ──
clf_df = results_df[results_df["model_type"] == "classification"]

for scheme_name in THRESHOLD_SCHEMES:
    scheme_clf = clf_df[clf_df["threshold_scheme"] == scheme_name]
    if scheme_clf.empty:
        continue

    comp_clf = scheme_clf.pivot_table(
        index=["sector", "dep_var"],
        columns="group",
        values=["F1_mean", "Acc_mean"]
    ).round(4)
    comp_clf.columns      = ["_".join(c) for c in comp_clf.columns]
    comp_clf["F1_winner"] = np.where(
        comp_clf["F1_mean_full"] >= comp_clf["F1_mean_theory"], "full", "theory"
    )
    fname = f"rf_comparison_classification_{scheme_name}.csv"
    comp_clf.to_csv(fname)
    print(f"\n── COMPARACIÓN CLASIFICACIÓN [{scheme_name.upper()}] (F1) ──")
    print(comp_clf[["F1_mean_full", "F1_mean_theory", "F1_winner"]].to_string())

print("\n✅ Archivos exportados:")
print("   rf_two_groups_metrics.csv")
print("   rf_two_groups_feature_importance.csv")
print("   rf_comparison_regression.csv")
print("   rf_comparison_classification_median.csv")
print("   rf_comparison_classification_p75.csv")
# Out:
# ############################################################
#   GRUPO: FULL  |  19 features
# ############################################################
#
# ============================================================
#   SECTOR: Advanced Manufacturing  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=0.386 ± 0.131
#   [Reg full] lq_bus | R²=0.521 ± 0.059
#   [Reg full] gd_emp | R²=-0.040 ± 0.132
#   [Reg full] gd_bus | R²=0.062 ± 0.148
#   [Clf full|median] lq_emp_binary_median | F1=0.716 ± 0.039 | n_pos=142
#   [Clf full|median] lq_bus_binary_median | F1=0.792 ± 0.020 | n_pos=142
#   [Clf full|median] gd_emp_binary_median | F1=0.488 ± 0.049 | n_pos=148
#   [Clf full|median] gd_bus_binary_median | F1=0.572 ± 0.080 | n_pos=148
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.716 ± 0.039 | n_pos=142
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.792 ± 0.020 | n_pos=142
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.246 ± 0.131 | n_pos=74
#   [Clf full|p75] gd_bus_binary_p75 | F1=0.215 ± 0.150 | n_pos=74
#
# ============================================================
#   SECTOR: Creative Industries  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=0.634 ± 0.086
#   [Reg full] lq_bus | R²=0.757 ± 0.039
#   [Reg full] gd_emp | R²=0.052 ± 0.062
#   [Reg full] gd_bus | R²=0.108 ± 0.110
#   [Clf full|median] lq_emp_binary_median | F1=0.591 ± 0.189 | n_pos=54
#   [Clf full|median] lq_bus_binary_median | F1=0.810 ± 0.060 | n_pos=85
#   [Clf full|median] gd_emp_binary_median | F1=0.599 ± 0.064 | n_pos=148
#   [Clf full|median] gd_bus_binary_median | F1=0.593 ± 0.069 | n_pos=148
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.591 ± 0.189 | n_pos=54
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.810 ± 0.060 | n_pos=85
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.050 ± 0.061 | n_pos=74
#   [Clf full|p75] gd_bus_binary_p75 | F1=0.050 ± 0.062 | n_pos=74
#
# ============================================================
#   SECTOR: Defence  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=-3.021 ± 4.002
#   [Reg full] lq_bus | R²=-0.221 ± 0.392
#   [Reg full] gd_emp | R²=-0.543 ± 0.613
#   [SKIP reg gd_bus] n=2 < 20
#   [Clf full|median] lq_emp_binary_median | F1=0.000 ± 0.000 | n_pos=23
#   ⚠️  [lq_bus_binary_median] solo 4 positivos — resultado inestable
#   [Clf full|median] lq_bus_binary_median | F1=0.000 ± 0.000 | n_pos=4
#   [Clf full|median] gd_emp_binary_median | F1=0.733 ± 0.047 | n_pos=29
#   [SKIP clf gd_bus_binary_median] n<20 o clase única
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=23
#   ⚠️  [lq_bus_binary_p75] solo 4 positivos — resultado inestable
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.000 ± 0.000 | n_pos=4
#   ⚠️  [gd_emp_binary_p75] solo 12 positivos — resultado inestable
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=12
#   [SKIP clf gd_bus_binary_p75] n<20 o clase única
#
# ============================================================
#   SECTOR: Digital and Technologies  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=0.507 ± 0.057
#   [Reg full] lq_bus | R²=0.628 ± 0.073
#   [Reg full] gd_emp | R²=0.067 ± 0.016
#   [Reg full] gd_bus | R²=0.056 ± 0.059
#   [Clf full|median] lq_emp_binary_median | F1=0.542 ± 0.079 | n_pos=75
#   [Clf full|median] lq_bus_binary_median | F1=0.727 ± 0.041 | n_pos=101
#   [Clf full|median] gd_emp_binary_median | F1=0.528 ± 0.105 | n_pos=148
#   [Clf full|median] gd_bus_binary_median | F1=0.645 ± 0.084 | n_pos=148
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.542 ± 0.079 | n_pos=75
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.727 ± 0.041 | n_pos=101
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.221 ± 0.053 | n_pos=74
#   [Clf full|p75] gd_bus_binary_p75 | F1=0.256 ± 0.100 | n_pos=74
#
# ============================================================
#   SECTOR: Financial Services  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=0.092 ± 0.210
#   [Reg full] lq_bus | R²=0.157 ± 0.129
#   [Reg full] gd_emp | R²=-0.065 ± 0.034
#   [Reg full] gd_bus | R²=0.126 ± 0.078
#   [Clf full|median] lq_emp_binary_median | F1=0.160 ± 0.150 | n_pos=42
#   [Clf full|median] lq_bus_binary_median | F1=0.210 ± 0.118 | n_pos=52
#   [Clf full|median] gd_emp_binary_median | F1=0.546 ± 0.074 | n_pos=148
#   [Clf full|median] gd_bus_binary_median | F1=0.628 ± 0.058 | n_pos=148
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.160 ± 0.150 | n_pos=42
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.210 ± 0.118 | n_pos=52
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.022 ± 0.044 | n_pos=74
#   [Clf full|p75] gd_bus_binary_p75 | F1=0.000 ± 0.000 | n_pos=74
#
# ============================================================
#   SECTOR: Life Sciences  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=0.013 ± 0.061
#   [Reg full] lq_bus | R²=0.220 ± 0.224
#   [Reg full] gd_emp | R²=-0.024 ± 0.083
#   [Reg full] gd_bus | R²=0.194 ± 0.093
#   [Clf full|median] lq_emp_binary_median | F1=0.049 ± 0.059 | n_pos=75
#   [Clf full|median] lq_bus_binary_median | F1=0.494 ± 0.127 | n_pos=64
#   [Clf full|median] gd_emp_binary_median | F1=0.532 ± 0.085 | n_pos=140
#   [Clf full|median] gd_bus_binary_median | F1=0.840 ± 0.017 | n_pos=168
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.049 ± 0.059 | n_pos=75
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.494 ± 0.127 | n_pos=64
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.125 ± 0.075 | n_pos=70
#   [Clf full|p75] gd_bus_binary_p75 | F1=0.283 ± 0.071 | n_pos=59
#
# ============================================================
#   SECTOR: Professional and Business Services  |  n = 296
# ============================================================
#   [Reg full] lq_emp | R²=0.411 ± 0.118
#   [Reg full] lq_bus | R²=0.633 ± 0.148
#   [Reg full] gd_emp | R²=0.004 ± 0.048
#   [Reg full] gd_bus | R²=0.028 ± 0.074
#   [Clf full|median] lq_emp_binary_median | F1=0.468 ± 0.176 | n_pos=58
#   [Clf full|median] lq_bus_binary_median | F1=0.806 ± 0.040 | n_pos=94
#   [Clf full|median] gd_emp_binary_median | F1=0.569 ± 0.040 | n_pos=148
#   [Clf full|median] gd_bus_binary_median | F1=0.637 ± 0.093 | n_pos=148
#   [Clf full|p75] lq_emp_binary_p75 | F1=0.468 ± 0.176 | n_pos=58
#   [Clf full|p75] lq_bus_binary_p75 | F1=0.806 ± 0.040 | n_pos=94
#   [Clf full|p75] gd_emp_binary_p75 | F1=0.122 ± 0.004 | n_pos=74
#   [Clf full|p75] gd_bus_binary_p75 | F1=0.119 ± 0.074 | n_pos=74
#
# ############################################################
#   GRUPO: THEORY  |  12 features
# ############################################################
#
# ============================================================
#   SECTOR: Advanced Manufacturing  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=0.068 ± 0.081
#   [Reg theory] lq_bus | R²=0.434 ± 0.070
#   [Reg theory] gd_emp | R²=-0.051 ± 0.097
#   [Reg theory] gd_bus | R²=0.030 ± 0.147
#   [Clf theory|median] lq_emp_binary_median | F1=0.707 ± 0.027 | n_pos=142
#   [Clf theory|median] lq_bus_binary_median | F1=0.738 ± 0.037 | n_pos=142
#   [Clf theory|median] gd_emp_binary_median | F1=0.464 ± 0.036 | n_pos=148
#   [Clf theory|median] gd_bus_binary_median | F1=0.560 ± 0.050 | n_pos=148
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.707 ± 0.027 | n_pos=142
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.738 ± 0.037 | n_pos=142
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.194 ± 0.100 | n_pos=74
#   [Clf theory|p75] gd_bus_binary_p75 | F1=0.157 ± 0.087 | n_pos=74
#
# ============================================================
#   SECTOR: Creative Industries  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=0.475 ± 0.114
#   [Reg theory] lq_bus | R²=0.688 ± 0.052
#   [Reg theory] gd_emp | R²=0.048 ± 0.050
#   [Reg theory] gd_bus | R²=0.043 ± 0.081
#   [Clf theory|median] lq_emp_binary_median | F1=0.565 ± 0.188 | n_pos=54
#   [Clf theory|median] lq_bus_binary_median | F1=0.780 ± 0.057 | n_pos=85
#   [Clf theory|median] gd_emp_binary_median | F1=0.561 ± 0.043 | n_pos=148
#   [Clf theory|median] gd_bus_binary_median | F1=0.536 ± 0.016 | n_pos=148
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.565 ± 0.188 | n_pos=54
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.780 ± 0.057 | n_pos=85
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=74
#   [Clf theory|p75] gd_bus_binary_p75 | F1=0.000 ± 0.000 | n_pos=74
#
# ============================================================
#   SECTOR: Defence  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=-3.049 ± 4.015
#   [Reg theory] lq_bus | R²=-0.260 ± 0.474
#   [Reg theory] gd_emp | R²=-0.606 ± 0.681
#   [SKIP reg gd_bus] n=2 < 20
#   [Clf theory|median] lq_emp_binary_median | F1=0.000 ± 0.000 | n_pos=23
#   ⚠️  [lq_bus_binary_median] solo 4 positivos — resultado inestable
#   [Clf theory|median] lq_bus_binary_median | F1=0.000 ± 0.000 | n_pos=4
#   [Clf theory|median] gd_emp_binary_median | F1=0.748 ± 0.075 | n_pos=29
#   [SKIP clf gd_bus_binary_median] n<20 o clase única
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=23
#   ⚠️  [lq_bus_binary_p75] solo 4 positivos — resultado inestable
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.000 ± 0.000 | n_pos=4
#   ⚠️  [gd_emp_binary_p75] solo 12 positivos — resultado inestable
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=12
#   [SKIP clf gd_bus_binary_p75] n<20 o clase única
#
# ============================================================
#   SECTOR: Digital and Technologies  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=0.284 ± 0.068
#   [Reg theory] lq_bus | R²=0.563 ± 0.062
#   [Reg theory] gd_emp | R²=0.035 ± 0.054
#   [Reg theory] gd_bus | R²=0.017 ± 0.078
#   [Clf theory|median] lq_emp_binary_median | F1=0.463 ± 0.139 | n_pos=75
#   [Clf theory|median] lq_bus_binary_median | F1=0.715 ± 0.016 | n_pos=101
#   [Clf theory|median] gd_emp_binary_median | F1=0.520 ± 0.075 | n_pos=148
#   [Clf theory|median] gd_bus_binary_median | F1=0.593 ± 0.043 | n_pos=148
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.463 ± 0.139 | n_pos=75
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.715 ± 0.016 | n_pos=101
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.187 ± 0.081 | n_pos=74
#   [Clf theory|p75] gd_bus_binary_p75 | F1=0.069 ± 0.057 | n_pos=74
#
# ============================================================
#   SECTOR: Financial Services  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=-0.375 ± 0.374
#   [Reg theory] lq_bus | R²=0.049 ± 0.188
#   [Reg theory] gd_emp | R²=-0.076 ± 0.075
#   [Reg theory] gd_bus | R²=0.126 ± 0.080
#   [Clf theory|median] lq_emp_binary_median | F1=0.000 ± 0.000 | n_pos=42
#   [Clf theory|median] lq_bus_binary_median | F1=0.163 ± 0.148 | n_pos=52
#   [Clf theory|median] gd_emp_binary_median | F1=0.537 ± 0.051 | n_pos=148
#   [Clf theory|median] gd_bus_binary_median | F1=0.620 ± 0.056 | n_pos=148
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=42
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.163 ± 0.148 | n_pos=52
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.000 ± 0.000 | n_pos=74
#   [Clf theory|p75] gd_bus_binary_p75 | F1=0.025 ± 0.050 | n_pos=74
#
# ============================================================
#   SECTOR: Life Sciences  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=-0.012 ± 0.068
#   [Reg theory] lq_bus | R²=0.100 ± 0.190
#   [Reg theory] gd_emp | R²=-0.047 ± 0.097
#   [Reg theory] gd_bus | R²=0.019 ± 0.055
#   [Clf theory|median] lq_emp_binary_median | F1=0.050 ± 0.061 | n_pos=75
#   [Clf theory|median] lq_bus_binary_median | F1=0.171 ± 0.126 | n_pos=64
#   [Clf theory|median] gd_emp_binary_median | F1=0.525 ± 0.045 | n_pos=140
#   [Clf theory|median] gd_bus_binary_median | F1=0.823 ± 0.011 | n_pos=168
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.050 ± 0.061 | n_pos=75
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.171 ± 0.126 | n_pos=64
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.099 ± 0.089 | n_pos=70
#   [Clf theory|p75] gd_bus_binary_p75 | F1=0.205 ± 0.067 | n_pos=59
#
# ============================================================
#   SECTOR: Professional and Business Services  |  n = 296
# ============================================================
#   [Reg theory] lq_emp | R²=0.260 ± 0.123
#   [Reg theory] lq_bus | R²=0.575 ± 0.147
#   [Reg theory] gd_emp | R²=0.011 ± 0.037
#   [Reg theory] gd_bus | R²=0.004 ± 0.055
#   [Clf theory|median] lq_emp_binary_median | F1=0.505 ± 0.153 | n_pos=58
#   [Clf theory|median] lq_bus_binary_median | F1=0.779 ± 0.032 | n_pos=94
#   [Clf theory|median] gd_emp_binary_median | F1=0.585 ± 0.044 | n_pos=148
#   [Clf theory|median] gd_bus_binary_median | F1=0.608 ± 0.037 | n_pos=148
#   [Clf theory|p75] lq_emp_binary_p75 | F1=0.505 ± 0.153 | n_pos=58
#   [Clf theory|p75] lq_bus_binary_p75 | F1=0.779 ± 0.032 | n_pos=94
#   [Clf theory|p75] gd_emp_binary_p75 | F1=0.025 ± 0.050 | n_pos=74
#   [Clf theory|p75] gd_bus_binary_p75 | F1=0.052 ± 0.063 | n_pos=74
#
# ── COMPARACIÓN REGRESIÓN (R²) ──
#                                             R2_mean_full  R2_mean_theory R2_winner
# sector                             dep_var
# Advanced Manufacturing             gd_bus         0.0619          0.0301      full
#                                    gd_emp        -0.0400         -0.0505      full
#                                    lq_bus         0.5214          0.4340      full
#                                    lq_emp         0.3858          0.0682      full
# Creative Industries                gd_bus         0.1079          0.0426      full
#                                    gd_emp         0.0516          0.0482      full
#                                    lq_bus         0.7570          0.6877      full
#                                    lq_emp         0.6341          0.4745      full
# Defence                            gd_emp        -0.5431         -0.6064      full
#                                    lq_bus        -0.2215         -0.2600      full
#                                    lq_emp        -3.0207         -3.0487      full
# Digital and Technologies           gd_bus         0.0564          0.0172      full
#                                    gd_emp         0.0672          0.0351      full
#                                    lq_bus         0.6281          0.5631      full
#                                    lq_emp         0.5068          0.2835      full
# Financial Services                 gd_bus         0.1258          0.1257      full
#                                    gd_emp        -0.0646         -0.0759      full
#                                    lq_bus         0.1570          0.0487      full
#                                    lq_emp         0.0917         -0.3747      full
# Life Sciences                      gd_bus         0.1940          0.0193      full
#                                    gd_emp        -0.0238         -0.0469      full
#                                    lq_bus         0.2203          0.1001      full
#                                    lq_emp         0.0134         -0.0119      full
# Professional and Business Services gd_bus         0.0284          0.0045      full
#                                    gd_emp         0.0040          0.0109    theory
#                                    lq_bus         0.6327          0.5753      full
#                                    lq_emp         0.4115          0.2600      full
#
# ── COMPARACIÓN CLASIFICACIÓN [MEDIAN] (F1) ──
#                                                          F1_mean_full  F1_mean_theory F1_winner
# sector                             dep_var
# Advanced Manufacturing             gd_bus_binary_median        0.5720          0.5599      full
#                                    gd_emp_binary_median        0.4878          0.4639      full
#                                    lq_bus_binary_median        0.7923          0.7380      full
#                                    lq_emp_binary_median        0.7157          0.7068      full
# Creative Industries                gd_bus_binary_median        0.5933          0.5365      full
#                                    gd_emp_binary_median        0.5986          0.5606      full
#                                    lq_bus_binary_median        0.8098          0.7805      full
#                                    lq_emp_binary_median        0.5911          0.5651      full
# Defence                            gd_emp_binary_median        0.7329          0.7477    theory
#                                    lq_bus_binary_median        0.0000          0.0000      full
#                                    lq_emp_binary_median        0.0000          0.0000      full
# Digital and Technologies           gd_bus_binary_median        0.6452          0.5930      full
#                                    gd_emp_binary_median        0.5278          0.5200      full
#                                    lq_bus_binary_median        0.7271          0.7147      full
#                                    lq_emp_binary_median        0.5423          0.4633      full
# Financial Services                 gd_bus_binary_median        0.6280          0.6198      full
#                                    gd_emp_binary_median        0.5462          0.5366      full
#                                    lq_bus_binary_median        0.2105          0.1629      full
#                                    lq_emp_binary_median        0.1600          0.0000      full
# Life Sciences                      gd_bus_binary_median        0.8405          0.8230      full
#                                    gd_emp_binary_median        0.5324          0.5254      full
#                                    lq_bus_binary_median        0.4941          0.1709      full
#                                    lq_emp_binary_median        0.0485          0.0500    theory
# Professional and Business Services gd_bus_binary_median        0.6373          0.6082      full
#                                    gd_emp_binary_median        0.5695          0.5854    theory
#                                    lq_bus_binary_median        0.8056          0.7792      full
#                                    lq_emp_binary_median        0.4680          0.5046    theory
#
# ── COMPARACIÓN CLASIFICACIÓN [P75] (F1) ──
#                                                       F1_mean_full  F1_mean_theory F1_winner
# sector                             dep_var
# Advanced Manufacturing             gd_bus_binary_p75        0.2150          0.1565      full
#                                    gd_emp_binary_p75        0.2465          0.1937      full
#                                    lq_bus_binary_p75        0.7923          0.7380      full
#                                    lq_emp_binary_p75        0.7157          0.7068      full
# Creative Industries                gd_bus_binary_p75        0.0502          0.0000      full
#                                    gd_emp_binary_p75        0.0500          0.0000      full
#                                    lq_bus_binary_p75        0.8098          0.7805      full
#                                    lq_emp_binary_p75        0.5911          0.5651      full
# Defence                            gd_emp_binary_p75        0.0000          0.0000      full
#                                    lq_bus_binary_p75        0.0000          0.0000      full
#                                    lq_emp_binary_p75        0.0000          0.0000      full
# Digital and Technologies           gd_bus_binary_p75        0.2558          0.0694      full
#                                    gd_emp_binary_p75        0.2207          0.1867      full
#                                    lq_bus_binary_p75        0.7271          0.7147      full
#                                    lq_emp_binary_p75        0.5423          0.4633      full
# Financial Services                 gd_bus_binary_p75        0.0000          0.0250    theory
#                                    gd_emp_binary_p75        0.0222          0.0000      full
#                                    lq_bus_binary_p75        0.2105          0.1629      full
#                                    lq_emp_binary_p75        0.1600          0.0000      full
# Life Sciences                      gd_bus_binary_p75        0.2829          0.2048      full
#                                    gd_emp_binary_p75        0.1254          0.0987      full
#                                    lq_bus_binary_p75        0.4941          0.1709      full
#                                    lq_emp_binary_p75        0.0485          0.0500    theory
# Professional and Business Services gd_bus_binary_p75        0.1191          0.0517      full
#                                    gd_emp_binary_p75        0.1221          0.0250      full
#                                    lq_bus_binary_p75        0.8056          0.7792      full
#                                    lq_emp_binary_p75        0.4680          0.5046    theory
#
# ✅ Archivos exportados:
#    rf_two_groups_metrics.csv
#    rf_two_groups_feature_importance.csv
#    rf_comparison_regression.csv
#    rf_comparison_classification_median.csv
#    rf_comparison_classification_p75.csv

# %%
# ─────────────────────────────────────────────
# 5. EXPORTAR
# ─────────────────────────────────────────────
results_df = pd.DataFrame(all_results)
fi_df      = pd.concat(all_fi, ignore_index=True) if all_fi else pd.DataFrame()

results_df.to_csv("rf_metrics.csv",          index=False)
fi_df.to_csv("rf_feature_importance.csv",    index=False)
print("\n✅ Archivos exportados.")

# ─────────────────────────────────────────────
# 6. RESUMEN — separado por tipo de modelo
# ─────────────────────────────────────────────
reg_df = results_df[results_df["model_type"] == "regression"][
    ["sector", "dep_var", "n", "R2_mean", "R2_std", "RMSE_mean", "RMSE_std"]
].copy()

clf_df = results_df[results_df["model_type"] == "classification"][
    ["sector", "dep_var", "n", "F1_mean", "F1_std", "Acc_mean", "Acc_std"]
].copy()

print("\n── REGRESIÓN (RF) ──")
print(reg_df.to_string(index=False))
print("\n── CLASIFICACIÓN (RF) ──")
print(clf_df.to_string(index=False))

reg_df.to_csv("rf_regression_summary.csv",     index=False)
clf_df.to_csv("rf_classification_summary.csv", index=False)
print("\n✅ Tablas de comparación exportadas:")
print("   rf_regression_summary.csv")
print("   rf_classification_summary.csv")
# Out:
# ✅ Archivos exportados.
#
# ── REGRESIÓN (RF) ──
#                             sector dep_var   n  R2_mean  R2_std  RMSE_mean  RMSE_std
#             Advanced Manufacturing  lq_emp 296   0.3858  0.1305     0.9572    0.2579
#             Advanced Manufacturing  lq_bus 296   0.5214  0.0586     0.2977    0.0159
#             Advanced Manufacturing  gd_emp 295  -0.0400  0.1322     0.0516    0.0066
#             Advanced Manufacturing  gd_bus 295   0.0619  0.1482     0.0326    0.0060
#                Creative Industries  lq_emp 296   0.6341  0.0856     0.3858    0.0627
#                Creative Industries  lq_bus 296   0.7570  0.0387     0.2366    0.0218
#                Creative Industries  gd_emp 296   0.0516  0.0623     0.0341    0.0039
#                Creative Industries  gd_bus 295   0.1079  0.1102     0.0157    0.0022
#                            Defence  lq_emp 296  -3.0207  4.0023     6.5715    4.6294
#                            Defence  lq_bus 296  -0.2215  0.3922     0.7454    0.5411
#                            Defence  gd_emp  46  -0.5431  0.6128     0.0706    0.0110
#           Digital and Technologies  lq_emp 296   0.5068  0.0574     0.3919    0.0619
#           Digital and Technologies  lq_bus 296   0.6281  0.0726     0.2083    0.0189
#           Digital and Technologies  gd_emp 295   0.0672  0.0165     0.0294    0.0042
#           Digital and Technologies  gd_bus 295   0.0564  0.0587     0.0180    0.0024
#                 Financial Services  lq_emp 296   0.0917  0.2098     0.6465    0.3997
#                 Financial Services  lq_bus 296   0.1570  0.1289     0.4605    0.2248
#                 Financial Services  gd_emp 295  -0.0646  0.0336     0.0507    0.0062
#                 Financial Services  gd_bus 295   0.1258  0.0777     0.0279    0.0047
#                      Life Sciences  lq_emp 296   0.0134  0.0615     1.6503    0.2676
#                      Life Sciences  lq_bus 296   0.2203  0.2239     0.7864    0.3279
#                      Life Sciences  gd_emp 280  -0.0238  0.0829     0.1399    0.0493
#                      Life Sciences  gd_bus 235   0.1940  0.0932     0.0673    0.0065
# Professional and Business Services  lq_emp 296   0.4115  0.1177     0.2957    0.0750
# Professional and Business Services  lq_bus 296   0.6327  0.1481     0.1611    0.0501
# Professional and Business Services  gd_emp 296   0.0040  0.0485     0.0337    0.0078
# Professional and Business Services  gd_bus 296   0.0284  0.0740     0.0176    0.0049
#             Advanced Manufacturing  lq_emp 296   0.0682  0.0810     1.2131    0.3836
#             Advanced Manufacturing  lq_bus 296   0.4340  0.0697     0.3238    0.0200
#             Advanced Manufacturing  gd_emp 295  -0.0505  0.0972     0.0519    0.0064
#             Advanced Manufacturing  gd_bus 295   0.0301  0.1466     0.0333    0.0065
#                Creative Industries  lq_emp 296   0.4745  0.1141     0.4607    0.0648
#                Creative Industries  lq_bus 296   0.6877  0.0522     0.2676    0.0207
#                Creative Industries  gd_emp 296   0.0482  0.0505     0.0342    0.0038
#                Creative Industries  gd_bus 295   0.0426  0.0808     0.0163    0.0025
#                            Defence  lq_emp 296  -3.0487  4.0151     6.5510    4.6122
#                            Defence  lq_bus 296  -0.2600  0.4743     0.7529    0.5319
#                            Defence  gd_emp  46  -0.6064  0.6807     0.0719    0.0116
#           Digital and Technologies  lq_emp 296   0.2835  0.0681     0.4732    0.0764
#           Digital and Technologies  lq_bus 296   0.5631  0.0620     0.2263    0.0164
#           Digital and Technologies  gd_emp 295   0.0351  0.0536     0.0298    0.0040
#           Digital and Technologies  gd_bus 295   0.0172  0.0777     0.0183    0.0022
#                 Financial Services  lq_emp 296  -0.3747  0.3742     0.7729    0.4390
#                 Financial Services  lq_bus 296   0.0487  0.1882     0.4818    0.2202
#                 Financial Services  gd_emp 295  -0.0759  0.0753     0.0510    0.0072
#                 Financial Services  gd_bus 295   0.1257  0.0800     0.0279    0.0047
#                      Life Sciences  lq_emp 296  -0.0119  0.0677     1.6653    0.2391
#                      Life Sciences  lq_bus 296   0.1001  0.1898     0.8390    0.3117
#                      Life Sciences  gd_emp 280  -0.0469  0.0969     0.1410    0.0485
#                      Life Sciences  gd_bus 235   0.0193  0.0549     0.0749    0.0103
# Professional and Business Services  lq_emp 296   0.2600  0.1234     0.3307    0.0779
# Professional and Business Services  lq_bus 296   0.5753  0.1473     0.1731    0.0456
# Professional and Business Services  gd_emp 296   0.0109  0.0372     0.0337    0.0080
# Professional and Business Services  gd_bus 296   0.0045  0.0552     0.0178    0.0049
#
# ── CLASIFICACIÓN (RF) ──
#                             sector              dep_var   n  F1_mean  F1_std  Acc_mean  Acc_std
#             Advanced Manufacturing lq_emp_binary_median 296   0.7157  0.0386    0.7128   0.0442
#             Advanced Manufacturing lq_bus_binary_median 296   0.7923  0.0201    0.7871   0.0237
#             Advanced Manufacturing gd_emp_binary_median 295   0.4878  0.0493    0.5254   0.0442
#             Advanced Manufacturing gd_bus_binary_median 295   0.5720  0.0800    0.5966   0.0460
#             Advanced Manufacturing    lq_emp_binary_p75 296   0.7157  0.0386    0.7128   0.0442
#             Advanced Manufacturing    lq_bus_binary_p75 296   0.7923  0.0201    0.7871   0.0237
#             Advanced Manufacturing    gd_emp_binary_p75 295   0.2465  0.1305    0.7661   0.0249
#             Advanced Manufacturing    gd_bus_binary_p75 295   0.2150  0.1502    0.7627   0.0415
#                Creative Industries lq_emp_binary_median 296   0.5911  0.1895    0.8919   0.0348
#                Creative Industries lq_bus_binary_median 296   0.8098  0.0603    0.8986   0.0263
#                Creative Industries gd_emp_binary_median 296   0.5986  0.0644    0.6013   0.0502
#                Creative Industries gd_bus_binary_median 295   0.5933  0.0691    0.5932   0.0514
#                Creative Industries    lq_emp_binary_p75 296   0.5911  0.1895    0.8919   0.0348
#                Creative Industries    lq_bus_binary_p75 296   0.8098  0.0603    0.8986   0.0263
#                Creative Industries    gd_emp_binary_p75 296   0.0500  0.0612    0.7466   0.0161
#                Creative Industries    gd_bus_binary_p75 295   0.0502  0.0617    0.7458   0.0214
#                            Defence lq_emp_binary_median 296   0.0000  0.0000    0.9223   0.0081
#                            Defence lq_bus_binary_median 296   0.0000  0.0000    0.9865   0.0068
#                            Defence gd_emp_binary_median  46   0.7329  0.0467    0.6311   0.0839
#                            Defence    lq_emp_binary_p75 296   0.0000  0.0000    0.9223   0.0081
#                            Defence    lq_bus_binary_p75 296   0.0000  0.0000    0.9865   0.0068
#                            Defence    gd_emp_binary_p75  46   0.0000  0.0000    0.7400   0.0475
#           Digital and Technologies lq_emp_binary_median 296   0.5423  0.0788    0.8211   0.0265
#           Digital and Technologies lq_bus_binary_median 296   0.7271  0.0408    0.8311   0.0356
#           Digital and Technologies gd_emp_binary_median 295   0.5278  0.1053    0.5559   0.0551
#           Digital and Technologies gd_bus_binary_median 295   0.6452  0.0844    0.6373   0.0732
#           Digital and Technologies    lq_emp_binary_p75 296   0.5423  0.0788    0.8211   0.0265
#           Digital and Technologies    lq_bus_binary_p75 296   0.7271  0.0408    0.8311   0.0356
#           Digital and Technologies    gd_emp_binary_p75 295   0.2207  0.0526    0.7661   0.0127
#           Digital and Technologies    gd_bus_binary_p75 295   0.2558  0.0995    0.7695   0.0230
#                 Financial Services lq_emp_binary_median 296   0.1600  0.1497    0.8716   0.0134
#                 Financial Services lq_bus_binary_median 296   0.2105  0.1184    0.8311   0.0180
#                 Financial Services gd_emp_binary_median 295   0.5462  0.0736    0.5322   0.0603
#                 Financial Services gd_bus_binary_median 295   0.6280  0.0578    0.6169   0.0691
#                 Financial Services    lq_emp_binary_p75 296   0.1600  0.1497    0.8716   0.0134
#                 Financial Services    lq_bus_binary_p75 296   0.2105  0.1184    0.8311   0.0180
#                 Financial Services    gd_emp_binary_p75 295   0.0222  0.0444    0.7356   0.0230
#                 Financial Services    gd_bus_binary_p75 295   0.0000  0.0000    0.7492   0.0068
#                      Life Sciences lq_emp_binary_median 296   0.0485  0.0595    0.7364   0.0214
#                      Life Sciences lq_bus_binary_median 296   0.4941  0.1267    0.8412   0.0313
#                      Life Sciences gd_emp_binary_median 280   0.5324  0.0851    0.5500   0.0653
#                      Life Sciences gd_bus_binary_median 235   0.8405  0.0169    0.7319   0.0289
#                      Life Sciences    lq_emp_binary_p75 296   0.0485  0.0595    0.7364   0.0214
#                      Life Sciences    lq_bus_binary_p75 296   0.4941  0.1267    0.8412   0.0313
#                      Life Sciences    gd_emp_binary_p75 280   0.1254  0.0747    0.7607   0.0087
#                      Life Sciences    gd_bus_binary_p75 235   0.2829  0.0707    0.7702   0.0208
# Professional and Business Services lq_emp_binary_median 296   0.4680  0.1761    0.8479   0.0417
# Professional and Business Services lq_bus_binary_median 296   0.8056  0.0399    0.8851   0.0165
# Professional and Business Services gd_emp_binary_median 296   0.5695  0.0401    0.5843   0.0296
# Professional and Business Services gd_bus_binary_median 296   0.6373  0.0925    0.6584   0.0694
# Professional and Business Services    lq_emp_binary_p75 296   0.4680  0.1761    0.8479   0.0417
# Professional and Business Services    lq_bus_binary_p75 296   0.8056  0.0399    0.8851   0.0165
# Professional and Business Services    gd_emp_binary_p75 296   0.1221  0.0036    0.7567   0.0091
# Professional and Business Services    gd_bus_binary_p75 296   0.1191  0.0745    0.7567   0.0149
#             Advanced Manufacturing lq_emp_binary_median 296   0.7068  0.0268    0.6959   0.0416
#             Advanced Manufacturing lq_bus_binary_median 296   0.7380  0.0367    0.7364   0.0240
#             Advanced Manufacturing gd_emp_binary_median 295   0.4639  0.0361    0.5017   0.0254
#             Advanced Manufacturing gd_bus_binary_median 295   0.5599  0.0504    0.5593   0.0322
#             Advanced Manufacturing    lq_emp_binary_p75 296   0.7068  0.0268    0.6959   0.0416
#             Advanced Manufacturing    lq_bus_binary_p75 296   0.7380  0.0367    0.7364   0.0240
#             Advanced Manufacturing    gd_emp_binary_p75 295   0.1937  0.1003    0.7525   0.0275
#             Advanced Manufacturing    gd_bus_binary_p75 295   0.1565  0.0871    0.7559   0.0173
#                Creative Industries lq_emp_binary_median 296   0.5651  0.1881    0.8818   0.0413
#                Creative Industries lq_bus_binary_median 296   0.7805  0.0573    0.8851   0.0224
#                Creative Industries gd_emp_binary_median 296   0.5606  0.0428    0.5676   0.0531
#                Creative Industries gd_bus_binary_median 295   0.5365  0.0156    0.5153   0.0314
#                Creative Industries    lq_emp_binary_p75 296   0.5651  0.1881    0.8818   0.0413
#                Creative Industries    lq_bus_binary_p75 296   0.7805  0.0573    0.8851   0.0224
#                Creative Industries    gd_emp_binary_p75 296   0.0000  0.0000    0.7364   0.0143
#                Creative Industries    gd_bus_binary_p75 295   0.0000  0.0000    0.7458   0.0107
#                            Defence lq_emp_binary_median 296   0.0000  0.0000    0.9223   0.0081
#                            Defence lq_bus_binary_median 296   0.0000  0.0000    0.9865   0.0068
#                            Defence gd_emp_binary_median  46   0.7477  0.0751    0.6733   0.0715
#                            Defence    lq_emp_binary_p75 296   0.0000  0.0000    0.9223   0.0081
#                            Defence    lq_bus_binary_p75 296   0.0000  0.0000    0.9865   0.0068
#                            Defence    gd_emp_binary_p75  46   0.0000  0.0000    0.7400   0.0475
#           Digital and Technologies lq_emp_binary_median 296   0.4633  0.1385    0.7972   0.0418
#           Digital and Technologies lq_bus_binary_median 296   0.7147  0.0160    0.8244   0.0162
#           Digital and Technologies gd_emp_binary_median 295   0.5200  0.0745    0.5186   0.0553
#           Digital and Technologies gd_bus_binary_median 295   0.5930  0.0428    0.5864   0.0410
#           Digital and Technologies    lq_emp_binary_p75 296   0.4633  0.1385    0.7972   0.0418
#           Digital and Technologies    lq_bus_binary_p75 296   0.7147  0.0160    0.8244   0.0162
#           Digital and Technologies    gd_emp_binary_p75 295   0.1867  0.0813    0.7695   0.0173
#           Digital and Technologies    gd_bus_binary_p75 295   0.0694  0.0569    0.7458   0.0152
#                 Financial Services lq_emp_binary_median 296   0.0000  0.0000    0.8581   0.0077
#                 Financial Services lq_bus_binary_median 296   0.1629  0.1485    0.8244   0.0131
#                 Financial Services gd_emp_binary_median 295   0.5366  0.0511    0.4949   0.0392
#                 Financial Services gd_bus_binary_median 295   0.6198  0.0555    0.6203   0.0657
#                 Financial Services    lq_emp_binary_p75 296   0.0000  0.0000    0.8581   0.0077
#                 Financial Services    lq_bus_binary_p75 296   0.1629  0.1485    0.8244   0.0131
#                 Financial Services    gd_emp_binary_p75 295   0.0000  0.0000    0.7390   0.0173
#                 Financial Services    gd_bus_binary_p75 295   0.0250  0.0500    0.7525   0.0083
#                      Life Sciences lq_emp_binary_median 296   0.0500  0.0612    0.7466   0.0153
#                      Life Sciences lq_bus_binary_median 296   0.1709  0.1265    0.7804   0.0322
#                      Life Sciences gd_emp_binary_median 280   0.5254  0.0448    0.5179   0.0452
#                      Life Sciences gd_bus_binary_median 235   0.8230  0.0110    0.7021   0.0135
#                      Life Sciences    lq_emp_binary_p75 296   0.0500  0.0612    0.7466   0.0153
#                      Life Sciences    lq_bus_binary_p75 296   0.1709  0.1265    0.7804   0.0322
#                      Life Sciences    gd_emp_binary_p75 280   0.0987  0.0895    0.7571   0.0087
#                      Life Sciences    gd_bus_binary_p75 235   0.2048  0.0667    0.7702   0.0208
# Professional and Business Services lq_emp_binary_median 296   0.5046  0.1532    0.8512   0.0437
# Professional and Business Services lq_bus_binary_median 296   0.7792  0.0317    0.8682   0.0201
# Professional and Business Services gd_emp_binary_median 296   0.5854  0.0443    0.5912   0.0286
# Professional and Business Services gd_bus_binary_median 296   0.6082  0.0374    0.6047   0.0352
# Professional and Business Services    lq_emp_binary_p75 296   0.5046  0.1532    0.8512   0.0437
# Professional and Business Services    lq_bus_binary_p75 296   0.7792  0.0317    0.8682   0.0201
# Professional and Business Services    gd_emp_binary_p75 296   0.0250  0.0500    0.7499   0.0084
# Professional and Business Services    gd_bus_binary_p75 296   0.0517  0.0633    0.7533   0.0178
#
# ✅ Tablas de comparación exportadas:
#    rf_regression_summary.csv
#    rf_classification_summary.csv

# %%
# ─────────────────────────────────────────────
# FEATURE IMPORTANCE — formato pivotado por sector
# Una hoja por sector, columnas = dep_vars
# ─────────────────────────────────────────────
from openpyxl import load_workbook
from openpyxl.styles import Font, PatternFill, Alignment
from openpyxl.utils import get_column_letter
import pandas as pd

TOP_N = 5

dep_vars_reg = ["lq_emp", "lq_bus", "gd_emp", "gd_bus"]
dep_vars_clf = ["lq_emp_binary", "lq_bus_binary", "gd_emp_binary", "gd_bus_binary"]

def build_pivot_for_sector(group_fi, sector, dep_reg, dep_clf, top_n=5):
    """
    Construye la tabla pivotada para un sector:
    filas = top features (union de todas las dep_vars)
    columnas = dep_vars
    separadas en bloque REGRESSION y CLASSIFICATION
    """
    rows = []

    for block_label, dep_list in [("REGRESSION", dep_reg), ("CLASSIFICATION", dep_clf)]:
        # Filtrar sector y dep_vars del bloque
        block_fi = group_fi[
            (group_fi["sector"] == sector) &
            (group_fi["dep_var"].isin(dep_list))
        ]
        if block_fi.empty:
            continue

        # Top N features por dep_var
        top_features = (
            block_fi
            .sort_values("importance", ascending=False)
            .groupby("dep_var")
            .head(top_n)
        )

        # Pivot: filas=feature, columnas=dep_var, valores=importance
        pivot = top_features.pivot_table(
            index="feature",
            columns="dep_var",
            values="importance",
            aggfunc="first"
        ).reindex(columns=dep_list)  # orden fijo de columnas

        # Eliminar filas donde todos son NaN
        pivot = pivot.dropna(how="all")
        pivot = pivot.reset_index()
        pivot.columns.name = None

        # Agregar fila de encabezado del bloque
        rows.append({"block": block_label, "data": pivot})

    return rows

for group_name in ["full", "theory"]:
    group_fi = fi_df[fi_df["group"] == group_name].copy()

    with pd.ExcelWriter(f"feature_importance_{group_name}.xlsx", engine="openpyxl") as writer:

        for sector in sorted(group_fi["sector"].unique()):
            blocks = build_pivot_for_sector(
                group_fi, sector, dep_vars_reg, dep_vars_clf, TOP_N
            )
            if not blocks:
                continue

            # ── Escribir hoja ──
            sheet_name = sector[:31]
            workbook   = writer.book
            worksheet  = workbook.create_sheet(title=sheet_name)

            # Estilos
            header_font    = Font(bold=True, color="FFFFFF")
            header_fill    = PatternFill("solid", fgColor="2F5496")  # azul oscuro
            section_fill   = PatternFill("solid", fgColor="D9E1F2")  # azul claro
            center_align   = Alignment(horizontal="center")

            # Título del sector
            worksheet.cell(row=1, column=1, value=f"Sector: {sector}").font = Font(bold=True, size=12)

            current_row = 2

            for block in blocks:
                label = block["block"]
                pivot = block["data"]
                cols  = pivot.columns.tolist()  # ["feature"] + dep_vars

                # ── Fila etiqueta bloque (REGRESSION / CLASSIFICATION) ──
                cell = worksheet.cell(row=current_row, column=1, value=label)
                cell.font = Font(bold=True, color="FFFFFF")
                cell.fill = header_fill
                cell.alignment = center_align
                worksheet.merge_cells(
                    start_row=current_row, start_column=1,
                    end_row=current_row,   end_column=len(cols)
                )
                current_row += 1

                # ── Fila de encabezados de columnas ──
                for col_idx, col_name in enumerate(cols, start=1):
                    cell = worksheet.cell(row=current_row, column=col_idx, value=col_name)
                    cell.font = Font(bold=True)
                    cell.fill = section_fill
                    cell.alignment = center_align
                current_row += 1

                # ── Filas de datos ──
                for _, data_row in pivot.iterrows():
                    for col_idx, col_name in enumerate(cols, start=1):
                        val = data_row[col_name]
                        # Redondear importancias, dejar NaN como vacío
                        if col_name != "feature" and pd.notna(val):
                            val = round(float(val), 4)
                        elif pd.isna(val):
                            val = None
                        worksheet.cell(row=current_row, column=col_idx, value=val)
                    current_row += 1

                current_row += 1  # fila vacía entre bloques

            # ── Ajustar ancho de columnas ──
            for col_idx in range(1, len(dep_vars_reg) + 2):
                col_letter = get_column_letter(col_idx)
                worksheet.column_dimensions[col_letter].width = 28 if col_idx == 1 else 14

    print(f"✅ Exportado: feature_importance_{group_name}.xlsx")
# Out:
# ✅ Exportado: feature_importance_full.xlsx
# ✅ Exportado: feature_importance_theory.xlsx

# %%
print(fi_df.columns.tolist())
print(fi_df.shape)
print(fi_df.head())
# Out:
# ['group', 'threshold_scheme', 'sector', 'dep_var', 'model_type', 'feature', 'importance']
# (2511, 7)
#   group threshold_scheme                  sector dep_var  model_type  \
# 0  full              all  Advanced Manufacturing  lq_emp  regression
# 1  full              all  Advanced Manufacturing  lq_emp  regression
# 2  full              all  Advanced Manufacturing  lq_emp  regression
# 3  full              all  Advanced Manufacturing  lq_emp  regression
# 4  full              all  Advanced Manufacturing  lq_emp  regression
#
#                        feature  importance
# 0        enterprise_birth_rate    0.007859
# 1        enterprise_death_rate    0.003071
# 2  enterprise_high_growth_rate    0.003649
# 3                    broadband    0.003990
# 4                  coverage_4g    0.003730

# %%
print(fi_df.columns.tolist())
# Out:
# ['group', 'threshold_scheme', 'sector', 'dep_var', 'model_type', 'feature', 'importance']

# %%
# summary for lq_emp regression

print("\n── TOP 5 FEATURES por sector (regresión lq_emp) ──────────")
top_fi_lqemp = (
    fi_df[(fi_df["dep_var"] == "lq_emp") & (fi_df["model_type"] == "regression")]
    .sort_values(["sector", "importance"], ascending=[True, False])
    .groupby("sector")
    .head(5)[["sector", "feature", "importance"]]
    .sort_values(["sector", "importance"], ascending=[True, False])
)
print(top_fi_lqemp.to_string(index=False))
# Out:
# ── TOP 5 FEATURES por sector (regresión lq_emp) ──────────
#                             sector                     feature  importance
#             Advanced Manufacturing            size_large_share    0.673170
#             Advanced Manufacturing apprenticeship_achievements    0.255312
#             Advanced Manufacturing       housing_net_additions    0.200893
#             Advanced Manufacturing       apprenticeship_starts    0.146387
#             Advanced Manufacturing apprenticeship_achievements    0.097874
#                Creative Industries       transport_to_employer    0.324773
#                Creative Industries apprenticeship_achievements    0.321999
#                Creative Industries            size_large_share    0.295908
#                Creative Industries       apprenticeship_starts    0.257758
#                Creative Industries                  nvq_level3    0.195257
#                            Defence             related_variety    0.454971
#                            Defence             related_variety    0.451767
#                            Defence       enterprise_birth_rate    0.123140
#                            Defence       enterprise_birth_rate    0.103946
#                            Defence enterprise_high_growth_rate    0.101017
#           Digital and Technologies            size_large_share    0.544070
#           Digital and Technologies                  nvq_level3    0.342251
#           Digital and Technologies enterprise_high_growth_rate    0.246149
#           Digital and Technologies             related_variety    0.108204
#           Digital and Technologies                  gcse_age19    0.097456
#                 Financial Services            size_large_share    0.601806
#                 Financial Services enterprise_high_growth_rate    0.318474
#                 Financial Services             related_variety    0.119954
#                 Financial Services            size_micro_share    0.089765
#                 Financial Services                  nvq_level3    0.087351
#                      Life Sciences            fe_participation    0.200811
#                      Life Sciences             related_variety    0.175417
#                      Life Sciences                  gcse_age19    0.164684
#                      Life Sciences            size_micro_share    0.161066
#                      Life Sciences            fe_participation    0.130347
# Professional and Business Services enterprise_high_growth_rate    0.263891
# Professional and Business Services            size_large_share    0.253430
# Professional and Business Services       apprenticeship_starts    0.228635
# Professional and Business Services                  gcse_age19    0.175182
# Professional and Business Services       apprenticeship_starts    0.160362

# %% [markdown]
# # For growth

# %% [markdown]
# # Export Comparative tables

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
from openpyxl.utils import get_column_letter

# ── Configuración ──────────────────────────────────────────────
OUTPUT_FILE = "feature_importance_por_sector_full_data.xlsx"

DEP_VARS  = ["lq_emp", "lq_bus", "gd_emp", "gd_bus"]
MOD_TYPES = ["regression", "classification"]
TOP_N     = 5

# Renombrar cagr -> gd en dep_var (por si acaso no se hizo antes)
fi_df["dep_var"] = fi_df["dep_var"].str.replace("cagr", "gd")

# Colores por model_type
COLORS = {
    "regression":     {"header": "1F4E79", "subheader": "BDD7EE", "alt": "EBF3FB"},
    "classification": {"header": "375623", "subheader": "C6EFCE", "alt": "EBF5EB"},
}

thin  = Side(style="thin",   color="CCCCCC")
thick = Side(style="medium", color="888888")
BORDER     = Border(left=thin,  right=thin,  top=thin,  bottom=thin)
BORDER_BOT = Border(left=thin,  right=thin,  top=thin,  bottom=thick)


# ── Helpers ────────────────────────────────────────────────────
def style_cell(cell, bold=False, bg=None, font_color="000000",
               align="center", wrap=False, border=BORDER, size=10):
    if bg:
        cell.fill = PatternFill("solid", fgColor=bg)
    cell.font      = Font(bold=bold, color=font_color, name="Calibri", size=size)
    cell.alignment = Alignment(horizontal=align, vertical="center", wrap_text=wrap)
    cell.border    = border


def build_pivot(fi_df, model_type, sector):
    mask = (
        (fi_df["model_type"] == model_type) &
        (fi_df["sector"]     == sector)
    )
    sub = fi_df[mask].copy()

    top = (
        sub.sort_values("importance", ascending=False)
           .groupby("dep_var")
           .head(TOP_N)
    )

    if top.empty:
        return pd.DataFrame(columns=DEP_VARS)

    pivot = (
        top.pivot_table(
            index="feature",
            columns="dep_var",
            values="importance",
            aggfunc="first"
        )
        .reindex(columns=[d for d in DEP_VARS if d in top["dep_var"].unique()])
    )

    pivot["_max"] = pivot.max(axis=1)
    pivot = pivot.sort_values("_max", ascending=False).drop(columns="_max")

    return pivot


# ── Escritura de una tabla (regression o classification) ───────
def write_table(ws, pivot, model_type, start_row, start_col=1):
    c  = COLORS[model_type]
    hc, shc, alt = c["header"], c["subheader"], c["alt"]

    dep_vars_present = list(pivot.columns)
    n_cols = 1 + len(dep_vars_present)

    end_col = start_col + n_cols - 1
    ws.merge_cells(
        start_row=start_row, start_column=start_col,
        end_row=start_row,   end_column=end_col
    )
    title = ws.cell(start_row, start_col, model_type.upper())
    style_cell(title, bold=True, bg=hc, font_color="FFFFFF",
               align="center", size=11)
    ws.row_dimensions[start_row].height = 20

    h_row = start_row + 1
    feat_h = ws.cell(h_row, start_col, "Feature")
    style_cell(feat_h, bold=True, bg=shc, align="left")
    ws.row_dimensions[h_row].height = 16

    for j, dv in enumerate(dep_vars_present):
        dv_h = ws.cell(h_row, start_col + 1 + j, dv)
        style_cell(dv_h, bold=True, bg=shc, align="center")

    for r_idx, (feat, row) in enumerate(pivot.iterrows()):
        data_row = h_row + 1 + r_idx
        bg = alt if r_idx % 2 == 0 else "FFFFFF"
        ws.row_dimensions[data_row].height = 15

        f_cell = ws.cell(data_row, start_col, feat)
        style_cell(f_cell, bg=bg, align="left")

        for j, dv in enumerate(dep_vars_present):
            val = row.get(dv)
            cell = ws.cell(data_row, start_col + 1 + j)
            if pd.notna(val):
                cell.value = round(float(val), 4)
                cell.number_format = "0.0000"
                style_cell(cell, bg=bg, align="center")
            else:
                cell.value = ""
                style_cell(cell, bg="F0F0F0", align="center")

    last_row = h_row + len(pivot)
    return last_row


# ── Exportación principal ──────────────────────────────────────
def export_feature_importance(fi_df, output_file=OUTPUT_FILE):
    sectors = sorted(fi_df["sector"].unique())

    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        for sector in sectors:
            sheet_name = str(sector)[:31]
            ws = writer.book.create_sheet(title=sheet_name)
            ws.sheet_view.showGridLines = False

            ws.merge_cells("A1:F1")
            t = ws["A1"]
            t.value = f"Sector: {sector}"
            style_cell(t, bold=True, bg="2E2E2E", font_color="FFFFFF",
                       align="center", size=13)
            ws.row_dimensions[1].height = 26

            current_row = 3

            for mt in MOD_TYPES:
                pivot = build_pivot(fi_df, mt, sector)

                if pivot.empty:
                    ws.cell(current_row, 1,
                            f"Sin datos para {mt} en este sector")
                    current_row += 2
                    continue

                last = write_table(ws, pivot, mt,
                                   start_row=current_row, start_col=1)
                current_row = last + 3

            ws.column_dimensions["A"].width = 30
            for j in range(len(DEP_VARS)):
                ws.column_dimensions[get_column_letter(2 + j)].width = 14

        if "Sheet" in writer.book.sheetnames:
            del writer.book["Sheet"]

    print(f"✅ Exportado: {output_file}  ({len(sectors)} sectores)")


# ── Llamada ────────────────────────────────────────────────────
export_feature_importance(fi_df)
# Out:
# ✅ Exportado: feature_importance_por_sector_full_data.xlsx  (7 sectores)

# %%
reg  = pd.read_csv("rf_comparison_regression.csv")
clf  = pd.read_csv("rf_comparison_classification.csv")

print("── REGRESIÓN ──")
print(reg[["sector","dep_var","R2_mean_full","R2_mean_theory","R2_winner"]].to_string(index=False))

print("\n── CLASIFICACIÓN ──")
print(clf[["sector","dep_var","F1_mean_full","F1_mean_theory","F1_winner"]].to_string(index=False))
# Out:
# ── REGRESIÓN ──
#                             sector dep_var  R2_mean_full  R2_mean_theory R2_winner
#             Advanced Manufacturing  gd_bus        0.0619          0.0301      full
#             Advanced Manufacturing  gd_emp       -0.0400         -0.0505      full
#             Advanced Manufacturing  lq_bus        0.5214          0.4340      full
#             Advanced Manufacturing  lq_emp        0.3858          0.0682      full
#                Creative Industries  gd_bus        0.1079          0.0426      full
#                Creative Industries  gd_emp        0.0516          0.0482      full
#                Creative Industries  lq_bus        0.7570          0.6877      full
#                Creative Industries  lq_emp        0.6341          0.4745      full
#                            Defence  gd_emp       -0.5431         -0.6064      full
#                            Defence  lq_bus       -0.2215         -0.2600      full
#                            Defence  lq_emp       -3.0207         -3.0487      full
#           Digital and Technologies  gd_bus        0.0564          0.0172      full
#           Digital and Technologies  gd_emp        0.0672          0.0351      full
#           Digital and Technologies  lq_bus        0.6281          0.5631      full
#           Digital and Technologies  lq_emp        0.5068          0.2835      full
#                 Financial Services  gd_bus        0.1258          0.1257      full
#                 Financial Services  gd_emp       -0.0646         -0.0759      full
#                 Financial Services  lq_bus        0.1570          0.0487      full
#                 Financial Services  lq_emp        0.0917         -0.3747      full
#                      Life Sciences  gd_bus        0.1940          0.0193      full
#                      Life Sciences  gd_emp       -0.0238         -0.0469      full
#                      Life Sciences  lq_bus        0.2203          0.1001      full
#                      Life Sciences  lq_emp        0.0134         -0.0119      full
# Professional and Business Services  gd_bus        0.0284          0.0045      full
# Professional and Business Services  gd_emp        0.0040          0.0109    theory
# Professional and Business Services  lq_bus        0.6327          0.5753      full
# Professional and Business Services  lq_emp        0.4115          0.2600      full
#
# ── CLASIFICACIÓN ──
#                             sector       dep_var  F1_mean_full  F1_mean_theory F1_winner
#             Advanced Manufacturing gd_bus_binary        0.5720          0.5599      full
#             Advanced Manufacturing gd_emp_binary        0.4878          0.4639      full
#             Advanced Manufacturing lq_bus_binary        0.7923          0.7380      full
#             Advanced Manufacturing lq_emp_binary        0.7157          0.7068      full
#                Creative Industries gd_bus_binary        0.5933          0.5365      full
#                Creative Industries gd_emp_binary        0.5986          0.5606      full
#                Creative Industries lq_bus_binary        0.8098          0.7805      full
#                Creative Industries lq_emp_binary        0.5911          0.5651      full
#                            Defence gd_emp_binary        0.7329          0.7477    theory
#                            Defence lq_bus_binary        0.0000          0.0000      full
#                            Defence lq_emp_binary        0.0000          0.0000      full
#           Digital and Technologies gd_bus_binary        0.6452          0.5930      full
#           Digital and Technologies gd_emp_binary        0.5278          0.5200      full
#           Digital and Technologies lq_bus_binary        0.7271          0.7147      full
#           Digital and Technologies lq_emp_binary        0.5423          0.4633      full
#                 Financial Services gd_bus_binary        0.6280          0.6198      full
#                 Financial Services gd_emp_binary        0.5462          0.5366      full
#                 Financial Services lq_bus_binary        0.2105          0.1629      full
#                 Financial Services lq_emp_binary        0.1600          0.0000      full
#                      Life Sciences gd_bus_binary        0.8405          0.8230      full
#                      Life Sciences gd_emp_binary        0.5324          0.5254      full
#                      Life Sciences lq_bus_binary        0.4941          0.1709      full
#                      Life Sciences lq_emp_binary        0.0485          0.0500    theory
# Professional and Business Services gd_bus_binary        0.6373          0.6082      full
# Professional and Business Services gd_emp_binary        0.5695          0.5854    theory
# Professional and Business Services lq_bus_binary        0.8056          0.7792      full
# Professional and Business Services lq_emp_binary        0.4680          0.5046    theory

# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
from openpyxl.utils import get_column_letter

# ─────────────────────────────────────────────
# DATOS
# ─────────────────────────────────────────────
reg = pd.read_csv("rf_comparison_regression.csv")
clf = pd.read_csv("rf_comparison_classification.csv")

# ─────────────────────────────────────────────
# UMBRALES Y COLORES
# ─────────────────────────────────────────────
# Regresión R²
def r2_fill(val):
    if pd.isna(val):
        return PatternFill("solid", fgColor="D9D9D9")  # gris
    if val >= 0.30:
        return PatternFill("solid", fgColor="C6EFCE")  # verde
    if val >= 0.10:
        return PatternFill("solid", fgColor="FFEB9C")  # amarillo
    return PatternFill("solid", fgColor="FFC7CE")      # rojo

# Clasificación F1
def f1_fill(val):
    if pd.isna(val):
        return PatternFill("solid", fgColor="D9D9D9")
    if val >= 0.65:
        return PatternFill("solid", fgColor="C6EFCE")  # verde
    if val >= 0.50:
        return PatternFill("solid", fgColor="FFEB9C")  # amarillo
    return PatternFill("solid", fgColor="FFC7CE")      # rojo

# Estilos generales
bold          = Font(bold=True)
white_bold    = Font(bold=True, color="FFFFFF")
header_fill   = PatternFill("solid", fgColor="2F5496")
section_fill  = PatternFill("solid", fgColor="D9E1F2")
center        = Alignment(horizontal="center", vertical="center", wrap_text=True)
left          = Alignment(horizontal="left",   vertical="center")
thin_border   = Border(
    left=Side(style="thin"), right=Side(style="thin"),
    top=Side(style="thin"),  bottom=Side(style="thin")
)

# ─────────────────────────────────────────────
# HELPER: escribir celda con estilo
# ─────────────────────────────────────────────
def write_cell(ws, row, col, value, font=None, fill=None, alignment=None, border=None):
    cell = ws.cell(row=row, column=col, value=value)
    if font:      cell.font      = font
    if fill:      cell.fill      = fill
    if alignment: cell.alignment = alignment
    if border:    cell.border    = border
    return cell

# ─────────────────────────────────────────────
# CONSTRUIR EXCEL
# ─────────────────────────────────────────────
wb = Workbook()
wb.remove(wb.active)  # quitar hoja vacía default

sectors = sorted(reg["sector"].unique())

for sector in sectors:
    ws = wb.create_sheet(title=sector[:31])

    reg_s = reg[reg["sector"] == sector].copy()
    clf_s = clf[clf["sector"] == sector].copy()

    # ── TÍTULO ──────────────────────────────
    ws.merge_cells("A1:E1")
    write_cell(ws, 1, 1, f"Sector: {sector}",
               font=Font(bold=True, size=13, color="FFFFFF"),
               fill=PatternFill("solid", fgColor="1F3864"),
               alignment=center)
    ws.row_dimensions[1].height = 22

    # ── LEYENDA ─────────────────────────────
    ws.merge_cells("A2:E2")
    write_cell(ws, 2, 1,
               "🟢 Bueno (R²≥0.30 / F1≥0.65)   🟡 Marginal (R²0.10–0.29 / F1 0.50–0.64)   🔴 No recomendado",
               font=Font(italic=True, size=9),
               alignment=center)
    ws.row_dimensions[2].height = 18

    current_row = 3

    # ════════════════════════════════════════
    # BLOQUE REGRESIÓN
    # ════════════════════════════════════════
    ws.merge_cells(f"A{current_row}:E{current_row}")
    write_cell(ws, current_row, 1, "REGRESIÓN — R² (CV medio)",
               font=white_bold, fill=header_fill, alignment=center)
    ws.row_dimensions[current_row].height = 18
    current_row += 1

    # Encabezados regresión
    reg_headers = ["Variable dependiente", "R² Full", "R² Theory", "Mejor grupo", "Valoración"]
    for col_idx, h in enumerate(reg_headers, start=1):
        write_cell(ws, current_row, col_idx, h,
                   font=bold, fill=section_fill,
                   alignment=center, border=thin_border)
    ws.row_dimensions[current_row].height = 16
    current_row += 1

    # Filas regresión
    for _, row_data in reg_s.iterrows():
        dep      = row_data["dep_var"]
        r2_full  = row_data["R2_mean_full"]
        r2_theory= row_data["R2_mean_theory"]
        winner   = row_data["R2_winner"]
        best_r2  = max(r2_full, r2_theory)

        # Valoración textual
        if best_r2 >= 0.30:
            valoracion = "✅ Recomendado"
        elif best_r2 >= 0.10:
            valoracion = "⚠️ Marginal"
        else:
            valoracion = "❌ No usar"

        write_cell(ws, current_row, 1, dep,        alignment=left,   border=thin_border)
        write_cell(ws, current_row, 2, round(r2_full,   4) if pd.notna(r2_full)   else "—",
                   fill=r2_fill(r2_full),   alignment=center, border=thin_border)
        write_cell(ws, current_row, 3, round(r2_theory, 4) if pd.notna(r2_theory) else "—",
                   fill=r2_fill(r2_theory), alignment=center, border=thin_border)
        write_cell(ws, current_row, 4, winner,     alignment=center, border=thin_border)
        write_cell(ws, current_row, 5, valoracion,
                   fill=r2_fill(best_r2),   alignment=center, border=thin_border)
        current_row += 1

    current_row += 1  # espacio

    # ════════════════════════════════════════
    # BLOQUE CLASIFICACIÓN
    # ════════════════════════════════════════
    ws.merge_cells(f"A{current_row}:E{current_row}")
    write_cell(ws, current_row, 1, "CLASIFICACIÓN — F1 (CV medio)",
               font=white_bold, fill=header_fill, alignment=center)
    ws.row_dimensions[current_row].height = 18
    current_row += 1

    # Encabezados clasificación
    clf_headers = ["Variable dependiente", "F1 Full", "F1 Theory", "Mejor grupo", "Valoración"]
    for col_idx, h in enumerate(clf_headers, start=1):
        write_cell(ws, current_row, col_idx, h,
                   font=bold, fill=section_fill,
                   alignment=center, border=thin_border)
    ws.row_dimensions[current_row].height = 16
    current_row += 1

    # Filas clasificación
    for _, row_data in clf_s.iterrows():
        dep      = row_data["dep_var"]
        f1_full  = row_data["F1_mean_full"]
        f1_theory= row_data["F1_mean_theory"]
        winner   = row_data["F1_winner"]
        best_f1  = max(f1_full, f1_theory)

        if best_f1 >= 0.65:
            valoracion = "✅ Recomendado"
        elif best_f1 >= 0.50:
            valoracion = "⚠️ Marginal"
        else:
            valoracion = "❌ No usar"

        write_cell(ws, current_row, 1, dep,         alignment=left,   border=thin_border)
        write_cell(ws, current_row, 2, round(f1_full,   4) if pd.notna(f1_full)   else "—",
                   fill=f1_fill(f1_full),   alignment=center, border=thin_border)
        write_cell(ws, current_row, 3, round(f1_theory, 4) if pd.notna(f1_theory) else "—",
                   fill=f1_fill(f1_theory), alignment=center, border=thin_border)
        write_cell(ws, current_row, 4, winner,      alignment=center, border=thin_border)
        write_cell(ws, current_row, 5, valoracion,
                   fill=f1_fill(best_f1),   alignment=center, border=thin_border)
        current_row += 1

    # ── Ajustar anchos ───────────────────────
    col_widths = [32, 12, 12, 14, 18]
    for i, w in enumerate(col_widths, start=1):
        ws.column_dimensions[get_column_letter(i)].width = w

wb.save("rf_model_quality_summary.xlsx")
print("✅ Exportado: rf_model_quality_summary.xlsx")
# Out:
# ✅ Exportado: rf_model_quality_summary.xlsx

# %%
import pandas as pd
import numpy as np
from openpyxl import Workbook
from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
from openpyxl.utils import get_column_letter

# ─────────────────────────────────────────────
# CODEBOOK
# ─────────────────────────────────────────────
cb = pd.read_excel("PP422_Variable_Codebook.xlsx")
cb = cb[["variable", "group", "definition"]].dropna(subset=["variable"])
cb["variable"] = cb["variable"].str.strip()
codebook = cb.set_index("variable").to_dict(orient="index")

def get_meta(feature, field):
    entry = codebook.get(feature.strip(), {})
    return entry.get(field, "—")

# ─────────────────────────────────────────────
# RENOMBRAR cagr -> gd
# ─────────────────────────────────────────────
fi_df["dep_var"] = fi_df["dep_var"].str.replace("cagr", "gd")

# ─────────────────────────────────────────────
# UMBRALES
# ─────────────────────────────────────────────
R2_GOOD     = 0.30
R2_MARGINAL = 0.10
F1_GOOD     = 0.65
F1_MARGINAL = 0.50
CUM_THRESH  = 0.80
MIN_FEAT    = 2
MAX_FEAT    = 5

# ─────────────────────────────────────────────
# MÉTRICAS
# ─────────────────────────────────────────────
reg = pd.read_csv("rf_comparison_regression.csv")
clf = pd.read_csv("rf_comparison_classification.csv")

reg["R2_best"] = reg[["R2_mean_full", "R2_mean_theory"]].max(axis=1)
clf["F1_best"] = clf[["F1_mean_full", "F1_mean_theory"]].max(axis=1)

# ─────────────────────────────────────────────
# FEATURE IMPORTANCE
# ─────────────────────────────────────────────
fi = fi_df[fi_df["group"] == "theory"].copy()

def get_top_features(fi_data, sector, dep_var,
                     cum_thresh=CUM_THRESH, min_f=MIN_FEAT, max_f=MAX_FEAT):
    sub = fi_data[
        (fi_data["sector"]  == sector) &
        (fi_data["dep_var"] == dep_var)
    ].sort_values("importance", ascending=False).reset_index(drop=True)
    if sub.empty:
        return pd.DataFrame()
    sub["cumulative"] = sub["importance"].cumsum()
    n = int((sub["cumulative"] < cum_thresh).sum()) + 1
    n = max(min_f, min(n, max_f))
    return sub[["feature", "importance"]].head(n).reset_index(drop=True)

# ─────────────────────────────────────────────
# ESTILOS
# ─────────────────────────────────────────────
FILLS = {
    "good":    PatternFill("solid", fgColor="C6EFCE"),
    "marginal":PatternFill("solid", fgColor="FFEB9C"),
    "bad":     PatternFill("solid", fgColor="FFC7CE"),
    "header":  PatternFill("solid", fgColor="2F5496"),
    "section": PatternFill("solid", fgColor="D9E1F2"),
    "title":   PatternFill("solid", fgColor="1F3864"),
    "feat_bg": PatternFill("solid", fgColor="F2F2F2"),
}

def quality_fill(val, metric="r2"):
    good, marg = (R2_GOOD, R2_MARGINAL) if metric == "r2" else (F1_GOOD, F1_MARGINAL)
    if pd.isna(val) or val < marg: return FILLS["bad"]
    if val < good:                 return FILLS["marginal"]
    return FILLS["good"]

def quality_label(val, metric="r2"):
    good, marg = (R2_GOOD, R2_MARGINAL) if metric == "r2" else (F1_GOOD, F1_MARGINAL)
    if pd.isna(val) or val < marg: return "❌ Not recommended"
    if val < good:                 return "⚠️ Marginal"
    return "✅ Recommended"

thin   = Side(style="thin")
BORDER = Border(left=thin, right=thin, top=thin, bottom=thin)
CENTER = Alignment(horizontal="center", vertical="center", wrap_text=True)
LEFT   = Alignment(horizontal="left",   vertical="center", wrap_text=True)
BOLD   = Font(bold=True)
WHITE_BOLD = Font(bold=True, color="FFFFFF")

def wc(ws, row, col, value, font=None, fill=None, align=None):
    c = ws.cell(row=row, column=col, value=value)
    if font:  c.font      = font
    if fill:  c.fill      = fill
    if align: c.alignment = align
    c.border = BORDER
    return c

# ─────────────────────────────────────────────
# COLUMNAS
# ─────────────────────────────────────────────
HEADERS_REG = ["Dependent Variable", "R² (best)", "Quality",
               "Feature", "Importance", "Cumul.", "Group", "Definition"]
HEADERS_CLF = ["Dependent Variable", "F1 (best)", "Quality",
               "Feature", "Importance", "Cumul.", "Group", "Definition"]
NCOLS = 8

REG_DEPS = ["lq_emp", "lq_bus"]
CLF_DEPS = ["lq_emp_binary", "lq_bus_binary",
            "gd_emp_binary", "gd_bus_binary"]

# ─────────────────────────────────────────────
# HELPER: fila de warning
# ─────────────────────────────────────────────
def write_warning_row(ws, current_row, dep, metric_val, fill_q, label, msg):
    wc(ws, current_row, 1, dep,   align=LEFT)
    wc(ws, current_row, 2,
       round(float(metric_val), 4) if pd.notna(metric_val) else "—",
       fill=fill_q, align=CENTER)
    wc(ws, current_row, 3, label, fill=fill_q, align=CENTER)
    wc(ws, current_row, 4, msg,
       font=Font(italic=True, color="9C0006"),
       fill=FILLS["bad"], align=LEFT)
    for col in range(5, NCOLS + 1):
        wc(ws, current_row, col, "", fill=FILLS["bad"])
    ws.merge_cells(
        start_row=current_row, start_column=4,
        end_row=current_row,   end_column=NCOLS
    )
    return current_row + 1

# ─────────────────────────────────────────────
# HELPER: bloque de features
# ─────────────────────────────────────────────
def write_features_block(ws, current_row, dep, metric_val,
                         fill_q, label, top):
    first_row = current_row
    for i, feat_row in top.iterrows():
        feat = feat_row["feature"]
        imp  = feat_row["importance"]
        cum  = top["importance"].iloc[:i+1].sum()
        grp  = get_meta(feat, "group")
        defn = get_meta(feat, "definition")

        if i == 0:
            wc(ws, current_row, 1, dep, align=LEFT)
            wc(ws, current_row, 2, round(float(metric_val), 4),
               fill=fill_q, align=CENTER)
            wc(ws, current_row, 3, label, fill=fill_q, align=CENTER)
        else:
            wc(ws, current_row, 1, "", align=LEFT)
            wc(ws, current_row, 2, "", fill=fill_q, align=CENTER)
            wc(ws, current_row, 3, "", fill=fill_q, align=CENTER)

        wc(ws, current_row, 4, feat,
           fill=FILLS["feat_bg"], align=LEFT)
        wc(ws, current_row, 5, round(float(imp), 4),
           fill=FILLS["feat_bg"], align=CENTER)
        wc(ws, current_row, 6, f"{cum:.1%}",
           fill=FILLS["feat_bg"], align=CENTER)
        wc(ws, current_row, 7, grp,
           fill=FILLS["feat_bg"], align=LEFT)
        wc(ws, current_row, 8, defn,
           fill=FILLS["feat_bg"], align=LEFT)

        current_row += 1

    if len(top) > 1:
        for col in [1, 2, 3]:
            ws.merge_cells(
                start_row=first_row, start_column=col,
                end_row=current_row - 1, end_column=col
            )
            c = ws.cell(first_row, col)
            c.alignment = LEFT if col == 1 else CENTER
            if col in [2, 3]:
                c.fill = fill_q
            c.border = BORDER

    return current_row

# ─────────────────────────────────────────────
# CONSTRUIR EXCEL
# ─────────────────────────────────────────────
wb = Workbook()
wb.remove(wb.active)

sectors = sorted(fi["sector"].unique())

for sector in sectors:
    ws = wb.create_sheet(title=sector[:31])

    # ── Título ──────────────────────────────
    ws.merge_cells(f"A1:{get_column_letter(NCOLS)}1")
    wc(ws, 1, 1, f"Sector: {sector}",
       font=Font(bold=True, size=13, color="FFFFFF"),
       fill=FILLS["title"], align=CENTER)
    ws.row_dimensions[1].height = 24

    # ── Leyenda ─────────────────────────────
    ws.merge_cells(f"A2:{get_column_letter(NCOLS)}2")
    wc(ws, 2, 1,
       "🟢 Good (R²≥0.30 / F1≥0.65)   "
       "🟡 Marginal (R²0.10–0.29 / F1 0.50–0.64)   "
       "🔴 Not recommended  |  "
       "Features: top 80% cumulative importance (min 2, max 5)",
       font=Font(italic=True, size=9), align=CENTER)
    ws.row_dimensions[2].height = 16

    current_row = 3

    # ════════════════════════════════════════
    # BLOQUE REGRESIÓN
    # ════════════════════════════════════════
    ws.merge_cells(f"A{current_row}:{get_column_letter(NCOLS)}{current_row}")
    wc(ws, current_row, 1, "REGRESSION — Location Quotient (LQ)",
       font=WHITE_BOLD, fill=FILLS["header"], align=CENTER)
    ws.row_dimensions[current_row].height = 18
    current_row += 1

    # Aviso gd
    ws.merge_cells(f"A{current_row}:{get_column_letter(NCOLS)}{current_row}")
    wc(ws, current_row, 1,
       "⚠️  Growth (gd) not shown in regression "
       "— R² ≈ 0 across all sectors. Use binary classification instead.",
       font=Font(italic=True, size=9, color="9C0006"),
       fill=FILLS["bad"], align=CENTER)
    ws.row_dimensions[current_row].height = 16
    current_row += 1

    # Encabezados
    for col, h in enumerate(HEADERS_REG, start=1):
        wc(ws, current_row, col, h,
           font=BOLD, fill=FILLS["section"], align=CENTER)
    ws.row_dimensions[current_row].height = 16
    current_row += 1

    for dep in REG_DEPS:
        r2_row = reg[(reg["sector"] == sector) & (reg["dep_var"] == dep)]
        r2_val = r2_row["R2_best"].values[0] if not r2_row.empty else np.nan
        fill_q = quality_fill(r2_val, "r2")
        label  = quality_label(r2_val, "r2")

        if pd.isna(r2_val) or r2_val < R2_MARGINAL:
            current_row = write_warning_row(
                ws, current_row, dep, r2_val, fill_q, label,
                "❌ Insufficient R² — features not shown"
            )
        else:
            top = get_top_features(fi, sector, dep)
            if not top.empty:
                current_row = write_features_block(
                    ws, current_row, dep, r2_val, fill_q, label, top
                )
            else:
                current_row = write_warning_row(
                    ws, current_row, dep, r2_val, fill_q, label,
                    "⚠️ No feature importance data available"
                )
        current_row += 1

    current_row += 1

    # ════════════════════════════════════════
    # BLOQUE CLASIFICACIÓN
    # ════════════════════════════════════════
    ws.merge_cells(f"A{current_row}:{get_column_letter(NCOLS)}{current_row}")
    wc(ws, current_row, 1, "BINARY CLASSIFICATION — LQ and Growth (gd)",
       font=WHITE_BOLD, fill=FILLS["header"], align=CENTER)
    ws.row_dimensions[current_row].height = 18
    current_row += 1

    # Encabezados
    for col, h in enumerate(HEADERS_CLF, start=1):
        wc(ws, current_row, col, h,
           font=BOLD, fill=FILLS["section"], align=CENTER)
    ws.row_dimensions[current_row].height = 16
    current_row += 1

    for dep in CLF_DEPS:
        f1_row = clf[(clf["sector"] == sector) & (clf["dep_var"] == dep)]
        f1_val = f1_row["F1_best"].values[0] if not f1_row.empty else np.nan
        fill_q = quality_fill(f1_val, "f1")
        label  = quality_label(f1_val, "f1")
        dep_fi = dep.replace("_binary", "")

        if pd.isna(f1_val) or f1_val < F1_MARGINAL:
            current_row = write_warning_row(
                ws, current_row, dep, f1_val, fill_q, label,
                "❌ Insufficient F1 — features not shown"
            )
        else:
            top = get_top_features(fi, sector, dep_fi)
            if not top.empty:
                current_row = write_features_block(
                    ws, current_row, dep, f1_val, fill_q, label, top
                )
            else:
                current_row = write_warning_row(
                    ws, current_row, dep, f1_val, fill_q, label,
                    "⚠️ No feature importance data available"
                )
        current_row += 1

    # ── Ajustar anchos ───────────────────────
    for i, w in enumerate([22, 11, 18, 26, 12, 9, 26, 55], start=1):
        ws.column_dimensions[get_column_letter(i)].width = w

    for row in ws.iter_rows():
        for cell in row:
            if cell.column == 8 and cell.value and len(str(cell.value)) > 80:
                ws.row_dimensions[cell.row].height = 45

wb.save("rf_feature_importance_filtered.xlsx")
print("✅ Exported: rf_feature_importance_filtered.xlsx")
# Out:
# ✅ Exported: rf_feature_importance_filtered.xlsx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# ─────────────────────────────────────────────
# CALCULAR VARIABLES BINARIAS — 3 criterios
# ─────────────────────────────────────────────
gd_vars = ["gd_emp", "gd_bus"]
criterios = {
    "median (p50)": 0.50,
    "p75":          0.75,
    "p90":          0.90,
}

binary_counts = []

for dep in gd_vars:
    if dep not in df.columns:
        print(f"⚠️  {dep} no encontrado en df")
        continue

    y = df[dep].dropna()

    for label, q in criterios.items():
        threshold = y.quantile(q)
        y_bin     = (y >= threshold).astype(int)
        n_ones    = y_bin.sum()
        n_zeros   = len(y_bin) - n_ones
        pct_ones  = n_ones / len(y_bin) * 100

        binary_counts.append({
            "dep_var":   dep,
            "criterio":  label,
            "threshold": round(threshold, 4),
            "n_total":   len(y_bin),
            "n_1":       int(n_ones),
            "n_0":       int(n_zeros),
            "pct_1":     round(pct_ones, 1),
            "pct_0":     round(100 - pct_ones, 1),
        })

counts_df = pd.DataFrame(binary_counts)
print(counts_df.to_string(index=False))

# ─────────────────────────────────────────────
# GRÁFICO
# ─────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle("Binary threshold comparison for growth variables (gd)",
             fontsize=13, fontweight="bold", y=1.02)

colors = {"1 (above threshold)": "#4472C4",
          "0 (below threshold)": "#ED7D31"}

for ax, dep in zip(axes, gd_vars):
    sub = counts_df[counts_df["dep_var"] == dep].reset_index(drop=True)

    x      = np.arange(len(sub))
    width  = 0.35

    bars0 = ax.bar(x - width/2, sub["n_0"], width,
                   label="0 (below threshold)", color="#ED7D31", alpha=0.85)
    bars1 = ax.bar(x + width/2, sub["n_1"], width,
                   label="1 (above threshold)", color="#4472C4", alpha=0.85)

    # Etiquetas encima de cada barra
    for bar, pct in zip(bars0, sub["pct_0"]):
        ax.text(bar.get_x() + bar.get_width()/2,
                bar.get_height() + 3,
                f"{pct:.0f}%", ha="center", va="bottom", fontsize=9)

    for bar, pct in zip(bars1, sub["pct_1"]):
        ax.text(bar.get_x() + bar.get_width()/2,
                bar.get_height() + 3,
                f"{pct:.0f}%", ha="center", va="bottom", fontsize=9)

    # Línea de balance perfecto (50%)
    ax.axhline(len(df[dep].dropna()) * 0.5,
               color="grey", linestyle="--", linewidth=0.8,
               label="50% balance line")

    # Threshold values en x-axis
    xtick_labels = [
        f"{row['criterio']}\n(thr={row['threshold']:.3f})"
        for _, row in sub.iterrows()
    ]
    ax.set_xticks(x)
    ax.set_xticklabels(xtick_labels, fontsize=9)
    ax.set_title(dep, fontsize=11, fontweight="bold")
    ax.set_ylabel("Number of observations")
    ax.set_ylim(0, len(df[dep].dropna()) * 1.15)
    ax.yaxis.set_major_locator(mticker.MaxNLocator(integer=True))
    ax.legend(fontsize=8)
    ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
plt.savefig("gd_binary_threshold_comparison.png", dpi=150, bbox_inches="tight")
plt.show()
print("✅ Guardado: gd_binary_threshold_comparison.png")
# Out:
# dep_var     criterio  threshold  n_total  n_1  n_0  pct_1  pct_0
#  gd_emp median (p50)    -0.0096     1803  902  901   50.0   50.0
#  gd_emp          p75     0.0152     1803  451 1352   25.0   75.0
#  gd_emp          p90     0.0462     1803  181 1622   10.0   90.0
#  gd_bus median (p50)    -0.0023     1713  857  856   50.0   50.0
#  gd_bus          p75     0.0107     1713  429 1284   25.0   75.0
#  gd_bus          p90     0.0269     1713  172 1541   10.0   90.0
# ✅ Guardado: gd_binary_threshold_comparison.png
