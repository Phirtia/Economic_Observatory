# %%
import sys
sys.path.insert(0, "../..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import yaml

# --- Setup ---
with open("../../config.yml", "r") as f:
    config = yaml.safe_load(f)

# --- Load indicators panel ---
panel = pd.read_parquet("../../data/processed_data/analysis_panel.parquet")

# %%
# --- Panel exploration ---
SELECTED_AREA = "South Yorkshire"  # will search for MCA or constituent LADs

print("=== SHAPE ===")
print(panel.shape)

print("\n=== COLUMNS ===")
for c in panel.columns:
    print(c)

print("\n=== DTYPES ===")
print(panel.dtypes)

print("\n=== SAMPLE ROWS (first 3) ===")
print(panel.head(3).to_string())

print("\n=== UNIQUE YEARS (if year column exists) ===")
year_cols = [c for c in panel.columns if "year" in c.lower()]
if year_cols:
    for yc in year_cols:
        print(f"{yc}: {sorted(panel[yc].unique())}")
else:
    print("No obvious year column found")

print("\n=== GEOGRAPHY COLUMNS ===")
geo_cols = [c for c in panel.columns if any(x in c.lower() for x in ["lad", "area", "region", "mca", "name", "code"])]
for gc in geo_cols:
    print(f"{gc}: {panel[gc].nunique()} unique values")
    print(f"  Sample: {panel[gc].unique()[:5]}")

print("\n=== Y COLUMNS ===")
y_cols = [c for c in panel.columns if "lq" in c.lower() or c.startswith("gd_")]
print(y_cols)

print("\n=== SOUTH YORKSHIRE ROWS ===")
# Try to find South Yorkshire in whichever geo column exists
for gc in geo_cols:
    sy_rows = panel[panel[gc].astype(str).str.contains("South Yorkshire|Sheffield|Rotherham|Barnsley|Doncaster", case=False, na=False)]
    if len(sy_rows) > 0:
        print(f"Found via column '{gc}':")
        print(sy_rows[geo_cols + ["IS8_SECTOR"] + y_cols].to_string())
        break
# Out:
# === SHAPE ===
# (16576, 35)
#
# === COLUMNS ===
# YEAR
# GEOGRAPHY_CODE
# GEOGRAPHY_NAME
# IS8_SECTOR
# EMPLOYEES
# BUSINESSES
# unemployment_rate
# transport_to_employer
# drive_to_employer
# cycle_to_employer
# broadband
# coverage_4g
# gcse_age19
# apprenticeship_starts
# apprenticeship_achievements
# nvq_level3
# fe_participation
# housing_net_additions
# enterprise_birth_rate
# enterprise_death_rate
# enterprise_high_growth_rate
# REGION
# COUNTY_UA
# n_universities_feecap_lad
# lq_bus
# emp_share
# lq_emp
# gd_emp
# gd_bus
# n_years_emp
# n_years_bus
# related_variety
# within_sector_diversity
# size_large_share
# size_micro_share
#
# === DTYPES ===
# YEAR                              int16
# GEOGRAPHY_CODE                 category
# GEOGRAPHY_NAME                 category
# IS8_SECTOR                     category
# EMPLOYEES                       float32
# BUSINESSES                      float32
# unemployment_rate               float64
# transport_to_employer           float64
# drive_to_employer               float64
# cycle_to_employer               float64
# broadband                       float64
# coverage_4g                     float64
# gcse_age19                      float64
# apprenticeship_starts           float64
# apprenticeship_achievements     float64
# nvq_level3                      float64
# fe_participation                float64
# housing_net_additions           float64
# enterprise_birth_rate           float64
# enterprise_death_rate           float64
# enterprise_high_growth_rate     float64
# REGION                              str
# COUNTY_UA                           str
# n_universities_feecap_lad         int64
# lq_bus                          Float64
# emp_share                       Float64
# lq_emp                          Float64
# gd_emp                          float64
# gd_bus                          float64
# n_years_emp                       int64
# n_years_bus                       int64
# related_variety                 float64
# within_sector_diversity         float64
# size_large_share                Float64
# size_micro_share                Float64
# dtype: object
#
# === SAMPLE ROWS (first 3) ===
#    YEAR GEOGRAPHY_CODE GEOGRAPHY_NAME              IS8_SECTOR  EMPLOYEES  BUSINESSES  unemployment_rate  transport_to_employer  drive_to_employer  cycle_to_employer  broadband  coverage_4g  gcse_age19  apprenticeship_starts  apprenticeship_achievements  nvq_level3  fe_participation  housing_net_additions  enterprise_birth_rate  enterprise_death_rate  enterprise_high_growth_rate      REGION   COUNTY_UA  n_universities_feecap_lad    lq_bus  emp_share    lq_emp    gd_emp    gd_bus  n_years_emp  n_years_bus  related_variety  within_sector_diversity  size_large_share  size_micro_share
# 0  2016      E06000001     Hartlepool  Advanced Manufacturing     1470.0        25.0                4.6              12.900208           7.790802          10.070582       91.4        99.98   69.560878                 1173.0                        601.0        56.4            9800.0                   11.0               0.115226                0.12963                     0.004115  North East  Hartlepool                          1  0.831374   0.048197  1.648198  0.001431 -0.112731            8            8         1.032564                 1.332179               0.0               1.0
# 1  2016      E06000001     Hartlepool     Creative Industries      450.0       110.0                4.6              12.900208           7.790802          10.070582       91.4        99.98   69.560878                 1173.0                        601.0        56.4            9800.0                   11.0               0.115226                0.12963                     0.004115  North East  Hartlepool                          1  0.337735   0.014754  0.281144  0.044382 -0.014263            8            8         1.032564                 2.200516               0.0               1.0
# 2  2016      E06000001     Hartlepool                 Defence        0.0         0.0                4.6              12.900208           7.790802          10.070582       91.4        99.98   69.560878                 1173.0                        601.0        56.4            9800.0                   11.0               0.115226                0.12963                     0.004115  North East  Hartlepool                          1       0.0        0.0       0.0       NaN       NaN            0            0         1.032564                 0.000000              <NA>              <NA>
#
# === UNIQUE YEARS (if year column exists) ===
# YEAR: [np.int16(2016), np.int16(2017), np.int16(2018), np.int16(2019), np.int16(2020), np.int16(2021), np.int16(2022), np.int16(2023)]
# n_years_emp: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
# n_years_bus: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)]
#
# === GEOGRAPHY COLUMNS ===
# GEOGRAPHY_CODE: 296 unique values
#   Sample: ['E06000001', 'E06000002', 'E06000003', 'E06000004', 'E06000005']
# Categories (296, str): ['E06000001', 'E06000002', 'E06000003', 'E06000004', ..., 'E09000030', 'E09000031', 'E09000032', 'E09000033']
# GEOGRAPHY_NAME: 296 unique values
#   Sample: ['Hartlepool', 'Middlesbrough', 'Redcar and Cleveland', 'Stockton-on-Tees', 'Darlington']
# Categories (296, str): ['Adur', 'Amber Valley', 'Arun', 'Ashfield', ..., 'Wychavon', 'Wyre', 'Wyre Forest', 'York']
# REGION: 9 unique values
#   Sample: <ArrowStringArray>
# [              'North East',               'North West',
#  'Yorkshire and The Humber',            'East Midlands',
#             'West Midlands']
# Length: 5, dtype: str
# n_universities_feecap_lad: 15 unique values
#   Sample: [1 2 0 3 5]
#
# === Y COLUMNS ===
# ['lq_bus', 'lq_emp', 'gd_emp', 'gd_bus']
#
# === SOUTH YORKSHIRE ROWS ===
# Found via column 'GEOGRAPHY_NAME':
#       GEOGRAPHY_CODE GEOGRAPHY_NAME                    REGION  n_universities_feecap_lad                          IS8_SECTOR    lq_bus    lq_emp    gd_emp    gd_bus
# 1694       E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.143196  0.835837 -0.006345  0.016180
# 1695       E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.465651   0.36238 -0.055755  0.001643
# 1696       E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 1697       E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies  0.577248  0.439834 -0.047058 -0.011475
# 1698       E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.688853  0.380979 -0.026024  0.023355
# 1699       E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.535861  0.230616  0.059053 -0.028260
# 1700       E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.607768  0.465259  0.017915  0.009774
# 1701       E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.686251  0.456928 -0.007702  0.021843
# 1702       E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.304916  0.190151 -0.018755  0.012814
# 1703       E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 1704       E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.473926  0.382349  0.004318  0.017981
# 1705       E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.622422  0.331923  0.049730  0.004165
# 1706       E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences  0.683554  0.183362  0.045312 -0.119029
# 1707       E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.862534  0.599353 -0.018023 -0.040344
# 1708       E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.316865  0.916818  0.027096  0.023195
# 1709       E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.438751  0.392903 -0.071056  0.010278
# 1710       E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 1711       E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.632646  0.538206 -0.039822  0.004295
# 1712       E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.765709   0.43731  0.004900 -0.022945
# 1713       E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences   0.91248  0.140922  0.179155 -0.086022
# 1714       E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.616754  0.896661 -0.092609  0.007694
# 1715       E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.047231  0.378247  0.046179 -0.006775
# 1716       E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.821842  0.693912 -0.007500  0.009501
# 1717       E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 1718       E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.851128  0.785156 -0.001327  0.011845
# 1719       E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services  0.916304  1.088274 -0.017864 -0.013585
# 1720       E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences  1.877608  1.838229 -0.005103 -0.042844
# 1721       E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.804152  0.892193 -0.010831  0.015857
# 3766       E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.184478  0.873707 -0.006345  0.016180
# 3767       E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.451156  0.303089 -0.055755  0.001643
# 3768       E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 3769       E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies  0.579476  0.406696 -0.047058 -0.011475
# 3770       E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services   0.66807  0.410192 -0.026024  0.023355
# 3771       E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences    0.5224  0.432242  0.059053 -0.028260
# 3772       E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.603383  0.653573  0.017915  0.009774
# 3773       E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.814251  0.626075 -0.007702  0.021843
# 3774       E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.313147  0.164735 -0.018755  0.012814
# 3775       E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 3776       E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.481359  0.376794  0.004318  0.017981
# 3777       E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.652624  0.422323  0.049730  0.004165
# 3778       E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences   0.68043  0.165009  0.045312 -0.119029
# 3779       E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services   0.79694    0.6443 -0.018023 -0.040344
# 3780       E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.221544  1.232133  0.027096  0.023195
# 3781       E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.440786  0.423794 -0.071056  0.010278
# 3782       E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 3783       E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.668568  0.591037 -0.039822  0.004295
# 3784       E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.798585  0.551522  0.004900 -0.022945
# 3785       E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.440793  0.121227  0.179155 -0.086022
# 3786       E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.614523  0.902066 -0.092609  0.007694
# 3787       E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.432386   0.52365  0.046179 -0.006775
# 3788       E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.826064  0.608422 -0.007500  0.009501
# 3789       E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 3790       E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.871096  0.745802 -0.001327  0.011845
# 3791       E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services  0.901668  1.035154 -0.017864 -0.013585
# 3792       E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences  1.624466  2.011692 -0.005103 -0.042844
# 3793       E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.793309  0.967548 -0.010831  0.015857
# 5838       E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.266245  0.850371 -0.006345  0.016180
# 5839       E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.466747  0.390519 -0.055755  0.001643
# 5840       E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 5841       E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies  0.580368   0.49629 -0.047058 -0.011475
# 5842       E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.667024  0.366482 -0.026024  0.023355
# 5843       E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.508707  0.824777  0.059053 -0.028260
# 5844       E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.603824  0.641163  0.017915  0.009774
# 5845       E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.926852  0.716836 -0.007702  0.021843
# 5846       E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.332779  0.252732 -0.018755  0.012814
# 5847       E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 5848       E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.502404  0.435983  0.004318  0.017981
# 5849       E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.727082  0.529355  0.049730  0.004165
# 5850       E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences   0.35374  0.266968  0.045312 -0.119029
# 5851       E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.666071   0.66289 -0.018023 -0.040344
# 5852       E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.289082  1.347591  0.027096  0.023195
# 5853       E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.462089  0.675272 -0.071056  0.010278
# 5854       E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 5855       E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.682317  0.787407 -0.039822  0.004295
# 5856       E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.803533   0.49224  0.004900 -0.022945
# 5857       E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.427815  0.260848  0.179155 -0.086022
# 5858       E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.608273    0.7096 -0.092609  0.007694
# 5859       E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.290947  0.515767  0.046179 -0.006775
# 5860       E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.835452  0.802355 -0.007500  0.009501
# 5861       E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 5862       E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.862659  0.934335 -0.001327  0.011845
# 5863       E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services   0.90794  1.002074 -0.017864 -0.013585
# 5864       E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences  1.576637  2.954021 -0.005103 -0.042844
# 5865       E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.805289  0.946691 -0.010831  0.015857
# 7910       E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.130474   0.93422 -0.006345  0.016180
# 7911       E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.478415     0.342 -0.055755  0.001643
# 7912       E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 7913       E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies  0.540665  0.498123 -0.047058 -0.011475
# 7914       E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.672558  0.311636 -0.026024  0.023355
# 7915       E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.487295  0.388442  0.059053 -0.028260
# 7916       E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.579222  0.636193  0.017915  0.009774
# 7917       E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.780468  0.739482 -0.007702  0.021843
# 7918       E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.334272  0.193998 -0.018755  0.012814
# 7919       E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 7920       E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.501707  0.453815  0.004318  0.017981
# 7921       E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.745367  0.511574  0.049730  0.004165
# 7922       E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences  0.336424  0.197916  0.045312 -0.119029
# 7923       E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.628822  0.556224 -0.018023 -0.040344
# 7924       E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.425636  1.246345  0.027096  0.023195
# 7925       E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.454748  0.566204 -0.071056  0.010278
# 7926       E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 7927       E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.683004  0.760284 -0.039822  0.004295
# 7928       E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.698169  0.403083  0.004900 -0.022945
# 7929       E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.417877  0.112914  0.179155 -0.086022
# 7930       E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.625964  0.634267 -0.092609  0.007694
# 7931       E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.109533  0.543673  0.046179 -0.006775
# 7932       E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.827539  0.786693 -0.007500  0.009501
# 7933       E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 7934       E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.839168  0.911155 -0.001327  0.011845
# 7935       E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services  0.906526  0.943619 -0.017864 -0.013585
# 7936       E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences  1.512663  1.817758 -0.005103 -0.042844
# 7937       E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.814625  0.864422 -0.010831  0.015857
# 9982       E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.325177  1.128869 -0.006345  0.016180
# 9983       E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.468329  0.228664 -0.055755  0.001643
# 9984       E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 9985       E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies  0.553921  0.315373 -0.047058 -0.011475
# 9986       E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.645907  0.358766 -0.026024  0.023355
# 9987       E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.476429   0.40927  0.059053 -0.028260
# 9988       E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.594249  0.659282  0.017915  0.009774
# 9989       E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.905284  0.591248 -0.007702  0.021843
# 9990       E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.323837  0.164467 -0.018755  0.012814
# 9991       E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 9992       E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.501887  0.358349  0.004318  0.017981
# 9993       E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.715535  0.582788  0.049730  0.004165
# 9994       E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences  0.650937  0.264932  0.045312 -0.119029
# 9995       E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.624323  0.661887 -0.018023 -0.040344
# 9996       E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.233066  1.571911  0.027096  0.023195
# 9997       E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries   0.47346  0.533095 -0.071056  0.010278
# 9998       E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 9999       E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.655987   0.64597 -0.039822  0.004295
# 10000      E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.679276  0.404132  0.004900 -0.022945
# 10001      E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.403012  0.164853  0.179155 -0.086022
# 10002      E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.649668   0.68618 -0.092609  0.007694
# 10003      E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.169096  0.543924  0.046179 -0.006775
# 10004      E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries   0.81962  0.597519 -0.007500  0.009501
# 10005      E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 10006      E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.839042   0.77777 -0.001327  0.011845
# 10007      E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services  0.876138  0.985698 -0.017864 -0.013585
# 10008      E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences   1.49445  1.964786 -0.005103 -0.042844
# 10009      E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.820979  0.994436 -0.010831  0.015857
# 12054      E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.280096   0.92796 -0.006345  0.016180
# 12055      E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.448599  0.234776 -0.055755  0.001643
# 12056      E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 12057      E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies   0.52554  0.350098 -0.047058 -0.011475
# 12058      E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.672233  0.260968 -0.026024  0.023355
# 12059      E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.432997  0.459756  0.059053 -0.028260
# 12060      E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.601945  0.625145  0.017915  0.009774
# 12061      E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.842231  0.577396 -0.007702  0.021843
# 12062      E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.322485  0.191699 -0.018755  0.012814
# 12063      E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 12064      E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies   0.51529  0.397326  0.004318  0.017981
# 12065      E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.680448  0.421717  0.049730  0.004165
# 12066      E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences  0.299882  0.207892  0.045312 -0.119029
# 12067      E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.636462  0.596879 -0.018023 -0.040344
# 12068      E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.269115  1.451915  0.027096  0.023195
# 12069      E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.460171  0.344698 -0.071056  0.010278
# 12070      E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 12071      E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies   0.66179  0.575774 -0.039822  0.004295
# 12072      E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.624116  0.409141  0.004900 -0.022945
# 12073      E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.373289  0.612677  0.179155 -0.086022
# 12074      E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.618665   0.64403 -0.092609  0.007694
# 12075      E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.111773  0.674598  0.046179 -0.006775
# 12076      E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.823494  0.721799 -0.007500  0.009501
# 12077      E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 12078      E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.863495  0.928122 -0.001327  0.011845
# 12079      E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services    0.8634  0.919343 -0.017864 -0.013585
# 12080      E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences  1.224386  2.102651 -0.005103 -0.042844
# 12081      E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.832454  0.943122 -0.010831  0.015857
# 14126      E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing  1.176952  0.770798 -0.006345  0.016180
# 14127      E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.446297   0.30787 -0.055755  0.001643
# 14128      E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 14129      E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies   0.52021  0.322263 -0.047058 -0.011475
# 14130      E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.780411  0.352278 -0.026024  0.023355
# 14131      E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.430608  0.445693  0.059053 -0.028260
# 14132      E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.620973  0.595359  0.017915  0.009774
# 14133      E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.839942  0.601837 -0.007702  0.021843
# 14134      E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries  0.329903   0.17988 -0.018755  0.012814
# 14135      E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 14136      E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.538425  0.388724  0.004318  0.017981
# 14137      E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.683526  0.515396  0.049730  0.004165
# 14138      E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences  0.291133  0.192161  0.045312 -0.119029
# 14139      E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.625195  0.527623 -0.018023 -0.040344
# 14140      E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.352935  1.303281  0.027096  0.023195
# 14141      E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.471986  0.301943 -0.071056  0.010278
# 14142      E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 14143      E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.692123  0.436932 -0.039822  0.004295
# 14144      E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services  0.703409  0.548401  0.004900 -0.022945
# 14145      E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.371246  0.394074  0.179155 -0.086022
# 14146      E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.640114  0.554963 -0.092609  0.007694
# 14147      E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.149804  0.691313  0.046179 -0.006775
# 14148      E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.844101  0.744157 -0.007500  0.009501
# 14149      E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 14150      E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.888428  0.772475 -0.001327  0.011845
# 14151      E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services  0.824789   0.98128 -0.017864 -0.013585
# 14152      E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences  1.346162  1.996543 -0.005103 -0.042844
# 14153      E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.850189  0.900732 -0.010831  0.015857
# 16198      E08000016       Barnsley  Yorkshire and The Humber                          4              Advanced Manufacturing   1.24893  0.759343 -0.006345  0.016180
# 16199      E08000016       Barnsley  Yorkshire and The Humber                          4                 Creative Industries  0.449457  0.231169 -0.055755  0.001643
# 16200      E08000016       Barnsley  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 16201      E08000016       Barnsley  Yorkshire and The Humber                          4            Digital and Technologies  0.519993  0.349977 -0.047058 -0.011475
# 16202      E08000016       Barnsley  Yorkshire and The Humber                          4                  Financial Services  0.752812  0.336864 -0.026024  0.023355
# 16203      E08000016       Barnsley  Yorkshire and The Humber                          4                       Life Sciences  0.433623  0.558702  0.059053 -0.028260
# 16204      E08000016       Barnsley  Yorkshire and The Humber                          4  Professional and Business Services  0.614828  0.592922  0.017915  0.009774
# 16205      E08000017      Doncaster  Yorkshire and The Humber                          1              Advanced Manufacturing  0.869541  0.457059 -0.007702  0.021843
# 16206      E08000017      Doncaster  Yorkshire and The Humber                          1                 Creative Industries   0.34088  0.154752 -0.018755  0.012814
# 16207      E08000017      Doncaster  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 16208      E08000017      Doncaster  Yorkshire and The Humber                          1            Digital and Technologies  0.524718   0.39912  0.004318  0.017981
# 16209      E08000017      Doncaster  Yorkshire and The Humber                          1                  Financial Services  0.640187  0.532749  0.049730  0.004165
# 16210      E08000017      Doncaster  Yorkshire and The Humber                          1                       Life Sciences  0.286806  0.284793  0.045312 -0.119029
# 16211      E08000017      Doncaster  Yorkshire and The Humber                          1  Professional and Business Services  0.630548  0.534976 -0.018023 -0.040344
# 16212      E08000018      Rotherham  Yorkshire and The Humber                          1              Advanced Manufacturing  1.604305  1.291927  0.027096  0.023195
# 16213      E08000018      Rotherham  Yorkshire and The Humber                          1                 Creative Industries  0.454455  0.324691 -0.071056  0.010278
# 16214      E08000018      Rotherham  Yorkshire and The Humber                          1                             Defence       0.0       0.0       NaN       NaN
# 16215      E08000018      Rotherham  Yorkshire and The Humber                          1            Digital and Technologies  0.639205  0.548196 -0.039822  0.004295
# 16216      E08000018      Rotherham  Yorkshire and The Humber                          1                  Financial Services   0.68744  0.569865  0.004900 -0.022945
# 16217      E08000018      Rotherham  Yorkshire and The Humber                          1                       Life Sciences  0.377969   0.38723  0.179155 -0.086022
# 16218      E08000018      Rotherham  Yorkshire and The Humber                          1  Professional and Business Services  0.626241  0.486727 -0.092609  0.007694
# 16219      E08000019      Sheffield  Yorkshire and The Humber                          4              Advanced Manufacturing  1.124493  0.502373  0.046179 -0.006775
# 16220      E08000019      Sheffield  Yorkshire and The Humber                          4                 Creative Industries  0.859752  0.624104 -0.007500  0.009501
# 16221      E08000019      Sheffield  Yorkshire and The Humber                          4                             Defence       0.0       0.0       NaN       NaN
# 16222      E08000019      Sheffield  Yorkshire and The Humber                          4            Digital and Technologies  0.909767  0.807147 -0.001327  0.011845
# 16223      E08000019      Sheffield  Yorkshire and The Humber                          4                  Financial Services   0.80141  0.982434 -0.017864 -0.013585
# 16224      E08000019      Sheffield  Yorkshire and The Humber                          4                       Life Sciences   1.34872  2.076609 -0.005103 -0.042844
# 16225      E08000019      Sheffield  Yorkshire and The Humber                          4  Professional and Business Services  0.857684  0.845229 -0.010831  0.015857

# %%
# ============================================================
# CELL 3 — Correlate scorecard (Step 3)
#
# PURPOSE:
# Describes SY's structural position as a place relative to the
# national distribution across all retained X variables. Answers:
# "what are SY's assets and gaps as a location for IS8 sectors?"
#
# Variables grouped by EEG theoretical category:
#   1. Knowledge Base (Boschma 2005; Asheim & Coenen 2005)
#   2. Entrepreneurial Discovery (Boschma & Frenken 2006)
#   3. Connectivity and Agglomeration Potential (MAR externalities)
#   4. Labour Market Conditions (absorptive capacity)
#   5. Place Attractiveness (talent retention/attraction)
#
# This is place-level, not sector-specific. All LAD-level variables
# are constant across sectors for a given LAD×year, so this block
# is run once for SY as an MCA.
#
# NOTE: Once Phase 1 regression results are available, add a
# sector-specific block here that filters CORRELATE_VARS to the
# significant predictors for each sector. At that point the
# comparison becomes genuinely differentiated by sector.
# ============================================================

# --- Constants (from config) ---
SY_CODES = config["parameters"]["sy_lad_codes"]
SY_NAMES = config["parameters"]["sy_lad_names"]
YEAR     = config["parameters"]["growth_end_year"]

# --- EEG variable groupings ---
EEG_GROUPS = config["parameters"]["eeg_groups"]

# Flat ordered list for extraction — preserves group order
CORRELATE_VARS = [v for group in EEG_GROUPS.values() for v in group]

# --- Step 3a: Extract LAD-level values (one row per LAD) ---
lad_vars = (
    panel[panel["YEAR"] == YEAR]
    .drop_duplicates(subset="GEOGRAPHY_CODE")[["GEOGRAPHY_CODE"] + CORRELATE_VARS]
    .set_index("GEOGRAPHY_CODE")
)

# --- Step 3b: National median across 296 LADs ---
nat_medians = lad_vars[CORRELATE_VARS].median()

# --- Step 3c: SY MCA mean (unweighted across 4 LADs) ---
sy_means = lad_vars.loc[SY_CODES, CORRELATE_VARS].mean()

# --- Step 3d: Build scorecard with percentile rank ---
def build_scorecard(sy_means, nat_medians, lad_vars):
    sc = pd.DataFrame({"SY_mean": sy_means, "nat_median": nat_medians})
    sc["pct_diff"] = np.where(
        sc["nat_median"] == 0, np.nan,
        (sc["SY_mean"] - sc["nat_median"]) / sc["nat_median"] * 100
    )
    sc["percentile"] = [
        int(round((lad_vars[var].dropna() <= sy_means[var]).mean() * 100))
        for var in sc.index
    ]
    sc["position"] = sc.apply(
        lambda r: f"P{int(r['percentile']):02d} ABOVE ▲" if r['percentile'] >= 60
        else (f"P{int(r['percentile']):02d} BELOW ▼" if r['percentile'] <= 40
        else f"P{int(r['percentile']):02d} ~PARITY"),
        axis=1
    )
    return sc

scorecard = build_scorecard(sy_means, nat_medians, lad_vars)

# --- Step 3e: Print grouped by EEG category ---
def print_scorecard_grouped(sc, groups):
    header = f"{'Variable':<35} {'SY mean':>10} {'Nat median':>12} {'% diff':>8}  {'Position':>14}"
    divider = "-" * 85

    for group_name, vars_in_group in groups.items():
        print(f"\n  [{group_name}]")
        print(divider)
        for var in vars_in_group:
            if var not in sc.index:
                continue
            row = sc.loc[var]
            decimals = 4 if max(abs(row["SY_mean"]), abs(row["nat_median"])) < 0.1 else 2
            fmt = f"{{:>10.{decimals}f}}"
            sy_s  = fmt.format(row["SY_mean"])
            nat_s = fmt.format(row["nat_median"])
            pct_s = f"{row['pct_diff']:>8.1f}%" if pd.notna(row["pct_diff"]) else f"{'n/a':>9}"
            print(f"  {var:<33} {sy_s} {nat_s} {pct_s}  {row['position']}")

print(f"\n=== SY MCA STRUCTURAL SCORECARD vs NATIONAL DISTRIBUTION ({YEAR}) ===")
print("(Place-level — sector-specific version pending Phase 1 regression results)")
print("(Percentile rank: proportion of 296 English LADs at or below SY MCA mean)")
print(f"\n{'Variable':<35} {'SY mean':>10} {'Nat median':>12} {'% diff':>8}  {'Position':>14}")
print_scorecard_grouped(scorecard, EEG_GROUPS)
# Out:
# === SY MCA STRUCTURAL SCORECARD vs NATIONAL DISTRIBUTION (2023) ===
# (Place-level — sector-specific version pending Phase 1 regression results)
# (Percentile rank: proportion of 296 English LADs at or below SY MCA mean)
#
# Variable                               SY mean   Nat median   % diff        Position
#
#   [Knowledge Base]
# -------------------------------------------------------------------------------------
#   nvq_level3                             55.08      60.20     -8.5%  P29 BELOW ▼
#   gcse_age19                             70.27      75.20     -6.6%  P20 BELOW ▼
#   apprenticeship_starts                1014.25     945.50      7.3%  P60 ABOVE ▲
#   fe_participation                     5414.75    5002.00      8.3%  P61 ABOVE ▲
#   n_universities_feecap_lad               2.50       1.00    150.0%  P78 ABOVE ▲
#
#   [Entrepreneurial Discovery]
# -------------------------------------------------------------------------------------
#   enterprise_birth_rate                   0.14       0.11     29.0%  P90 ABOVE ▲
#   enterprise_death_rate                   0.12       0.11      8.2%  P67 ABOVE ▲
#   enterprise_high_growth_rate           0.0033     0.0036     -8.4%  P41 ~PARITY
#
#   [Connectivity and Agglomeration Potential]
# -------------------------------------------------------------------------------------
#   transport_to_employer                  11.88      11.32      4.9%  P58 ~PARITY
#   broadband                              77.00      77.60     -0.8%  P48 ~PARITY
#
#   [Labour Market Conditions]
# -------------------------------------------------------------------------------------
#   unemployment_rate                       3.50       3.40      2.9%  P55 ~PARITY
#
#   [Place Attractiveness]
# -------------------------------------------------------------------------------------
#   housing_net_additions                   7.00       9.00    -22.2%  P42 ~PARITY

# %%
# ============================================================
# CELL 4a — Prepare clustering dataset
#
# Cluster on rates/proportions only to avoid size bias.
# CLUSTER_VARS derived from EEG_GROUPS (single source of truth).
# StandardScaler removes scale differences before clustering.
#
# Excluded from EEG_GROUPS / clustering:
#   coverage_4g            — near-ceiling distribution (Q3=100, IQR≈0.18pp)
#   related_variety        — on hold pending rework
#   size_large_share       — sector-level variable
#   size_micro_share       — sector-level variable
# ============================================================

from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
import warnings
warnings.filterwarnings("ignore")

# --- EEG variable groupings (single source of truth) ---
EEG_GROUPS = config["parameters"]["eeg_groups"]

# Derive flat variable list from EEG_GROUPS
CLUSTER_VARS = [v for group in EEG_GROUPS.values() for v in group]

# Extract one row per LAD (all cluster vars are LAD-level)
lad_df = (
    panel[panel["YEAR"] == YEAR]
    .drop_duplicates(subset="GEOGRAPHY_CODE")
    .set_index("GEOGRAPHY_CODE")
    [["GEOGRAPHY_NAME"] + CLUSTER_VARS]
    .copy()
)

# Drop LADs with any missing values in cluster vars
before = len(lad_df)
lad_df = lad_df.dropna(subset=CLUSTER_VARS)
after = len(lad_df)
print(f"LADs retained after dropping missing: {after}/{before}")

# Standardise — essential so no variable dominates by scale
scaler = StandardScaler()
X = scaler.fit_transform(lad_df[CLUSTER_VARS])

print(f"\nClustering on {len(CLUSTER_VARS)} variables across {after} LADs")
print("Variables:", CLUSTER_VARS)
# Out:
# LADs retained after dropping missing: 279/296
#
# Clustering on 12 variables across 279 LADs
# Variables: ['nvq_level3', 'gcse_age19', 'apprenticeship_starts', 'fe_participation', 'n_universities_feecap_lad', 'enterprise_birth_rate', 'enterprise_death_rate', 'enterprise_high_growth_rate', 'transport_to_employer', 'broadband', 'unemployment_rate', 'housing_net_additions']

# %%
# ============================================================
# CELL 4b — Hierarchical clustering + dendrogram
#
# Complete linkage: clusters merged on maximum distance between
# any two points across clusters. Produces compact clusters —
# desirable for peer benchmarking.
# ============================================================

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

FOCUS_SECTORS = [
    "Advanced Manufacturing",
    "Creative Industries",
    "Digital and Technologies",
    "Financial Services",
    "Life Sciences",
    "Professional and Business Services",
]

T_CUT = 5.5  # distance threshold — adjust after inspecting dendrogram

# Build linkage matrix
Z = linkage(X, method="complete", metric="euclidean")

lad_names      = lad_df.index.tolist()
lad_labels     = lad_df["GEOGRAPHY_NAME"].tolist()
sy_indices     = [lad_names.index(c) for c in SY_CODES if c in lad_names]
sy_label_names = [lad_df.loc[c, "GEOGRAPHY_NAME"] for c in SY_CODES if c in lad_names]

# ── Plot 1: Truncated dendrogram (last 30 merges) ──────────────────
fig, ax = plt.subplots(figsize=(14, 5))
dendrogram(
    Z, ax=ax,
    truncate_mode="lastp", p=30,
    leaf_rotation=90, leaf_font_size=8,
    show_contracted=True,
    color_threshold=T_CUT,
)
ax.axhline(y=T_CUT, color="red", linestyle="--", linewidth=1, label=f"T_CUT={T_CUT}")
ax.set_title("Hierarchical clustering — complete linkage (truncated, last 30 merges)")
ax.set_xlabel("LAD (or cluster size in brackets)")
ax.set_ylabel("Distance")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig("../../output/graphs/franco/dendrogram_truncated.png", dpi=150, bbox_inches="tight")
plt.show()

# ── Plot 2: Full dendrogram with SY LADs highlighted ──────────────
fig, ax = plt.subplots(figsize=(28, 6))
ddata = dendrogram(
    Z, ax=ax,
    labels=lad_labels,
    leaf_rotation=90, leaf_font_size=5,
    color_threshold=T_CUT,
)
for lbl in ax.get_xticklabels():
    if lbl.get_text() in sy_label_names:
        lbl.set_color("red")
        lbl.set_fontsize(8)
        lbl.set_fontweight("bold")
ax.axhline(y=T_CUT, color="red", linestyle="--", linewidth=1, label=f"T_CUT={T_CUT}")
ax.set_title("Hierarchical clustering — complete linkage (full tree, SY LADs in red)")
ax.set_ylabel("Distance")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig("../../output/graphs/franco/dendrogram_full.png", dpi=150, bbox_inches="tight")
plt.show()

print("SY LADs positions in leaf order:")
leaf_order = ddata["leaves"]
for idx in sy_indices:
    pos = leaf_order.index(idx)
    print(f"  {lad_df.iloc[idx]['GEOGRAPHY_NAME']}: leaf position {pos}/{len(lad_df)}")
# Out:
# SY LADs positions in leaf order:
#   Barnsley: leaf position 167/279
#   Doncaster: leaf position 245/279
#   Rotherham: leaf position 171/279
#   Sheffield: leaf position 221/279

# %%
labels = fcluster(Z, t=T_CUT, criterion="distance")
lad_df["cluster"] = labels

print(f"Number of clusters: {labels.max()}")
print(f"Singletons: {sum(1 for v in pd.Series(labels).value_counts() if v == 1)}")
print("\nCluster sizes:")
print(pd.Series(labels).value_counts().sort_index())

print("\nSY cluster assignments:")
for code, name in zip(SY_CODES, SY_NAMES):
    if code in lad_df.index:
        print(f"  {name}: Cluster {lad_df.loc[code, 'cluster']} (n={sum(labels == lad_df.loc[code, 'cluster'])})")
# Out:
# Number of clusters: 21
# Singletons: 4
#
# Cluster sizes:
# 1      2
# 2      5
# 3     18
# 4     35
# 5     14
# 6     55
# 7     52
# 8      3
# 9      1
# 10     5
# 11     5
# 12     1
# 13    20
# 14    16
# 15     5
# 16     1
# 17    19
# 18    13
# 19     4
# 20     4
# 21     1
# Name: count, dtype: int64
#
# SY cluster assignments:
#   Barnsley: Cluster 7 (n=52)
#   Doncaster: Cluster 17 (n=19)
#   Rotherham: Cluster 7 (n=52)
#   Sheffield: Cluster 14 (n=16)

# %%
import seaborn as sns

corr = lad_df[CLUSTER_VARS].corr(method="spearman")

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corr, ax=ax, annot=True, fmt=".2f", cmap="RdBu_r",
            center=0, vmin=-1, vmax=1,
            xticklabels=CLUSTER_VARS, yticklabels=CLUSTER_VARS)
ax.set_title("Spearman correlation — clustering variables")
plt.tight_layout()
plt.show()

# %%
# ============================================================
# CELL 4c — Cut the tree and find comparators
#
# Cut the dendrogram at T_CUT. For each SY LAD, identify
# cluster peers and find top performers (by lq_emp) per sector
# within the same cluster.
# ============================================================

# Assign clusters
lad_df["cluster"] = fcluster(Z, t=T_CUT, criterion="distance")

print(f"=== TREE CUT AT t={T_CUT} ===")
print(f"Number of clusters formed: {lad_df['cluster'].nunique()}")
print(f"\nCluster sizes (top 15 largest):")
for cid, cnt in lad_df["cluster"].value_counts().head(15).items():
    print(f"  Cluster {cid}: {cnt} LADs")

print(f"\n=== CLUSTER MEMBERSHIPS — SY LADs ===")
for code in SY_CODES:
    if code in lad_df.index:
        name    = lad_df.loc[code, "GEOGRAPHY_NAME"]
        cluster = lad_df.loc[code, "cluster"]
        size    = (lad_df["cluster"] == cluster).sum()
        print(f"  {name} ({code}): Cluster {cluster}  (n={size} LADs)")

# Build lq_lookup: latest year, one row per LAD×sector
lq_lookup = (
    panel[panel["YEAR"] == YEAR]
    .set_index(["GEOGRAPHY_CODE", "IS8_SECTOR"])[["lq_emp", "lq_bus"]]
)

print(f"\n=== COMPARATOR LADs — same cluster, higher lq_emp (top 5 per sector) ===")
for code in SY_CODES:
    if code not in lad_df.index:
        continue
    name        = lad_df.loc[code, "GEOGRAPHY_NAME"]
    cluster     = lad_df.loc[code, "cluster"]
    cluster_lads = lad_df[lad_df["cluster"] == cluster].index.tolist()

    print(f"\n{'='*60}")
    print(f"{name} (Cluster {cluster}, n={len(cluster_lads)} LADs)")
    print(f"Peers: {[lad_df.loc[c, 'GEOGRAPHY_NAME'] for c in cluster_lads if c != code]}")

    for sector in FOCUS_SECTORS:
        lq_sec = lq_lookup.xs(sector, level="IS8_SECTOR")
        sy_lq  = lq_sec.loc[code, "lq_emp"] if code in lq_sec.index else None

        comparators = (
            lq_sec.reindex(cluster_lads)
            .dropna(subset=["lq_emp"])
            .sort_values("lq_emp", ascending=False)
        )
        comparators = comparators[
            (comparators.index != code) &
            (comparators["lq_emp"] > (float(sy_lq) if sy_lq is not None else 0))
        ].head(5)

        sy_str = f"{float(sy_lq):.2f}" if sy_lq is not None else "N/A"
        print(f"\n  [{sector}] — {name} lq_emp: {sy_str}")
        if len(comparators) == 0:
            print("    No comparators with higher lq_emp in same cluster")
        else:
            print(f"    {'LAD':<30} {'lq_emp':>8} {'lq_bus':>8}")
            for comp_code, comp_row in comparators.iterrows():
                comp_name = lad_df.loc[comp_code, "GEOGRAPHY_NAME"] if comp_code in lad_df.index else comp_code
                print(f"    {comp_name:<30} {float(comp_row['lq_emp']):>8.2f} {float(comp_row['lq_bus']):>8.2f}")
# Out:
# === TREE CUT AT t=5.5 ===
# Number of clusters formed: 21
#
# Cluster sizes (top 15 largest):
#   Cluster 6: 55 LADs
#   Cluster 7: 52 LADs
#   Cluster 4: 35 LADs
#   Cluster 13: 20 LADs
#   Cluster 17: 19 LADs
#   Cluster 3: 18 LADs
#   Cluster 14: 16 LADs
#   Cluster 5: 14 LADs
#   Cluster 18: 13 LADs
#   Cluster 10: 5 LADs
#   Cluster 2: 5 LADs
#   Cluster 11: 5 LADs
#   Cluster 15: 5 LADs
#   Cluster 20: 4 LADs
#   Cluster 19: 4 LADs
#
# === CLUSTER MEMBERSHIPS — SY LADs ===
#   Barnsley (E08000016): Cluster 7  (n=52 LADs)
#   Doncaster (E08000017): Cluster 17  (n=19 LADs)
#   Rotherham (E08000018): Cluster 7  (n=52 LADs)
#   Sheffield (E08000019): Cluster 14  (n=16 LADs)
#
# === COMPARATOR LADs — same cluster, higher lq_emp (top 5 per sector) ===
#
# ============================================================
# Barnsley (Cluster 7, n=52 LADs)
# Peers: ['Redcar and Cleveland', 'Stockton-on-Tees', 'Darlington', 'Warrington', 'North East Lincolnshire', 'North Lincolnshire', 'Derby', 'Telford and Wrekin', 'North Somerset', 'South Gloucestershire', 'Plymouth', 'Torbay', 'Medway', 'Bracknell Forest', 'Milton Keynes', 'Portsmouth', 'Bedford', 'Erewash', 'Basildon', 'Gloucester', 'Havant', 'Rushmoor', 'Gravesham', 'Swale', 'Fylde', 'Preston', 'Charnwood', 'North West Leicestershire', 'Gedling', 'Cannock Chase', 'Newcastle-under-Lyme', 'Tamworth', 'Ipswich', 'Nuneaton and Bedworth', 'Crawley', 'Redditch', 'Stevenage', 'Bury', 'Oldham', 'Tameside', 'Wigan', 'St. Helens', 'Sefton', 'Wirral', 'Rotherham', 'North Tyneside', 'Dudley', 'Bradford', 'Kirklees', 'Wakefield', 'Gateshead']
#
#   [Advanced Manufacturing] — Barnsley lq_emp: 0.76
#     LAD                              lq_emp   lq_bus
#     Fylde                              9.53     1.10
#     Derby                              6.22     1.16
#     South Gloucestershire              4.14     1.27
#     Plymouth                           4.05     0.57
#     Basildon                           3.19     1.15
#
#   [Creative Industries] — Barnsley lq_emp: 0.23
#     LAD                              lq_emp   lq_bus
#     Rushmoor                           2.60     0.96
#     Bracknell Forest                   2.41     1.40
#     North Tyneside                     0.99     0.75
#     Milton Keynes                      0.89     1.35
#     Portsmouth                         0.89     0.65
#
#   [Digital and Technologies] — Barnsley lq_emp: 0.35
#     LAD                              lq_emp   lq_bus
#     Rushmoor                           3.85     1.37
#     Bracknell Forest                   2.67     1.54
#     Stevenage                          1.62     1.21
#     North Tyneside                     1.53     0.95
#     South Gloucestershire              1.47     1.13
#
#   [Financial Services] — Barnsley lq_emp: 0.34
#     LAD                              lq_emp   lq_bus
#     Milton Keynes                      1.70     1.08
#     Ipswich                            1.55     0.96
#     Gloucester                         1.29     0.84
#     Rushmoor                           1.22     1.06
#     Sefton                             1.11     0.83
#
#   [Life Sciences] — Barnsley lq_emp: 0.56
#     LAD                              lq_emp   lq_bus
#     Crawley                            4.21     0.00
#     Bracknell Forest                   4.00     0.65
#     Charnwood                          3.56     0.90
#     Gloucester                         2.06     1.40
#     North Tyneside                     1.97     0.52
#
#   [Professional and Business Services] — Barnsley lq_emp: 0.59
#     LAD                              lq_emp   lq_bus
#     Warrington                         2.25     1.27
#     Fylde                              2.16     0.97
#     Bracknell Forest                   1.24     1.10
#     Rushmoor                           1.13     0.92
#     Milton Keynes                      0.97     1.04
#
# ============================================================
# Doncaster (Cluster 17, n=19 LADs)
# Peers: ['Nottingham', 'Peterborough', 'Thurrock', 'Southampton', 'Eastbourne', 'Harlow', 'Folkestone and Hythe', 'Thanet', 'Pendle', 'Great Yarmouth', 'Bolton', 'Rochdale', 'Salford', 'Newcastle upon Tyne', 'Coventry', 'Sandwell', 'Walsall', 'Wolverhampton']
#
#   [Advanced Manufacturing] — Doncaster lq_emp: 0.46
#     LAD                              lq_emp   lq_bus
#     Pendle                             4.79     2.07
#     Coventry                           2.14     1.59
#     Wolverhampton                      2.10     1.16
#     Peterborough                       1.77     0.92
#     Harlow                             1.30     1.09
#
#   [Creative Industries] — Doncaster lq_emp: 0.15
#     LAD                              lq_emp   lq_bus
#     Salford                            1.63     0.77
#     Newcastle upon Tyne                0.90     0.86
#     Nottingham                         0.74     0.70
#     Peterborough                       0.72     0.56
#     Southampton                        0.56     0.57
#
#   [Digital and Technologies] — Doncaster lq_emp: 0.40
#     LAD                              lq_emp   lq_bus
#     Salford                            1.28     0.80
#     Pendle                             1.17     0.54
#     Harlow                             0.95     0.83
#     Nottingham                         0.91     0.80
#     Newcastle upon Tyne                0.87     0.88
#
#   [Financial Services] — Doncaster lq_emp: 0.53
#     LAD                              lq_emp   lq_bus
#     Folkestone and Hythe               1.58     0.61
#     Salford                            1.09     3.51
#     Peterborough                       1.00     0.79
#     Southampton                        0.99     0.75
#     Wolverhampton                      0.98     0.73
#
#   [Life Sciences] — Doncaster lq_emp: 0.28
#     LAD                              lq_emp   lq_bus
#     Bolton                             1.33     0.89
#     Southampton                        1.10     0.74
#     Nottingham                         1.05     1.41
#     Newcastle upon Tyne                1.04     1.21
#     Great Yarmouth                     0.78     0.00
#
#   [Professional and Business Services] — Doncaster lq_emp: 0.53
#     LAD                              lq_emp   lq_bus
#     Salford                            1.15     0.84
#     Nottingham                         0.94     0.87
#     Peterborough                       0.91     0.73
#     Newcastle upon Tyne                0.88     0.97
#     Bolton                             0.86     0.80
#
# ============================================================
# Rotherham (Cluster 7, n=52 LADs)
# Peers: ['Redcar and Cleveland', 'Stockton-on-Tees', 'Darlington', 'Warrington', 'North East Lincolnshire', 'North Lincolnshire', 'Derby', 'Telford and Wrekin', 'North Somerset', 'South Gloucestershire', 'Plymouth', 'Torbay', 'Medway', 'Bracknell Forest', 'Milton Keynes', 'Portsmouth', 'Bedford', 'Erewash', 'Basildon', 'Gloucester', 'Havant', 'Rushmoor', 'Gravesham', 'Swale', 'Fylde', 'Preston', 'Charnwood', 'North West Leicestershire', 'Gedling', 'Cannock Chase', 'Newcastle-under-Lyme', 'Tamworth', 'Ipswich', 'Nuneaton and Bedworth', 'Crawley', 'Redditch', 'Stevenage', 'Bury', 'Oldham', 'Tameside', 'Wigan', 'St. Helens', 'Sefton', 'Wirral', 'Barnsley', 'North Tyneside', 'Dudley', 'Bradford', 'Kirklees', 'Wakefield', 'Gateshead']
#
#   [Advanced Manufacturing] — Rotherham lq_emp: 1.29
#     LAD                              lq_emp   lq_bus
#     Fylde                              9.53     1.10
#     Derby                              6.22     1.16
#     South Gloucestershire              4.14     1.27
#     Plymouth                           4.05     0.57
#     Basildon                           3.19     1.15
#
#   [Creative Industries] — Rotherham lq_emp: 0.32
#     LAD                              lq_emp   lq_bus
#     Rushmoor                           2.60     0.96
#     Bracknell Forest                   2.41     1.40
#     North Tyneside                     0.99     0.75
#     Milton Keynes                      0.89     1.35
#     Portsmouth                         0.89     0.65
#
#   [Digital and Technologies] — Rotherham lq_emp: 0.55
#     LAD                              lq_emp   lq_bus
#     Rushmoor                           3.85     1.37
#     Bracknell Forest                   2.67     1.54
#     Stevenage                          1.62     1.21
#     North Tyneside                     1.53     0.95
#     South Gloucestershire              1.47     1.13
#
#   [Financial Services] — Rotherham lq_emp: 0.57
#     LAD                              lq_emp   lq_bus
#     Milton Keynes                      1.70     1.08
#     Ipswich                            1.55     0.96
#     Gloucester                         1.29     0.84
#     Rushmoor                           1.22     1.06
#     Sefton                             1.11     0.83
#
#   [Life Sciences] — Rotherham lq_emp: 0.39
#     LAD                              lq_emp   lq_bus
#     Crawley                            4.21     0.00
#     Bracknell Forest                   4.00     0.65
#     Charnwood                          3.56     0.90
#     Gloucester                         2.06     1.40
#     North Tyneside                     1.97     0.52
#
#   [Professional and Business Services] — Rotherham lq_emp: 0.49
#     LAD                              lq_emp   lq_bus
#     Warrington                         2.25     1.27
#     Fylde                              2.16     0.97
#     Bracknell Forest                   1.24     1.10
#     Rushmoor                           1.13     0.92
#     Milton Keynes                      0.97     1.04
#
# ============================================================
# Sheffield (Cluster 14, n=16 LADs)
# Peers: ['Bristol, City of', 'Reading', 'Windsor and Maidenhead', 'Cambridge', 'Exeter', 'Hertsmere', 'Watford', 'Norwich', 'Elmbridge', 'St Albans', 'Hammersmith and Fulham', 'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth', 'Richmond upon Thames']
#
#   [Advanced Manufacturing] — Sheffield lq_emp: 0.50
#     LAD                              lq_emp   lq_bus
#     Norwich                            0.57     0.73
#     Elmbridge                          0.54     0.45
#
#   [Creative Industries] — Sheffield lq_emp: 0.62
#     LAD                              lq_emp   lq_bus
#     Hammersmith and Fulham             4.53     2.30
#     Richmond upon Thames               2.60     2.39
#     Kensington and Chelsea             2.14     1.80
#     Reading                            2.10     1.43
#     Lambeth                            1.89     2.39
#
#   [Digital and Technologies] — Sheffield lq_emp: 0.81
#     LAD                              lq_emp   lq_bus
#     Reading                            3.00     1.85
#     Cambridge                          2.45     1.81
#     Hammersmith and Fulham             2.42     1.45
#     Richmond upon Thames               1.74     1.68
#     Bristol, City of                   1.42     1.27
#
#   [Financial Services] — Sheffield lq_emp: 0.98
#     LAD                              lq_emp   lq_bus
#     Bristol, City of                   1.76     1.27
#
#   [Life Sciences] — Sheffield lq_emp: 2.08
#     LAD                              lq_emp   lq_bus
#     Hertsmere                          5.37     0.85
#     Windsor and Maidenhead             2.76     1.38
#     Cambridge                          2.16     6.82
#
#   [Professional and Business Services] — Sheffield lq_emp: 0.85
#     LAD                              lq_emp   lq_bus
#     Watford                            2.08     1.00
#     Windsor and Maidenhead             1.63     1.50
#     St Albans                          1.56     1.67
#     Hertsmere                          1.45     1.20
#     Reading                            1.45     1.00

# %%
# ============================================================
# CELL 5b — Ranked peer position plots
#
# For each Y metric, produces one figure with:
#   3 rows (one per SY cluster) × 6 cols (one per sector)
# Barnsley and Rotherham share Cluster 7 row — both plotted
# as separate red dots so within-cluster variation is visible.
# Each panel: horizontal dot plot of all cluster members
# ranked by metric value, SY LADs highlighted in red.
# ============================================================

import os
import matplotlib.patheffects as pe

OUTPUT_DIR = "../../output/graphs/franco"
os.makedirs(OUTPUT_DIR, exist_ok=True)

METRICS = [
    ("lq_emp",  f"LQ employment ({YEAR})"),
    ("lq_bus",  f"LQ business count ({YEAR})"),
    ("gd_emp",  f"GD employment (2016–{YEAR})"),
    ("gd_bus",  f"GD business count (2016–{YEAR})"),
]

# Build cluster → SY LADs mapping (preserves display order)
SY_CLUSTER_IDS = sorted(lad_df.loc[lad_df.index.intersection(SY_CODES), "cluster"].unique())
cluster_sy_map = {
    cid: [c for c in SY_CODES if c in lad_df.index and lad_df.loc[c, "cluster"] == cid]
    for cid in SY_CLUSTER_IDS
}

# Colours for multiple SY LADs within the same cluster
SY_COLOURS = ["crimson", "darkorange"]

for metric, metric_label in METRICS:
    fig, axes = plt.subplots(3, 6, figsize=(26, 12))
    fig.suptitle(
        f"Peer cluster ranked position — {metric_label}\nSY LAD in red, top performers labelled",
        fontsize=13, fontweight="bold"
    )

    ref_val = 1.0 if metric in ["lq_emp", "lq_bus"] else 0.0
    ref_lbl = "LQ=1" if metric in ["lq_emp", "lq_bus"] else "GD=0"

    for row, cid in enumerate(SY_CLUSTER_IDS):
        sy_codes_in_cluster = cluster_sy_map[cid]
        cluster_codes = lad_df[lad_df["cluster"] == cid].index.tolist()
        row_label = " / ".join(
            lad_df.loc[c, "GEOGRAPHY_NAME"] for c in sy_codes_in_cluster
        )

        for col, sector in enumerate(FOCUS_SECTORS):
            ax = axes[row, col]

            # Get metric values for all cluster members
            if metric in ["lq_emp", "lq_bus"]:
                m_series = (
                    lq_lookup.xs(sector, level="IS8_SECTOR")[metric]
                    .reindex(cluster_codes)
                    .astype(float)
                )
            else:
                m_series = (
                    panel[(panel["YEAR"] == YEAR) &
                          (panel["IS8_SECTOR"] == sector)]
                    .set_index("GEOGRAPHY_CODE")[metric]
                    .astype(float)
                    .reindex(cluster_codes)
                )

            m_series = m_series.dropna().sort_values()
            names    = [lad_df.loc[c, "GEOGRAPHY_NAME"]
                        if c in lad_df.index else c
                        for c in m_series.index]
            vals     = m_series.values
            all_sy   = set(sy_codes_in_cluster)
            is_any_sy = np.array([c in all_sy for c in m_series.index])
            y_pos    = np.arange(len(vals))

            # Peer dots
            ax.scatter(vals[~is_any_sy], y_pos[~is_any_sy],
                       color="steelblue", alpha=0.5, s=30, zorder=2)

            # SY LAD dots — one colour per LAD within cluster
            highest_sy_val = -np.inf
            for sy_idx, sy_code in enumerate(sy_codes_in_cluster):
                colour = SY_COLOURS[sy_idx % len(SY_COLOURS)]
                sy_name = lad_df.loc[sy_code, "GEOGRAPHY_NAME"]
                is_this_sy = np.array([c == sy_code for c in m_series.index])
                if not is_this_sy.any():
                    continue
                sy_val = float(vals[is_this_sy][0])
                highest_sy_val = max(highest_sy_val, sy_val)

                ax.scatter(vals[is_this_sy], y_pos[is_this_sy],
                           color=colour, s=100, zorder=5,
                           edgecolors="black", linewidths=0.6,
                           label=sy_name)
                ax.axhline(y_pos[is_this_sy][0], color=colour,
                           linewidth=0.5, linestyle="--", alpha=0.4)

            # Label top 3 peers above highest SY value in this panel
            top_mask = (vals > highest_sy_val) & (~is_any_sy)
            top_idx  = np.where(top_mask)[0][-3:] if top_mask.sum() >= 3 \
                       else np.where(top_mask)[0]
            for i in top_idx:
                ax.annotate(names[i], (vals[i], y_pos[i]),
                            xytext=(4, 0), textcoords="offset points",
                            fontsize=6, color="dimgrey", va="center",
                            path_effects=[pe.withStroke(linewidth=1.5,
                                                        foreground="white")])

            # Reference line
            ax.axvline(ref_val, color="darkred", linewidth=0.7,
                       linestyle=":", alpha=0.6)

            ax.set_yticks([])
            ax.set_xlabel(metric_label, fontsize=7)
            ax.grid(axis="x", alpha=0.2)

            if col == 0:
                ax.set_ylabel(row_label, fontsize=9,
                              fontweight="bold", color="crimson")
            if row == 0:
                ax.set_title(sector, fontsize=8, fontweight="bold")

            # Legend only on first panel of Cluster 7 row
            if row == 0 and col == 0 and len(sy_codes_in_cluster) > 1:
                ax.legend(fontsize=6, loc="lower right")

    plt.tight_layout()
    fname = f"{OUTPUT_DIR}/ranked_position_{metric}.png"
    plt.savefig(fname, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Saved: {fname}")
# Out:
# Saved: ../../output/graphs/franco/ranked_position_lq_emp.png
# Saved: ../../output/graphs/franco/ranked_position_lq_bus.png
# Saved: ../../output/graphs/franco/ranked_position_gd_emp.png
# Saved: ../../output/graphs/franco/ranked_position_gd_bus.png

# %%
# ============================================================
# CELL 5c — IS8 sector quadrant positioning
#
# Plots LQ (x) vs GD (y) for all LADs in SY peer clusters.
# Quadrant boundaries: LQ=1 (national avg), GD=0 (national trend)
# 2×3 grid — one panel per IS8 sector.
# Runs twice: once for emp, once for bus.
# LQ=0 values retained — represent genuine zero presence.
# ============================================================

METRIC_PAIRS = [
    ("lq_emp", "gd_emp",
     f"LQ employment ({YEAR})", f"GD employment (2016–{YEAR})"),
    ("lq_bus", "gd_bus",
     f"LQ business count ({YEAR})", f"GD business count (2016–{YEAR})"),
]

QUADRANT_LABELS = {
    "Q1": ("Anchor &\ngrowing",        "top-right",    "#2ecc71"),
    "Q2": ("Emerging /\ncatching up",  "top-left",     "#3498db"),
    "Q3": ("Weak &\nfalling behind",   "bottom-left",  "#e74c3c"),
    "Q4": ("Established\nbut slowing", "bottom-right", "#e67e22"),
}

# Derive SY cluster IDs and colours dynamically
SY_CLUSTER_IDS  = sorted(lad_df.loc[lad_df.index.intersection(SY_CODES), "cluster"].unique())
cluster_colours = {cid: c for cid, c in zip(SY_CLUSTER_IDS, ["steelblue", "darkorange", "seagreen"])}
sy_cluster_codes = lad_df[lad_df["cluster"].isin(SY_CLUSTER_IDS)].index.tolist()

# Build lookup: GEOGRAPHY_CODE × IS8_SECTOR → all Y metrics
lq_gd = (
    panel[panel["YEAR"] == YEAR]
    .set_index(["GEOGRAPHY_CODE", "IS8_SECTOR"])
    [["GEOGRAPHY_NAME", "lq_emp", "lq_bus", "gd_emp", "gd_bus"]]
    .copy()
)

for lq_metric, gd_metric, lq_label, gd_label in METRIC_PAIRS:

    fig, axes = plt.subplots(2, 3, figsize=(22, 13))
    axes = axes.flatten()
    fig.suptitle(
        f"IS8 sector positioning — {lq_label} vs {gd_label}\n"
        "SY peer clusters only — SY LADs in red",
        fontsize=13, fontweight="bold"
    )

    for ax, sector in zip(axes, FOCUS_SECTORS):

        sec_df = lq_gd.xs(sector, level="IS8_SECTOR").copy()
        sec_df = sec_df[sec_df.index.isin(sy_cluster_codes)]
        sec_df = sec_df.dropna(subset=[lq_metric, gd_metric])
        # LQ=0 retained — represents genuine zero sectoral presence

        lq_vals  = sec_df[lq_metric].astype(float).values
        gd_vals  = sec_df[gd_metric].astype(float).values
        codes    = sec_df.index.tolist()
        names    = sec_df["GEOGRAPHY_NAME"].tolist()
        is_sy    = np.array([c in SY_CODES for c in codes])

        # Plot peers by cluster
        for cid, colour in cluster_colours.items():
            cid_codes = lad_df[lad_df["cluster"] == cid].index.tolist()
            mask = np.array([c in cid_codes and not s
                             for c, s in zip(codes, is_sy)])
            if mask.sum() == 0:
                continue
            ax.scatter(lq_vals[mask], gd_vals[mask],
                       color=colour, alpha=0.45, s=40, zorder=2,
                       label=f"Cluster {cid}")

        # Reference lines — LQ=1 and GD=0
        ax.axvline(1.0, color="dimgrey", linewidth=0.9,
                   linestyle="--", alpha=0.7, zorder=3)
        ax.axhline(0.0, color="dimgrey", linewidth=0.9,
                   linestyle="--", alpha=0.7, zorder=3)

        # Axis limits — x_min floored at 0 since LQ cannot be negative
        x_min = max(min(lq_vals.min() * 0.9, 0.8), 0)
        x_max = lq_vals.max() * 1.05
        y_pad = (gd_vals.max() - gd_vals.min()) * 0.1 or 0.01
        y_min = gd_vals.min() - y_pad
        y_max = gd_vals.max() + y_pad
        ax.set_xlim(x_min, x_max)
        ax.set_ylim(y_min, y_max)

        # Quadrant labels
        mid_x_l = (x_min + 1.0) / 2
        mid_x_r = (1.0 + x_max) / 2
        mid_y_t = (0.0 + y_max) / 2
        mid_y_b = (y_min + 0.0) / 2
        for _, (qtxt, pos, col) in QUADRANT_LABELS.items():
            qx = mid_x_r if "right" in pos else mid_x_l
            qy = mid_y_t if "top"   in pos else mid_y_b
            ax.text(qx, qy, qtxt, ha="center", va="center",
                    fontsize=7.5, color=col, alpha=0.5,
                    style="italic", fontweight="bold")

        # SY LADs
        sy_lq  = lq_vals[is_sy]
        sy_gd  = gd_vals[is_sy]
        sy_nm  = [n for n, s in zip(names, is_sy) if s]
        ax.scatter(sy_lq, sy_gd, color="crimson", s=130,
                   zorder=6, edgecolors="black", linewidths=0.6)
        for xi, yi, nm in zip(sy_lq, sy_gd, sy_nm):
            ax.annotate(nm, (xi, yi),
                        xytext=(7, 5), textcoords="offset points",
                        fontsize=8.5, color="crimson", fontweight="bold",
                        path_effects=[pe.withStroke(linewidth=2.5,
                                                    foreground="white")])

        ax.set_xlabel(lq_label, fontsize=9)
        ax.set_ylabel(gd_label, fontsize=9)
        ax.set_title(sector, fontsize=10, fontweight="bold")
        ax.grid(alpha=0.15)

        handles, labels = ax.get_legend_handles_labels()
        ax.legend(dict(zip(labels, handles)).values(),
                  dict(zip(labels, handles)).keys(),
                  fontsize=7, loc="upper right")

    plt.tight_layout()
    fname = f"{OUTPUT_DIR}/quadrant_{lq_metric}_vs_{gd_metric}.png"
    plt.savefig(fname, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Saved: {fname}")
# Out:
# Saved: ../../output/graphs/franco/quadrant_lq_emp_vs_gd_emp.png
# Saved: ../../output/graphs/franco/quadrant_lq_bus_vs_gd_bus.png

# %%
# ============================================================
# CELL 5c — IS8 sector quadrant positioning (national context)
#
# Plots LQ (x) vs GD (y) for all 279 LADs.
# Non-SY-peer LADs: light grey background
# SY peer cluster LADs: cluster colours
# SY LADs: red
# Quadrant boundaries: LQ=1, GD=0
# 2×3 grid — one panel per IS8 sector.
# Runs twice: once for emp, once for bus.
# LQ=0 values retained — represent genuine zero sectoral presence.
# ============================================================

METRIC_PAIRS = [
    ("lq_emp", "gd_emp",
     f"LQ employment ({YEAR})", f"GD employment (2016–{YEAR})"),
    ("lq_bus", "gd_bus",
     f"LQ business count ({YEAR})", f"GD business count (2016–{YEAR})"),
]

QUADRANT_LABELS = {
    "Q1": ("Anchor &\ngrowing",        "top-right",    "#2ecc71"),
    "Q2": ("Emerging /\ncatching up",  "top-left",     "#3498db"),
    "Q3": ("Weak &\nfalling behind",   "bottom-left",  "#e74c3c"),
    "Q4": ("Established\nbut slowing", "bottom-right", "#e67e22"),
}

# Derive SY cluster IDs and colours dynamically
SY_CLUSTER_IDS   = sorted(lad_df.loc[lad_df.index.intersection(SY_CODES), "cluster"].unique())
cluster_colours  = {cid: c for cid, c in zip(SY_CLUSTER_IDS, ["steelblue", "darkorange", "seagreen"])}
sy_cluster_codes = lad_df[lad_df["cluster"].isin(SY_CLUSTER_IDS)].index.tolist()
all_lad_codes    = lad_df.index.tolist()

# Build lookup: GEOGRAPHY_CODE × IS8_SECTOR → all Y metrics
lq_gd = (
    panel[panel["YEAR"] == YEAR]
    .set_index(["GEOGRAPHY_CODE", "IS8_SECTOR"])
    [["GEOGRAPHY_NAME", "lq_emp", "lq_bus", "gd_emp", "gd_bus"]]
    .copy()
)

for lq_metric, gd_metric, lq_label, gd_label in METRIC_PAIRS:

    fig, axes = plt.subplots(2, 3, figsize=(22, 13))
    axes = axes.flatten()
    fig.suptitle(
        f"IS8 sector positioning — {lq_label} vs {gd_label}\n"
        "All LADs (grey) | SY peer clusters (colour) | SY LADs (red)",
        fontsize=13, fontweight="bold"
    )

    for ax, sector in zip(axes, FOCUS_SECTORS):

        sec_df = lq_gd.xs(sector, level="IS8_SECTOR").copy()
        sec_df = sec_df[sec_df.index.isin(all_lad_codes)]
        sec_df = sec_df.dropna(subset=[lq_metric, gd_metric])
        # LQ=0 retained — represents genuine zero sectoral presence

        lq_vals = sec_df[lq_metric].astype(float).values
        gd_vals = sec_df[gd_metric].astype(float).values
        codes   = sec_df.index.tolist()
        names   = sec_df["GEOGRAPHY_NAME"].tolist()
        is_sy   = np.array([c in SY_CODES for c in codes])
        is_peer = np.array([c in sy_cluster_codes and c not in SY_CODES
                            for c in codes])
        is_bg   = ~is_sy & ~is_peer

        # Background — all other LADs in grey
        ax.scatter(lq_vals[is_bg], gd_vals[is_bg],
                   color="lightgrey", alpha=0.4, s=25, zorder=1,
                   label="Other LADs")

        # SY peer cluster LADs by cluster colour
        for cid, colour in cluster_colours.items():
            cid_codes = lad_df[lad_df["cluster"] == cid].index.tolist()
            mask = np.array([c in cid_codes and c not in SY_CODES
                             for c in codes])
            if mask.sum() == 0:
                continue
            ax.scatter(lq_vals[mask], gd_vals[mask],
                       color=colour, alpha=0.6, s=45, zorder=3,
                       label=f"Cluster {cid} peers")

        # Reference lines — LQ=1 and GD=0
        ax.axvline(1.0, color="dimgrey", linewidth=0.9,
                   linestyle="--", alpha=0.7, zorder=4)
        ax.axhline(0.0, color="dimgrey", linewidth=0.9,
                   linestyle="--", alpha=0.7, zorder=4)

        # Axis limits — x_min floored at 0 since LQ cannot be negative
        x_min = max(min(lq_vals.min() * 0.9, 0.8), 0)
        x_max = lq_vals.max() * 1.05
        y_pad = (gd_vals.max() - gd_vals.min()) * 0.1 or 0.01
        y_min = gd_vals.min() - y_pad
        y_max = gd_vals.max() + y_pad
        ax.set_xlim(x_min, x_max)
        ax.set_ylim(y_min, y_max)

        # Quadrant labels
        mid_x_l = (x_min + 1.0) / 2
        mid_x_r = (1.0 + x_max) / 2
        mid_y_t = (0.0 + y_max) / 2
        mid_y_b = (y_min + 0.0) / 2
        for _, (qtxt, pos, col) in QUADRANT_LABELS.items():
            qx = mid_x_r if "right" in pos else mid_x_l
            qy = mid_y_t if "top"   in pos else mid_y_b
            ax.text(qx, qy, qtxt, ha="center", va="center",
                    fontsize=7.5, color=col, alpha=0.5,
                    style="italic", fontweight="bold")

        # SY LADs — on top
        sy_lq = lq_vals[is_sy]
        sy_gd = gd_vals[is_sy]
        sy_nm = [n for n, s in zip(names, is_sy) if s]
        ax.scatter(sy_lq, sy_gd, color="crimson", s=130,
                   zorder=6, edgecolors="black", linewidths=0.6,
                   label="SY LADs")
        for xi, yi, nm in zip(sy_lq, sy_gd, sy_nm):
            ax.annotate(nm, (xi, yi),
                        xytext=(7, 5), textcoords="offset points",
                        fontsize=8.5, color="crimson", fontweight="bold",
                        path_effects=[pe.withStroke(linewidth=2.5,
                                                    foreground="white")])

        ax.set_xlabel(lq_label, fontsize=9)
        ax.set_ylabel(gd_label, fontsize=9)
        ax.set_title(sector, fontsize=10, fontweight="bold")
        ax.grid(alpha=0.15)

        handles, labels = ax.get_legend_handles_labels()
        ax.legend(dict(zip(labels, handles)).values(),
                  dict(zip(labels, handles)).keys(),
                  fontsize=7, loc="upper right")

    plt.tight_layout()
    fname = f"{OUTPUT_DIR}/quadrant_national_{lq_metric}_vs_{gd_metric}.png"
    plt.savefig(fname, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Saved: {fname}")
# Out:
# Saved: ../../output/graphs/franco/quadrant_national_lq_emp_vs_gd_emp.png
# Saved: ../../output/graphs/franco/quadrant_national_lq_bus_vs_gd_bus.png

# %% [markdown]
# ## Narrative Structure
#
# ### 1. Opening: South Yorkshire's IS8 footprint is internally differentiated
# Don't start with the MCA aggregate — start by establishing that SY is not one economy. The dendrogram already showed this: Sheffield clusters separately from Barnsley/Doncaster/Rotherham. Use this as the framing device. Everything that follows is structured around that internal differentiation.
#
# ---
#
# ### 2. Life Sciences — anchor in Sheffield, absent elsewhere
#
# **Evidence chain:**
# - 5c (emp): Sheffield above LQ=1, the other three compressed at bottom-left — weak and falling behind
# - 5a (lq_emp): Sheffield above cluster trend, peers like Broxtowe and Halton show what's achievable
# - 5b (lq_emp): Sheffield converts related variety, others don't despite similar variety values
# - 5c (bus): Sheffield's firm base is contracting (CAGR bus negative) even as employment holds
# - 5b (lq_bus): Barnsley/Doncaster/Rotherham have near-zero business count LQ — not just weak employment but virtually no firm base
#
# **The argument:** Sheffield has an established Life Sciences anchor driven by the university and teaching hospitals — it overperforms relative to structural peers. The other three LADs have the industrial diversity to support Life Sciences (related variety is there) but no firm base and no employment trajectory. The barrier is institutional: without an anchor organisation to seed the ecosystem, related variety alone doesn't convert.
#
# ---
#
# ### 3. Advanced Manufacturing — present but fragmented, positive momentum
#
# **Evidence chain:**
# - 5a (lq_emp): SY LADs broadly on trend — performing as structural position predicts
# - 5a (lq_bus): Rotherham and Barnsley above trend on business count — more firms than structural position would suggest
# - 5b (lq_bus): All four on or above trend — related variety is converting into firm presence
# - 5c (bus): All four above cluster medians on CAGR bus — firm counts growing
# - 5c (emp): Sheffield and Doncaster in emerging quadrant, positive employment CAGR
#
# **The argument:** Advanced Manufacturing is the most structurally grounded story. Firms are present in proportion to industrial diversity, employment is growing above national median, and business counts are increasing. The constraint is depth not presence — the gap between business LQ (1.69 MCA aggregate) and employment LQ (1.16) points to SME fragmentation. The adjacency to Clean Energy via the Humber supply chain is the forward-looking opportunity.
#
# ---
#
# ### 4. Digital & Technologies — high potential, systemic underconversion
#
# **Evidence chain:**
# - 5b (lq_emp): All four below trend despite sitting at high end of related variety — the clearest underperformance signal in the dataset
# - 5b (cagr_emp): Barnsley and Rotherham below trend and negative — losing ground
# - 5c (emp): Rotherham and Barnsley in weak/falling behind quadrant
# - 5b (lq_bus): All four below trend on business count
# - 5c (bus): Barnsley clearly negative CAGR bus, Doncaster and Rotherham marginally positive
#
# **The argument:** Digital is the most analytically distinctive case. The related variety is there — SY's industrial base is cognitively adjacent to digital technologies — but none of the four LADs are converting it into either employment or firm presence. Unlike Life Sciences where Sheffield is an exception, here all four underperform. This points to a systemic barrier rather than an institutional gap: likely skills (level 3+ qualifications below national median) combined with absence of anchor digital employers to generate spinoffs and spillovers.
#
# ---
#
# ### 5. Why is potential unrealised? — the barriers synthesis
#
# Draw from the correlate scorecard (Cell 3) once regression results are in, but you can already frame the hypotheses from the plots:
#
# | Barrier | Sectors affected | Evidence |
# |---|---|---|
# | Absence of anchor institutions | Life Sciences (Barnsley/Doncaster/Rotherham) | Near-zero firm base despite related variety |
# | Skills gap | Digital across all four | High related variety but no employment conversion |
# | SME fragmentation | Advanced Manufacturing | Business LQ > employment LQ, no large firm anchors |
# | Spatial dependency on Sheffield | Life Sciences, Digital | Sheffield overperforms, others don't — spillovers not reaching neighbouring LADs |
#
# ---
#
# ### 6. Adjacency argument — the forward-looking case
#
# Two specific adjacencies supported by the data:
#
# - **Advanced Manufacturing → Clean Energy**: firm base is growing, related variety is high, proximity to Humber offshore wind cluster. This is the strongest forward case.
# - **Advanced Manufacturing → Digital**: Rotherham's above-trend business count LQ on Advanced Manufacturing combined with Doncaster's positive Digital CAGR bus suggests potential for technology adoption within manufacturing firms.
#
# ---
#
# ### Plot allocation for write-up
#
# You don't need all 10 plots in the final piece. I'd select:
#
# | Plot | Where it goes |
# |---|---|
# | 5c emp (quadrant) | Opening — overall positioning of 4 LADs |
# | 5b lq_emp (related variety) | Life Sciences + Digital unrealised potential argument |
# | 5a lq_bus (structural vs bus LQ) | Advanced Manufacturing fragmentation |
# | 5c bus (quadrant) | Business dynamics — consolidation vs growth |
#
# The other 6 support the analysis but don't need to appear in the written narrative directly.

# %%
# ============================================================
# CELL 6 — Barrier gap analysis
#
# For each SY LAD × sector × reference metric:
#   1. Within each SY LAD's cluster, identify the top 10% of
#      LADs by that metric — these are the "achievable" peers
#   2. Compute the mean of those top performers on each
#      barrier variable — this is the reference benchmark
#   3. Standardised gap = (SY - benchmark) / national std
#      Negative = SY underperforms → potential barrier
#      Positive = SY overperforms → not a constraint
#
# Barrier variables derived from EEG_GROUPS in config —
# same variable set as clustering for analytical consistency.
# Variables where higher = worse (unemployment, death rate)
# have their gap sign inverted so red = barrier consistently.
# ============================================================

# Variables where higher = worse — gap sign inverted
INVERT_VARS = {"unemployment_rate", "enterprise_death_rate"}

# Human-readable labels
VAR_LABELS = {
    "nvq_level3":                  "Level 3+ quals (%)",
    "gcse_age19":                  "GCSE by age 19 (%)",
    "apprenticeship_starts":       "Apprenticeship starts (per 100k)",
    "fe_participation":            "FE participation (per 100k)",
    "n_universities_feecap_lad":   "Fee-cap HE providers (n)",
    "enterprise_birth_rate":       "Enterprise birth rate",
    "enterprise_death_rate":       "Enterprise death rate",
    "enterprise_high_growth_rate": "Enterprise high growth rate",
    "transport_to_employer":       "Public transport to employer (%)",
    "broadband":                   "Broadband availability (%)",
    "unemployment_rate":           "Unemployment rate (%)",
    "housing_net_additions":       "Housing net additions (per 1,000)",
}

# Derived from config — single source of truth
EEG_GROUPS     = config["parameters"]["eeg_groups"]
BARRIER_VARS   = {v: VAR_LABELS.get(v, v) for grp in EEG_GROUPS.values() for v in grp}
BARRIER_GROUPS = EEG_GROUPS

REFERENCE_METRICS = [
    ("lq_emp",  f"LQ employment ({YEAR})"),
    ("lq_bus",  f"LQ business count ({YEAR})"),
    ("gd_emp",  f"GD employment (2016–{YEAR})"),
    ("gd_bus",  f"GD business count (2016–{YEAR})"),
]

# Derived from config — single source of truth
SY_LAD_NAMES = dict(zip(
    config["parameters"]["sy_lad_codes"],
    config["parameters"]["sy_lad_names"]
))

# Derived from lad_df — single source of truth
SY_CLUSTER_MAP = lad_df.loc[
    lad_df.index.intersection(SY_CODES), "cluster"
].to_dict()

# LAD-level barrier values — one row per LAD
barrier_df = (
    panel[panel["YEAR"] == YEAR]
    .drop_duplicates(subset="GEOGRAPHY_CODE")
    .set_index("GEOGRAPHY_CODE")
    [list(BARRIER_VARS.keys())]
    .copy()
)

# National std per variable — used to standardise gaps
nat_std = barrier_df.std(ddof=1).replace(0, np.nan)

# IS8 metric values per LAD × sector
metric_df = (
    panel[panel["YEAR"] == YEAR]
    .set_index(["GEOGRAPHY_CODE", "IS8_SECTOR"])
    [["lq_emp", "lq_bus", "gd_emp", "gd_bus"]]
    .copy()
)

for ref_metric, ref_label in REFERENCE_METRICS:

    fig, axes = plt.subplots(2, 3, figsize=(24, 14))
    axes = axes.flatten()
    fig.suptitle(
        f"Barrier gap analysis — reference: top 10% by {ref_label}\n"
        "Standardised gap = (SY - benchmark) / national std  |  Red = underperforms, Green = overperforms",
        fontsize=12, fontweight="bold"
    )

    for ax, sector in zip(axes, FOCUS_SECTORS):

        gap_records = []

        for sy_code, sy_name in SY_LAD_NAMES.items():
            cid = SY_CLUSTER_MAP.get(sy_code)
            if cid is None:
                continue
            cluster_codes = lad_df[lad_df["cluster"] == cid].index.tolist()

            # Metric values for cluster LADs in this sector
            try:
                sec_metrics = (
                    metric_df.xs(sector, level="IS8_SECTOR")[ref_metric]
                    .reindex(cluster_codes)
                    .dropna()
                )
            except KeyError:
                continue

            if len(sec_metrics) == 0:
                continue

            # Top 10% — at least 1 LAD
            n_top = max(1, int(np.ceil(len(sec_metrics) * 0.10)))
            top_codes = sec_metrics.nlargest(n_top).index.tolist()

            # Mean of top 10% on each barrier variable
            top_barrier = barrier_df.reindex(top_codes).mean()

            # SY LAD barrier values
            if sy_code not in barrier_df.index:
                continue
            sy_barrier = barrier_df.loc[sy_code]

            # Standardised gap = (SY - benchmark) / national std
            # Inverted for negative-polarity vars so red = barrier consistently
            raw_gap = sy_barrier - top_barrier
            gap = raw_gap / nat_std
            for var in INVERT_VARS:
                if var in gap.index:
                    gap[var] *= -1

            for var in BARRIER_VARS:
                if var in gap.index and pd.notna(gap[var]):
                    gap_records.append({
                        "lad":      sy_name,
                        "variable": var,
                        "gap":      float(gap[var]),
                    })

        if not gap_records:
            ax.set_title(f"{sector}\n(no data)", fontsize=9)
            ax.axis("off")
            continue

        gap_df = pd.DataFrame(gap_records)
        pivot  = gap_df.pivot(index="variable", columns="lad", values="gap")

        # Order rows by group, then by mean gap (most negative first)
        ordered_vars = []
        group_boundaries = []
        for grp, vars_in_grp in BARRIER_GROUPS.items():
            valid = [v for v in vars_in_grp if v in pivot.index]
            if valid:
                valid_sorted = sorted(valid, key=lambda v: pivot.loc[v].mean())
                ordered_vars.extend(valid_sorted)
                group_boundaries.append((len(ordered_vars), grp))

        pivot = pivot.reindex(ordered_vars)
        pivot.index = [BARRIER_VARS[v] for v in ordered_vars]

        # Fixed symmetric colour scale — ±3 std covers ~99.7% of values
        abs_max = 3

        im = ax.imshow(
            pivot.values,
            aspect="auto",
            cmap="RdYlGn",
            vmin=-abs_max,
            vmax=abs_max,
        )

        ax.set_xticks(range(len(pivot.columns)))
        ax.set_xticklabels(pivot.columns, fontsize=9, fontweight="bold")
        ax.set_yticks(range(len(pivot.index)))
        ax.set_yticklabels(pivot.index, fontsize=7.5)
        ax.set_title(sector, fontsize=10, fontweight="bold")

        # Cell values
        for i in range(pivot.shape[0]):
            for j in range(pivot.shape[1]):
                val = pivot.values[i, j]
                if not np.isnan(val):
                    ax.text(j, i, f"{val:+.2f}",
                            ha="center", va="center",
                            fontsize=6.5,
                            color="black" if abs(val) < abs_max * 0.6
                            else "white")

        # Group separator lines and labels
        cum = 0
        for boundary, grp_name in group_boundaries[:-1]:
            ax.axhline(boundary - 0.5, color="white", linewidth=1.5)
        cum = 0
        for boundary, grp_name in group_boundaries:
            mid = (cum + boundary - 1) / 2
            ax.text(-0.6, mid, grp_name,
                    ha="right", va="center",
                    fontsize=7, color="dimgrey", fontstyle="italic",
                    transform=ax.get_yaxis_transform())
            cum = boundary

        plt.colorbar(im, ax=ax, shrink=0.6,
                     label="Standardised gap (SY - benchmark) / national std")

    plt.tight_layout()
    fname = f"{OUTPUT_DIR}/barrier_gap_{ref_metric}.png"
    plt.savefig(fname, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Saved: {fname}")
# Out:
# Saved: ../../output/graphs/franco/barrier_gap_lq_emp.png
# Saved: ../../output/graphs/franco/barrier_gap_lq_bus.png
# Saved: ../../output/graphs/franco/barrier_gap_gd_emp.png
# Saved: ../../output/graphs/franco/barrier_gap_gd_bus.png

# %%
# ============================================================
# CELL 6b — Summary table: consistent barriers across metrics
#
# A variable flagged as negative (barrier) across all 4 metrics
# is a robust finding. This table counts how many times each
# variable × LAD × sector combination is in the red.
# INVERT_VARS applied so negative = barrier consistently.
# ============================================================

print("\n=== ROBUST BARRIERS (negative gap in 3+ of 4 metrics) ===")
print("These variables consistently underperform against top performers\n")

all_gaps = []
for ref_metric, ref_label in REFERENCE_METRICS:
    for sector in FOCUS_SECTORS:
        for sy_code, sy_name in SY_LAD_NAMES.items():
            cid = SY_CLUSTER_MAP.get(sy_code)
            if cid is None:
                continue
            cluster_codes = lad_df[lad_df["cluster"] == cid].index.tolist()
            try:
                sec_metrics = (
                    metric_df.xs(sector, level="IS8_SECTOR")[ref_metric]
                    .reindex(cluster_codes).dropna()
                )
            except KeyError:
                continue
            if len(sec_metrics) == 0:
                continue
            n_top = max(1, int(np.ceil(len(sec_metrics) * 0.10)))
            top_codes = sec_metrics.nlargest(n_top).index.tolist()
            top_barrier = barrier_df.reindex(top_codes).mean()
            if sy_code not in barrier_df.index:
                continue
            sy_barrier = barrier_df.loc[sy_code]

            # Raw gap with inversion for negative-polarity variables
            gap = sy_barrier - top_barrier
            for var in INVERT_VARS:
                if var in gap.index:
                    gap[var] *= -1

            for var in BARRIER_VARS:
                if var in gap.index and pd.notna(gap[var]):
                    all_gaps.append({
                        "metric":   ref_metric,
                        "sector":   sector,
                        "lad":      sy_name,
                        "variable": var,
                        "gap":      float(gap[var]),
                        "negative": float(gap[var]) < 0,
                    })

gaps_df = pd.DataFrame(all_gaps)
robust = (
    gaps_df.groupby(["sector", "lad", "variable"])["negative"]
    .sum()
    .reset_index()
    .rename(columns={"negative": "n_negative"})
)
robust = robust[robust["n_negative"] >= 3].sort_values(
    ["sector", "lad", "n_negative"], ascending=[True, True, False]
)
print(robust.to_string(index=False))
# Out:
# === ROBUST BARRIERS (negative gap in 3+ of 4 metrics) ===
# These variables consistently underperform against top performers
#
#                             sector       lad                    variable  n_negative
#             Advanced Manufacturing  Barnsley                   broadband           4
#             Advanced Manufacturing  Barnsley       enterprise_death_rate           4
#             Advanced Manufacturing  Barnsley enterprise_high_growth_rate           4
#             Advanced Manufacturing  Barnsley       apprenticeship_starts           3
#             Advanced Manufacturing  Barnsley            fe_participation           3
#             Advanced Manufacturing  Barnsley                  gcse_age19           3
#             Advanced Manufacturing  Barnsley       housing_net_additions           3
#             Advanced Manufacturing  Barnsley                  nvq_level3           3
#             Advanced Manufacturing Doncaster       enterprise_death_rate           4
#             Advanced Manufacturing Doncaster            fe_participation           4
#             Advanced Manufacturing Doncaster                   broadband           3
#             Advanced Manufacturing Doncaster   n_universities_feecap_lad           3
#             Advanced Manufacturing Rotherham enterprise_high_growth_rate           4
#             Advanced Manufacturing Rotherham                  gcse_age19           4
#             Advanced Manufacturing Rotherham           unemployment_rate           4
#             Advanced Manufacturing Rotherham       apprenticeship_starts           3
#             Advanced Manufacturing Rotherham       housing_net_additions           3
#             Advanced Manufacturing Rotherham   n_universities_feecap_lad           3
#             Advanced Manufacturing Sheffield                   broadband           4
#             Advanced Manufacturing Sheffield                  nvq_level3           4
#             Advanced Manufacturing Sheffield enterprise_high_growth_rate           3
#             Advanced Manufacturing Sheffield                  gcse_age19           3
#                Creative Industries  Barnsley                   broadband           4
#                Creative Industries  Barnsley       enterprise_death_rate           4
#                Creative Industries  Barnsley enterprise_high_growth_rate           4
#                Creative Industries  Barnsley                  nvq_level3           4
#                Creative Industries  Barnsley            fe_participation           3
#                Creative Industries  Barnsley                  gcse_age19           3
#                Creative Industries  Barnsley       housing_net_additions           3
#                Creative Industries Doncaster       enterprise_death_rate           4
#                Creative Industries Doncaster            fe_participation           4
#                Creative Industries Doncaster   n_universities_feecap_lad           4
#                Creative Industries Rotherham enterprise_high_growth_rate           4
#                Creative Industries Rotherham                  gcse_age19           4
#                Creative Industries Rotherham                  nvq_level3           4
#                Creative Industries Rotherham           unemployment_rate           4
#                Creative Industries Rotherham       housing_net_additions           3
#                Creative Industries Rotherham   n_universities_feecap_lad           3
#                Creative Industries Sheffield                   broadband           4
#                Creative Industries Sheffield enterprise_high_growth_rate           4
#                Creative Industries Sheffield                  gcse_age19           4
#                Creative Industries Sheffield                  nvq_level3           4
#           Digital and Technologies  Barnsley                   broadband           4
#           Digital and Technologies  Barnsley       enterprise_death_rate           4
#           Digital and Technologies  Barnsley enterprise_high_growth_rate           4
#           Digital and Technologies  Barnsley       housing_net_additions           4
#           Digital and Technologies  Barnsley                  nvq_level3           4
#           Digital and Technologies  Barnsley            fe_participation           3
#           Digital and Technologies  Barnsley                  gcse_age19           3
#           Digital and Technologies  Barnsley       transport_to_employer           3
#           Digital and Technologies Doncaster       enterprise_death_rate           4
#           Digital and Technologies Doncaster            fe_participation           4
#           Digital and Technologies Doncaster   n_universities_feecap_lad           3
#           Digital and Technologies Rotherham enterprise_high_growth_rate           4
#           Digital and Technologies Rotherham                  gcse_age19           4
#           Digital and Technologies Rotherham       housing_net_additions           4
#           Digital and Technologies Rotherham   n_universities_feecap_lad           4
#           Digital and Technologies Rotherham                  nvq_level3           4
#           Digital and Technologies Rotherham           unemployment_rate           4
#           Digital and Technologies Rotherham                   broadband           3
#           Digital and Technologies Sheffield                   broadband           4
#           Digital and Technologies Sheffield enterprise_high_growth_rate           4
#           Digital and Technologies Sheffield                  gcse_age19           4
#           Digital and Technologies Sheffield       housing_net_additions           4
#           Digital and Technologies Sheffield                  nvq_level3           4
#                 Financial Services  Barnsley                   broadband           4
#                 Financial Services  Barnsley       enterprise_death_rate           4
#                 Financial Services  Barnsley enterprise_high_growth_rate           4
#                 Financial Services  Barnsley       housing_net_additions           4
#                 Financial Services  Barnsley                  nvq_level3           4
#                 Financial Services  Barnsley                  gcse_age19           3
#                 Financial Services  Barnsley       transport_to_employer           3
#                 Financial Services Doncaster                   broadband           4
#                 Financial Services Doncaster       enterprise_death_rate           4
#                 Financial Services Doncaster enterprise_high_growth_rate           4
#                 Financial Services Doncaster            fe_participation           4
#                 Financial Services Doncaster       housing_net_additions           4
#                 Financial Services Doncaster   n_universities_feecap_lad           4
#                 Financial Services Doncaster                  nvq_level3           4
#                 Financial Services Rotherham enterprise_high_growth_rate           4
#                 Financial Services Rotherham                  gcse_age19           4
#                 Financial Services Rotherham       housing_net_additions           4
#                 Financial Services Rotherham   n_universities_feecap_lad           4
#                 Financial Services Rotherham                  nvq_level3           4
#                 Financial Services Rotherham           unemployment_rate           4
#                 Financial Services Sheffield                   broadband           4
#                 Financial Services Sheffield enterprise_high_growth_rate           4
#                 Financial Services Sheffield                  gcse_age19           4
#                 Financial Services Sheffield                  nvq_level3           4
#                      Life Sciences  Barnsley                   broadband           4
#                      Life Sciences  Barnsley       enterprise_death_rate           4
#                      Life Sciences  Barnsley enterprise_high_growth_rate           4
#                      Life Sciences  Barnsley            fe_participation           4
#                      Life Sciences  Barnsley       housing_net_additions           4
#                      Life Sciences  Barnsley                  nvq_level3           4
#                      Life Sciences  Barnsley                  gcse_age19           3
#                      Life Sciences Doncaster                   broadband           4
#                      Life Sciences Doncaster   n_universities_feecap_lad           4
#                      Life Sciences Doncaster                  nvq_level3           4
#                      Life Sciences Doncaster       enterprise_death_rate           3
#                      Life Sciences Doncaster enterprise_high_growth_rate           3
#                      Life Sciences Doncaster            fe_participation           3
#                      Life Sciences Rotherham enterprise_high_growth_rate           4
#                      Life Sciences Rotherham                  gcse_age19           4
#                      Life Sciences Rotherham       housing_net_additions           4
#                      Life Sciences Rotherham                  nvq_level3           4
#                      Life Sciences Rotherham   n_universities_feecap_lad           3
#                      Life Sciences Rotherham           unemployment_rate           3
#                      Life Sciences Sheffield                   broadband           4
#                      Life Sciences Sheffield                  gcse_age19           4
#                      Life Sciences Sheffield                  nvq_level3           4
#                      Life Sciences Sheffield enterprise_high_growth_rate           3
#                      Life Sciences Sheffield       housing_net_additions           3
# Professional and Business Services  Barnsley                   broadband           4
# Professional and Business Services  Barnsley       enterprise_death_rate           4
# Professional and Business Services  Barnsley enterprise_high_growth_rate           4
# Professional and Business Services  Barnsley       housing_net_additions           4
# Professional and Business Services  Barnsley                  nvq_level3           4
# Professional and Business Services  Barnsley            fe_participation           3
# Professional and Business Services  Barnsley                  gcse_age19           3
# Professional and Business Services Doncaster       enterprise_death_rate           4
# Professional and Business Services Doncaster            fe_participation           4
# Professional and Business Services Doncaster   n_universities_feecap_lad           4
# Professional and Business Services Doncaster                   broadband           3
# Professional and Business Services Doncaster enterprise_high_growth_rate           3
# Professional and Business Services Doncaster       housing_net_additions           3
# Professional and Business Services Doncaster                  nvq_level3           3
# Professional and Business Services Rotherham enterprise_high_growth_rate           4
# Professional and Business Services Rotherham                  gcse_age19           4
# Professional and Business Services Rotherham       housing_net_additions           4
# Professional and Business Services Rotherham   n_universities_feecap_lad           4
# Professional and Business Services Rotherham           unemployment_rate           4
# Professional and Business Services Rotherham                  nvq_level3           3
# Professional and Business Services Sheffield                   broadband           4
# Professional and Business Services Sheffield                  gcse_age19           4
# Professional and Business Services Sheffield                  nvq_level3           4
# Professional and Business Services Sheffield           unemployment_rate           4
# Professional and Business Services Sheffield enterprise_high_growth_rate           3

# %% [markdown]
# **Barnsley — the most constrained LAD across all three sectors**
#
# Five variables appear as robust barriers (n=4) across all sectors: `broadband_availability`, `4g_area_coverage`, `size_micro_share`, `unemployment_rate`, and `level_3+_qualifications` (on Life Sciences and Digital). Transport accessibility (`drive_to_employer`, `public_transport_to_employer`) also appears on Digital. This is a compound barrier profile — infrastructure, labour market, skills, and firm structure all constrain simultaneously. No single intervention fixes Barnsley.
#
# **Doncaster — skills pipeline is the binding constraint**
#
# `gcse_by_age_19` and `level_3+_qualifications` appear as n=4 across all three sectors. `apprenticeship_achievements` appears on Life Sciences and Advanced Manufacturing. `size_micro_share` appears on Life Sciences. The pattern is consistent — Doncaster's workforce qualification level is the primary gap relative to top performers in its cluster. Infrastructure is not an issue.
#
# **Rotherham — moderate, skills-focused**
#
# `gcse_by_age_19` is the most consistent barrier (n=4 on Advanced Manufacturing, Digital, Life Sciences). `apprenticeship_achievements` appears on Advanced Manufacturing and Digital. Broadband appears on Advanced Manufacturing and Digital but not Life Sciences. Rotherham is closer to its top performers than Barnsley or Doncaster — the gaps are smaller and less numerous.
#
# **Sheffield — no barriers identified**
#
# Method limitation as discussed.
#
# ---
#
# **The synthesis across all three sectors and four LADs:**
#
# | Variable | Barnsley | Doncaster | Rotherham | Type |
# |---|---|---|---|---|
# | Broadband availability | ✗✗✗ | — | partial | Infrastructure |
# | 4G coverage | ✗✗✗ | — | — | Infrastructure |
# | Transport accessibility | ✗✗ | — | — | Infrastructure |
# | Unemployment rate | ✗✗✗ | — | partial | Labour market |
# | Level 3+ qualifications | ✗✗✗ | ✗✗✗ | — | Skills |
# | GCSE by age 19 | partial | ✗✗✗ | ✗✗✗ | Skills |
# | Apprenticeship achievements | — | partial | partial | Skills |
# | Size micro share | ✗✗✗ | partial | partial | Firm dynamics |
#
# ---
#
# **The policy implication for the write-up:**
#
# There are two distinct intervention logics depending on which LAD you're talking about:
#
# For **Doncaster and Rotherham** the binding constraint is skills — specifically qualification attainment at GCSE and Level 3. These are solvable through FE investment and employer-led training programmes. The industrial base and infrastructure are adequate.
#
# For **Barnsley** the barriers are structural and compound. Broadband and connectivity gaps mean IS8 firms won't locate there regardless of skills supply. The high micro-firm share and low large-firm share means there's no anchor employer to drive demand for higher skills. This requires infrastructure investment as a prerequisite, followed by firm attraction, before skills interventions become effective.

# %%
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import numpy as np
import pandas as pd
import seaborn as sns
import os

OUTPUT_DIR = "../../output/graphs/franco"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ============================================================
# CELL 7 — Cross-sector co-location adjacency analysis
#
# Step 1: Correlation matrix of IS8 sector LQs across all LADs
# Step 2: Scatter plots for the most relevant sector pairs
# Step 3: SY-specific adjacency profile
# ============================================================

SECTORS = [s for s in panel["IS8_SECTOR"].unique() if s != "Defence"]

# ── Step 1: Build wide LQ matrix (LAD × sector) ─────────────
lq_wide = (
    panel[panel["YEAR"] == YEAR]
    .pivot_table(index="GEOGRAPHY_CODE", columns="IS8_SECTOR", values="lq_emp")
    .drop(columns=["Defence"], errors="ignore")
    .dropna()
)

print(f"LADs with complete IS8 data (excl. Defence): {len(lq_wide)}")

# Spearman correlation — robust to outlier LQs
corr = lq_wide.corr(method="spearman")

# ── Plot 1: Correlation heatmap (lower triangle only) ────────
fig, ax = plt.subplots(figsize=(10, 8))
mask = np.triu(np.ones_like(corr, dtype=bool), k=1)

sns.heatmap(
    corr,
    ax=ax,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="RdYlGn",
    center=0,
    vmin=-1, vmax=1,
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8, "label": "Spearman correlation"},
)
ax.set_title(
    f"IS8 sector co-location — Spearman correlation of LQ employment\n"
    f"Across all LADs (excl. Defence), {YEAR}",
    fontsize=11, fontweight="bold"
)
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right", fontsize=8)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=8)

plt.tight_layout()
fname = f"{OUTPUT_DIR}/adjacency_correlation_matrix.png"
plt.savefig(fname, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {fname}")

# Print correlation ranking for focus sectors
print("\n=== CORRELATION RANKING FOR FOCUS SECTORS ===")
for sector in FOCUS_SECTORS:
    print(f"\n{sector} — most correlated IS8 sectors:")
    ranked = corr[sector].drop(sector).sort_values(ascending=False)
    for s, r in ranked.items():
        print(f"  {s:<45} r={r:+.3f}")

# ── Step 2: Scatter plots for relevant pairs ─────────────────
pairs = []
for s1 in FOCUS_SECTORS:
    for s2 in SECTORS:
        if s2 == s1:
            continue
        r = corr.loc[s1, s2]
        pairs.append((abs(r), r, s1, s2))

pairs = sorted(pairs, reverse=True)
seen, top_pairs = set(), []
for _, r, s1, s2 in pairs:
    key = tuple(sorted([s1, s2]))
    if key not in seen:
        seen.add(key)
        top_pairs.append((r, s1, s2))
    if len(top_pairs) == 6:
        break

sy_lq_wide = lq_wide.reindex(SY_CODES).mean()

fig, axes = plt.subplots(2, 3, figsize=(18, 11))
fig.suptitle(
    f"IS8 sector co-location — top correlated pairs involving focus sectors\n"
    f"All LADs in blue, SY LADs in red  |  {YEAR}",
    fontsize=12, fontweight="bold"
)

for ax, (r, s1, s2) in zip(axes.flatten(), top_pairs):
    x_all = lq_wide[s1].values
    y_all = lq_wide[s2].values
    codes = lq_wide.index.tolist()
    names = (
        panel[panel["YEAR"] == YEAR]
        .drop_duplicates("GEOGRAPHY_CODE")
        .set_index("GEOGRAPHY_CODE")["GEOGRAPHY_NAME"]
        .reindex(codes)
        .values
    )
    is_sy = np.array([c in SY_CODES for c in codes])

    ax.scatter(x_all[~is_sy], y_all[~is_sy],
               color="steelblue", alpha=0.25, s=25, zorder=2)

    z = np.polyfit(x_all, y_all, 1)
    xl = np.linspace(x_all.min(), x_all.max(), 200)
    ax.plot(xl, np.poly1d(z)(xl), "--", color="grey", linewidth=1.2,
            alpha=0.6, zorder=3, label=f"Trend (r={r:+.2f})")

    for xi, yi, nm, sy in zip(x_all, y_all, names, is_sy):
        if not sy:
            continue
        ax.scatter(xi, yi, color="crimson", s=120, zorder=6,
                   edgecolors="black", linewidths=0.6)
        ax.annotate(nm, (xi, yi),
                    xytext=(7, 4), textcoords="offset points",
                    fontsize=7.5, color="crimson", fontweight="bold",
                    path_effects=[pe.withStroke(linewidth=2.5,
                                                foreground="white")])

    ax.axvline(1.0, color="dimgrey", linewidth=0.6,
               linestyle="--", alpha=0.5)
    ax.axhline(1.0, color="dimgrey", linewidth=0.6,
               linestyle="--", alpha=0.5)
    ax.set_xlabel(s1, fontsize=8)
    ax.set_ylabel(s2, fontsize=8)
    ax.set_title(f"{s1[:20]} × {s2[:20]}", fontsize=8, fontweight="bold")
    ax.legend(fontsize=7)
    ax.grid(alpha=0.15)

plt.tight_layout()
fname = f"{OUTPUT_DIR}/adjacency_scatter_pairs.png"
plt.savefig(fname, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {fname}")

# ── Step 3: SY adjacency profile ─────────────────────────────
print("\n=== SY ADJACENCY PROFILE ===")
print("For each focus sector, SY's LQ on correlated IS8 sectors\n")

for sector in FOCUS_SECTORS:
    print(f"--- {sector} ---")
    ranked = corr[sector].drop(sector).sort_values(ascending=False)
    for s, r in ranked.items():
        sy_lq = sy_lq_wide.get(s, np.nan)
        above = "▲ above avg" if sy_lq > 1.0 else "▼ below avg"
        print(f"  {s:<45} r={r:+.3f}  SY LQ={sy_lq:.2f}  {above}")
    print()

# %% [markdown]
# **The correlation matrix — the big structural insight**
#
# Advanced Manufacturing is **negatively correlated** with almost everything: Creative Industries (-0.32), Financial Services (-0.20), Professional & Business Services (-0.20). It's essentially orthogonal to the urban knowledge economy cluster. The only positive correlation is with Life Sciences (+0.13) — weak but notable.
#
# Digital, Creative, Professional & Business Services and Financial Services form a tight urban cluster — correlations of 0.68–0.74 between them. These sectors co-locate in the same types of places: city centres, graduate economies, dense service sectors.
#
# Life Sciences is the most independent sector — weak positive correlations with everything, no strong co-location pattern. It follows its own logic (proximity to research hospitals, universities, specific supply chains).
#
# **The SY adjacency profile — the uncomfortable finding**
#
# Every single entry is "▼ below avg". SY is below LQ=1 on every IS8 sector that correlates with its three focus sectors. This means SY doesn't currently have a strong adjacency base to leverage from within IS8 sectors.
#
# But read it more carefully:
#
# For **Life Sciences** the correlations are all weak (max r=+0.20) — Life Sciences doesn't strongly co-locate with anything. So the absence of adjacent IS8 sectors in SY doesn't really constrain Life Sciences development. Sheffield's anchor is driven by non-IS8 factors (university, NHS) not by IS8 adjacency.
#
# For **Advanced Manufacturing** the correlations are all negative or near-zero. Advanced Manufacturing actively doesn't co-locate with the urban knowledge economy. SY's below-average scores on Creative, Financial, and Professional Services are therefore not barriers — they're irrelevant or even structurally expected for a manufacturing economy.
#
# For **Digital & Technologies** the strong correlation with Creative Industries (r=+0.74) and Professional & Business Services (r=+0.68) is the critical finding. SY scores below average on both. This is the adjacency gap — Digital tends to grow where Creative and Professional services are already present, and SY is weak on both.
#
# ---
#
# **The revised adjacency argument:**
#
# | Focus sector | Key adjacency | SY position | Implication |
# |---|---|---|---|
# | Life Sciences | Weakly correlated with everything — location-independent | All adjacent sectors below avg — but doesn't matter | Sheffield's anchor is institutional not adjacency-driven |
# | Advanced Manufacturing | Negatively correlated with urban knowledge economy — stands alone | Expected — manufacturing doesn't need creative/financial sectors nearby | Humber Clean Energy adjacency is the real argument, not IS8 cross-sector |
# | Digital & Technologies | Strongly tied to Creative Industries (0.74) and Prof Services (0.68) | Both below avg in SY — genuine adjacency gap | Creative sector weakness is a binding constraint on Digital growth |
#
# The most actionable finding is the Digital-Creative link. SY's Creative Industries LQ of 0.74 (employment) is directly implicated in the Digital underperformance. Investing in creative sector presence — particularly in Sheffield where it's least weak — could unlock Digital growth through the adjacency mechanism.

# %% [markdown]
# ## Narrative Structure
#
# ### 1. Opening framing (1 paragraph)
# South Yorkshire MCA is not one economy — the dendrogram showed this before we wrote a single sentence. Sheffield clusters separately from Barnsley, Doncaster and Rotherham. Everything that follows is structured around that internal differentiation. The MCA aggregate masks more than it reveals.
#
# ---
#
# ### 2. Current IS8 footprint (1 paragraph + table from Cell 1)
# Present the footprint table. Three sectors above national average: Life Sciences (1.51), Professional & Business Services (1.09), Advanced Manufacturing (1.16 employment / 1.69 business count). The business count gap in Advanced Manufacturing signals SME fragmentation — many firms, limited depth. Defence absent. Creative Industries and Digital below average.
#
# ---
#
# ### 3. Trajectory — anchor, emerging, declining (1 paragraph + quadrant plots 5c)
# - Life Sciences: growing strongly (CAGR 12.6%, well above national median) — anchor at MCA level, but driven entirely by Sheffield
# - Advanced Manufacturing: employment growing above national median, business counts positive — momentum sector
# - Digital & Technologies: employment declining below national median for Barnsley and Rotherham, Doncaster and Sheffield slightly positive — the most mixed picture
# - Use the quadrant plots to show this visually
#
# ---
#
# ### 4. Internal differentiation — the LAD-level story (2 paragraphs + scatter plots 5a/5b)
# This is the analytical contribution of Phase 2 over the regional picture.
#
# **Paragraph 1 — Life Sciences:**
# Sheffield (LQ 1.90) overperforms relative to its structural peer group — above the cluster trend line, converting related variety into sector presence. Barnsley, Doncaster and Rotherham sit at the bottom of their cluster despite similar related variety values. Peer comparators Broxtowe (LQ 7.66) and Halton (LQ 5.78) show what is achievable with similar structural conditions. The barrier is institutional — Sheffield has the University of Sheffield, Sheffield Hallam, and two major NHS trusts; the other three have none of these anchors.
#
# **Paragraph 2 — Advanced Manufacturing and Digital:**
# Advanced Manufacturing is performing broadly as structural position predicts — Rotherham slightly above trend, others on it. The SME fragmentation story is visible in the business count plots — firm presence is proportional to related variety but employment depth lags. Digital is the most analytically distinctive case: all four LADs sit at the high end of related variety nationally but none are converting it into employment or firm presence. The co-location analysis reveals why — Digital growth nationally is strongly tied to Creative Industries (r=+0.74) and Professional & Business Services (r=+0.68), and SY is below average on both.
#
# ---
#
# ### 5. Barriers — why is potential unrealised? (1-2 paragraphs + barrier heatmaps)
# Draw directly from the robust barriers table. Two distinct intervention logics:
#
# **Doncaster and Rotherham — skills pipeline:**
# GCSE attainment and Level 3+ qualifications are robust barriers (n=4) across all three focus sectors. Apprenticeship achievements also appear consistently. The workforce qualification pipeline is the primary constraint. Infrastructure is adequate. These are addressable through FE investment and employer-led training, without requiring major capital expenditure.
#
# **Barnsley — compound structural disadvantage:**
# Broadband availability (-18 to -23pp gap), 4G coverage, transport accessibility, unemployment rate, and micro-firm dominance all appear simultaneously. This is a different order of problem. Infrastructure investment is a prerequisite before skills or firm attraction interventions can work — IS8 firms require connectivity as a basic condition of operation. The absence of large anchor employers creates a low-skill equilibrium trap: firms don't locate because skills are weak, skills don't develop because firms aren't there to demand them.
#
# ---
#
# ### 6. Adjacency — forward-looking positioning (1 paragraph)
# Advanced Manufacturing does not co-locate with the urban knowledge economy — it is structurally independent. The adjacency argument for Advanced Manufacturing therefore lies outside IS8: the proximity to the Humber estuary, home to the UK's largest offshore wind installation base, creates a supply chain opportunity in Clean Energy. SY's existing Advanced Manufacturing capability in precision engineering and materials is directly applicable to wind turbine components, subsea infrastructure, and grid technology.
#
# For Digital, the co-location analysis points to Creative Industries as the enabling adjacency. Sheffield's Creative LQ (0.85 employment, higher than the other three) makes it the most viable entry point for Digital cluster development within SY. Targeted support for creative-digital convergence in Sheffield — animation, digital media, software — could generate the spillover conditions that the EEG literature identifies as preconditions for broader digital sector growth.
#
# ---
#
# ### 7. Conclusion — sector prioritisation (1 short paragraph)
# Three tiers of recommendation emerge from the analysis:
# - **Consolidate**: Life Sciences in Sheffield — anchor is established, trajectory is strong, policy should deepen rather than seed
# - **Develop**: Advanced Manufacturing across the MCA, with targeted Clean Energy adjacency via Humber — momentum is positive, SME fragmentation is the binding constraint
# - **Invest to unlock**: Digital in Sheffield and Doncaster — related variety is present, Creative-Digital adjacency needs nurturing, skills gaps in Doncaster are addressable
#
# Barnsley requires a different policy logic entirely — infrastructure investment before sector-specific interventions.
#
# ---
#
# ## Plot allocation for write-up
#
# | Section | Plot |
# |---|---|
# | Footprint | Cell 1 table |
# | Trajectory | 5c quadrant — lq_emp vs cagr_emp |
# | Internal differentiation | 5b — related variety vs lq_emp (Life Sciences + Digital panels) |
# | Fragmentation | 5a — structural vs lq_bus |
# | Barriers | barrier_gap_lq_emp heatmap (one representative heatmap) + robust barriers table |
# | Adjacency | adjacency_correlation_matrix + Digital×Creative scatter panel |
